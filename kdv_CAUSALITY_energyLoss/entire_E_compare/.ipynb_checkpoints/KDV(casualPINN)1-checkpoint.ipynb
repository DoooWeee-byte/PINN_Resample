# %% [markdown]
# step_size=5000

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata

import torch
from torch import nn
import torch.optim as optim
from torch.optim import lr_scheduler

import argparse
import random
import os
import math

#os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# CUDA support
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

def activation(name):
    if name in ['tanh', 'Tanh']:
        return nn.Tanh()
    elif name in ['relu', 'ReLU']:
        return nn.ReLU(inplace=True)
    elif name in ['leaky_relu', 'LeakyReLU']:
        return nn.LeakyReLU(inplace=True)
    elif name in ['sigmoid', 'Sigmoid']:
        return nn.Sigmoid()
    elif name in ['softplus', 'Softplus']:
        return nn.Softplus()
    else:
        raise ValueError(f'unknown activation function: {name}')

# %%
seed_torch(42)

# %% [markdown]
# ## 网络模型

# %%
class MLP(nn.Module):
    """Deep Neural Network"""

    def __init__(self, L, M, dim_hidden, hidden_layers, dim_out,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        
        dim_in = M * 2 + 2
        
        model = nn.Sequential()
        
        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))
            
        self.model = model
        
        self.L = L
        self.M = M
        
        if init_name is not None:
            self.init_weight(init_name)

            
        self.k = nn.Parameter(torch.arange(1, self.M+1), requires_grad=False)
                    
    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
                
#         for layer, param in enumerate(self.parameters()):
#             if layer % 2 == 1:
#                 nn.init.constant_(param, 0.0)
#             else:
#                 nn_init(param)
                
    def input_encoding(self, t, x):
        w = 2.0 * math.pi / self.L
        out = torch.cat([t, torch.ones_like(t), 
                            torch.cos(self.k * w * x), torch.sin(self.k * w * x)], dim = 1) 
        
        return out    
            
    def forward(self, H):
        t = H[:, 0:1]
        x = H[:, 1:2]
        
        H = self.input_encoding(t, x)
        H = self.model(H)
        
        return H
    
    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params
    
    def print(self):
        print(self.bias)

# %%
model = MLP(L=2.0, M=10, dim_hidden=128, hidden_layers=4, dim_out=1)

# %% [markdown]
# ## PDE部分

# %% [markdown]
# KDV方程：
# $$
# \left\{\begin{matrix}
# &u_{t}+ \lambda_1 u u_{x} + \lambda_2 u_{xxx}=0  ,(t,x)\in (0,1)\times (-1,1),  \\
# &u(0,x)= cos(\pi x),  \\
# &u(t,-1)=u(t,1),t\in [0,1],  \\
# &u_x(t,-1)=u_x(t,1),x\in [0,1].
# \end{matrix}\right.
# $$
# $\lambda_1 = 1.000$, $\lambda_2 = 0.0025$.

# %% [markdown]
# ## Options

# %%
import argparse
class Options_KDV(object):
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--no_cuda', action='store_true', default=False, help='disable CUDA or not')
        parser.add_argument('--dim_hidden', type=int, default=12, help='neurons in hidden layers')     # 10 9
        parser.add_argument('--hidden_layers', type=int, default=9, help='number of hidden layers')    # 4  20
        parser.add_argument('--lam', type=float, default=1, help='weight in loss function')
        parser.add_argument('--lr', type=float, default=0.001, help='initial learning rate')
        parser.add_argument('--epochs_Adam', type=int, default=600000, help='epochs for Adam optimizer')
        parser.add_argument('--epochs_LBFGS', type=int, default=2500, help='epochs for LBFGS optimizer')
        parser.add_argument('--newton_iter', type=int, default=100, help='newton_iter for LBFGS optimizer')
        parser.add_argument('--step_size', type=int, default=10000, help='step size in lr_scheduler for Adam optimizer')
        parser.add_argument('--gamma', type=float, default=0.9, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--tol', type=float, default=100, help='the annealing scheme')
        parser.add_argument('--resume', type=bool, default=False, help='resume or not')
        parser.add_argument('--sample_method', type=str, default='uniform', help='sample method')

        self.parser = parser

    def parse(self):
        arg = self.parser.parse_args(args=[])
        arg.load_model = False
        arg.cuda = not arg.no_cuda and torch.cuda.is_available()
        # arg.cuda = False
        arg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(arg.cuda)
        print(arg.device)
        return arg

args = Options_KDV().parse()
print(args.hidden_layers)

'''
def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth.tar')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth.tar')
        shutil.copyfile(last_model, best_model)
'''
# Out:
# True
# cuda
# 9
# "\ndef save_model(state, is_best=None, save_dir=None):\n    last_model = os.path.join(save_dir, 'last_model.pth.tar')\n    torch.save(state, last_model)\n    if is_best:\n        best_model = os.path.join(save_dir, 'best_model.pth.tar')\n        shutil.copyfile(last_model, best_model)\n"

# %%
model.to(device)
args.model=model

# %% [markdown]
# ## 数据集生成

# %%
class Trainset_KDV():
    '''
    训练点:时间剖分 100 段， 空间上分成25段，每段上取4个高斯点
    '''
    def __init__(self, *args):
        self.args = args
        self.shape = (self.args[1], self.args[0])
        
    def __call__(self):
        return self.data()
    
    def data(self):
        gp = np.array([0.8611363116,-0.8611363116,0.3399810436,-0.3399810436])
        gc = np.array([0.3478548451,0.3478548451,0.6521451549,0.6521451549])
        n_t = self.args[0]
        n_x = self.args[1]
        n_ics = self.args[2]
        
        # 生成初值训练点
        t = np.linspace(0, 1, n_t)
        x = np.linspace(-1, 1, n_x)
        t, x = np.meshgrid(t, x)
        tx = np.hstack((t.reshape(-1,1), x.reshape(-1,1)))
        
        t_ics = np.zeros(n_ics)
        x_ics = np.linspace(-1, 1, n_ics)
        tx_ics = np.hstack([t_ics.reshape(-1,1),x_ics.reshape(-1,1)])
        
        u_ics = np.cos(math.pi*x_ics)
        u_ics = u_ics.reshape(-1,1)
        M = np.triu(np.ones([n_t, n_t]),k=1).T
        
        # 生成tgx(高斯训练点)
        l = np.linspace(-1, 1, 26)[:, None]
        l = np.hstack([l[:-1], l[1:]])
        c = (l[:, 1] - l[:, 0])/2
        c = c[:, None]
        gp = gp[None, :]
        d = ((l[:, 1] + l[:, 0])/2)
        d = d[:, None]
        n_p = c * gp + d  # n_p是100个高斯积分点
        n_p = n_p.reshape(100, 1)
        gcl = c * gc     # gcl是这100个高斯积分点对应的权重  
        gcl = gcl.reshape(100, 1)
        t = np.linspace(0, 1, n_t)
        t = np.random.choice(t, 5, False)
        t = t[:, None]
        x, t = np.meshgrid(n_p, t)
        print(t.shape, x.shape)
        txg = np.hstack([t.reshape(-1, 1), x.reshape(-1, 1)])
        
        # 计算一下初始能量
        E2 =  np.cos(math.pi*n_p) ** 2 * gcl
        E2 = np.sum(E2)
        
        txg = np.hstack((t.reshape(-1,1), x.reshape(-1,1)))
        
        tx = torch.from_numpy(tx).float().to(device)
        txg = torch.from_numpy(txg).float().to(device)
        tx_ics = torch.from_numpy(tx_ics).float().to(device)
        u_ics = torch.from_numpy(u_ics).float().to(device)
        M = torch.from_numpy(M).float().to(device)
        
        return tx, tx_ics, u_ics, M, gcl, txg, E2

# %%
trainset = Trainset_KDV(100, 256, 512)
args.trainset = trainset
tx, tx_ics, u_ics, M, gcl, txg, E2 = trainset()
# Out:
# (5, 100) (5, 100)

# %%
gcl.shape
# Out:
# (100, 1)

# %% [markdown]
# ## 训练

# %%
class Trainer_Wave(object):
    def __init__(self, args):
        self.model = args.model
        self.lr = args.lr
        self.gamma = args.gamma
        self.trainset = args.trainset
        self.step_size = args.step_size
        self.model_name = self.model.__class__.__name__     
        self.optimizer_Adam = optim.Adam(self.model.parameters(), lr=self.lr, betas=(0.9, 0.999))
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=self.gamma)
        self.epochs_Adam = args.epochs_Adam
        self.tol = args.tol
        
        # data
        self.tx, self.tx_ics, self.u_ics, self.M,  self.gcl, self.txg, self.E2 = self.trainset()
        self.gcl = torch.from_numpy(self.gcl).float().to(device)
        self.E2 = torch.tensor(self.E2).float().to(device)
        
        # Logger
        self.loss_log = []
        self.loss_ics_log = []
        self.loss_res_log = []
        self.W_log = []
        self.L_t_log = []
        self.epoch_log = []
        

    def net_r(self, tx):
        tx.requires_grad_(True).to(device)
        u = self.model(tx)
        grad_u = grad(u, tx)[0]
        u_t = grad_u[:,[0]]
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, tx)[0][:, [1]]
        u_xxx = grad(u_xx, tx)[0][:, [1]]

        residual = u_t  + u * u_x + 0.0025 * u_xxx

        return residual

    def net_u(self, tx):
        u = self.model(tx)  
        return u
    
    def residuals_and_weights(self):
        r_pred = self.net_r(self.tx) 
        r_pred = r_pred.reshape(self.trainset.shape[0], self.trainset.shape[1]) # :shape(100,100)
        L_t = torch.mean(r_pred**2, axis=0) 
        L_t = L_t
        W = torch.exp(-self.tol * (self.M @ L_t.detach()))
        
        return L_t, W
    
    def loss_ics(self):
        u_pred = self.net_u(self.tx_ics)
        loss_ics = torch.mean((u_pred - self.u_ics)**2)
        return loss_ics
    
    def loss_res(self):
        r_pred = self.net_r(self.tx)
        loss_r = torch.mean(r_pred**2)
        return loss_r
    
    def loss(self):
        L0 = 100 * self.loss_ics()
        L_t, W = self.residuals_and_weights()
        loss = torch.mean(W * L_t) + L0 
        return loss
    
    def energy_loss(self):
        q_pred = self.net_u(self.txg)
        q_pred = q_pred.reshape(-1, 100)
        gcl = self.gcl.reshape(1, 100)
        
        q_pred = q_pred ** 2 * gcl
        q_pred = torch.sum(q_pred, axis=1)
        q_pred = (q_pred - self.E2)
        loss_q = torch.mean(q_pred ** 2)
        return loss_q
    
    def train(self):
        start = time.time()
        for epoch in range(self.epochs_Adam):
            self.optimizer_Adam.zero_grad()
            loss_value = self.loss()
            loss_value.backward()
            self.optimizer_Adam.step()
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()            
            
            if epoch % 1000 == 0:
                loss_value = self.loss()
                loss_ics_value = self.loss_ics()
                loss_res_value = self.loss_res()
                loss_energy_value = self.energy_loss()
                L_t_value, W_value = self.residuals_and_weights()
                
                self.loss_log.append(loss_value.detach().cpu())
                self.loss_ics_log.append(loss_ics_value.detach().cpu())
                self.loss_res_log.append(loss_res_value.detach().cpu())
                self.W_log.append(W_value.detach().cpu())
                self.L_t_log.append(L_t_value.detach().cpu())
                self.epoch_log.append(epoch)
                
                end = time.time()
                running_time = end - start
                start = time.time()
                
                print(f'Epoch #  {epoch}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_ics:{loss_ics_value:.2e}, loss_res:{loss_res_value:.2e}, loss_energy_value:{loss_energy_value:2e}')

# %%
trainer = Trainer_Wave(args)
trainer.train()
# Out:
# (5, 100) (5, 100)
# Epoch #  0/600000    time:0.16
# loss:5.39e+01, loss_ics:5.11e-01, loss_res:2.85e+02, loss_energy_value:7.655143e-01
# Epoch #  1000/600000    time:56.09
# loss:3.99e-03, loss_ics:2.87e-07, loss_res:6.82e+01, loss_energy_value:1.400524e-01
# Epoch #  2000/600000    time:60.54
# loss:3.78e-04, loss_ics:2.66e-07, loss_res:4.84e+01, loss_energy_value:2.789182e-01
# Epoch #  3000/600000    time:62.75
# loss:1.13e-03, loss_ics:8.13e-06, loss_res:3.38e+01, loss_energy_value:3.065061e-01
# Epoch #  4000/600000    time:65.73
# loss:3.17e-03, loss_ics:2.81e-05, loss_res:2.81e+01, loss_energy_value:3.355340e-01
# Epoch #  5000/600000    time:64.93
# loss:8.50e-04, loss_ics:5.94e-06, loss_res:2.48e+01, loss_energy_value:3.535501e-01
# Epoch #  6000/600000    time:67.44
# loss:9.80e-04, loss_ics:7.41e-06, loss_res:2.17e+01, loss_energy_value:3.787576e-01
# Epoch #  7000/600000    time:62.03
# loss:2.21e-03, loss_ics:1.99e-05, loss_res:1.91e+01, loss_energy_value:3.881383e-01
# Epoch #  8000/600000    time:62.51
# loss:3.13e-03, loss_ics:2.91e-05, loss_res:1.75e+01, loss_energy_value:3.756514e-01
# Epoch #  9000/600000    time:64.97
# loss:5.72e-03, loss_ics:5.52e-05, loss_res:1.70e+01, loss_energy_value:3.682451e-01
# Epoch #  10000/600000    time:65.77
# loss:1.25e-03, loss_ics:1.06e-05, loss_res:1.68e+01, loss_energy_value:3.663557e-01
# Epoch #  11000/600000    time:65.02
# loss:1.13e-03, loss_ics:9.57e-06, loss_res:1.68e+01, loss_energy_value:3.390668e-01
# Epoch #  12000/600000    time:67.04
# loss:5.34e-04, loss_ics:3.84e-06, loss_res:1.55e+01, loss_energy_value:3.414313e-01
# Epoch #  13000/600000    time:65.96
# loss:4.13e-04, loss_ics:2.67e-06, loss_res:1.43e+01, loss_energy_value:3.217596e-01
# Epoch #  14000/600000    time:64.53
# loss:1.86e-03, loss_ics:1.71e-05, loss_res:1.36e+01, loss_energy_value:3.038710e-01
# Epoch #  15000/600000    time:70.31
# loss:4.69e-04, loss_ics:3.23e-06, loss_res:1.28e+01, loss_energy_value:2.966094e-01
# Epoch #  16000/600000    time:62.20
# loss:3.79e-04, loss_ics:2.42e-06, loss_res:1.24e+01, loss_energy_value:2.866972e-01
# Epoch #  17000/600000    time:70.24
# loss:1.89e-04, loss_ics:5.54e-07, loss_res:1.33e+01, loss_energy_value:2.328905e-01
# Epoch #  18000/600000    time:69.19
# loss:3.67e-04, loss_ics:2.41e-06, loss_res:1.21e+01, loss_energy_value:2.241218e-01
# Epoch #  19000/600000    time:68.28
# loss:3.94e-04, loss_ics:2.69e-06, loss_res:1.07e+01, loss_energy_value:2.348071e-01
# Epoch #  20000/600000    time:68.06
# loss:1.28e-03, loss_ics:1.15e-05, loss_res:9.78e+00, loss_energy_value:2.300930e-01
# Epoch #  21000/600000    time:70.57
# loss:2.03e-04, loss_ics:5.74e-07, loss_res:9.12e+00, loss_energy_value:2.159031e-01
# Epoch #  22000/600000    time:65.42
# loss:1.42e-03, loss_ics:1.29e-05, loss_res:8.68e+00, loss_energy_value:1.932022e-01
# Epoch #  23000/600000    time:71.14
# loss:3.20e-04, loss_ics:1.96e-06, loss_res:8.23e+00, loss_energy_value:1.854906e-01
# Epoch #  24000/600000    time:70.53
# loss:2.38e-04, loss_ics:1.07e-06, loss_res:7.75e+00, loss_energy_value:1.847968e-01
# Epoch #  25000/600000    time:68.38
# loss:2.23e-04, loss_ics:1.01e-06, loss_res:7.37e+00, loss_energy_value:1.732286e-01
# Epoch #  26000/600000    time:68.28
# loss:5.50e-04, loss_ics:4.24e-06, loss_res:6.93e+00, loss_energy_value:1.934392e-01
# Epoch #  27000/600000    time:66.47
# loss:2.47e-04, loss_ics:1.28e-06, loss_res:6.55e+00, loss_energy_value:2.101898e-01
# Epoch #  28000/600000    time:68.74
# loss:1.44e-04, loss_ics:1.45e-08, loss_res:6.10e+00, loss_energy_value:2.319068e-01
# Epoch #  29000/600000    time:65.37
# loss:1.41e-04, loss_ics:2.47e-07, loss_res:6.40e+00, loss_energy_value:1.961107e-01
# Epoch #  30000/600000    time:70.68
# loss:2.37e-04, loss_ics:1.21e-06, loss_res:6.01e+00, loss_energy_value:2.116440e-01
# Epoch #  31000/600000    time:68.31
# loss:6.55e-04, loss_ics:5.39e-06, loss_res:5.73e+00, loss_energy_value:2.142230e-01
# Epoch #  32000/600000    time:66.69
# loss:9.27e-04, loss_ics:8.07e-06, loss_res:5.46e+00, loss_energy_value:2.203156e-01
# Epoch #  33000/600000    time:69.75
# loss:2.71e-04, loss_ics:1.56e-06, loss_res:5.27e+00, loss_energy_value:2.171503e-01
# Epoch #  34000/600000    time:69.31
# loss:8.09e-03, loss_ics:6.43e-05, loss_res:4.80e+00, loss_energy_value:3.107617e-01
# Epoch #  35000/600000    time:68.61
# loss:1.40e-04, loss_ics:2.75e-07, loss_res:4.83e+00, loss_energy_value:2.065177e-01
# Epoch #  36000/600000    time:70.58
# loss:2.36e-04, loss_ics:1.04e-06, loss_res:4.85e+00, loss_energy_value:1.993943e-01
# Epoch #  37000/600000    time:70.04
# loss:2.86e-04, loss_ics:1.73e-06, loss_res:4.69e+00, loss_energy_value:1.965668e-01
# Epoch #  38000/600000    time:69.36
# loss:2.44e-04, loss_ics:1.26e-06, loss_res:4.67e+00, loss_energy_value:1.924753e-01
# Epoch #  39000/600000    time:64.20
# loss:3.48e-04, loss_ics:2.30e-06, loss_res:4.54e+00, loss_energy_value:1.909273e-01
# Epoch #  40000/600000    time:69.42
# loss:2.03e-04, loss_ics:9.06e-07, loss_res:4.52e+00, loss_energy_value:1.825114e-01
# Epoch #  41000/600000    time:74.12
# loss:2.58e-04, loss_ics:1.43e-06, loss_res:4.53e+00, loss_energy_value:1.760292e-01
# Epoch #  42000/600000    time:65.14
# loss:1.64e-04, loss_ics:4.98e-07, loss_res:4.53e+00, loss_energy_value:1.725989e-01
# Epoch #  43000/600000    time:68.17
# loss:1.96e-04, loss_ics:8.10e-07, loss_res:4.43e+00, loss_energy_value:1.677521e-01
# Epoch #  44000/600000    time:71.43
# loss:1.72e-04, loss_ics:5.36e-07, loss_res:4.43e+00, loss_energy_value:1.661809e-01
# Epoch #  45000/600000    time:67.88
# loss:2.07e-04, loss_ics:9.68e-07, loss_res:4.44e+00, loss_energy_value:1.638771e-01
# Epoch #  46000/600000    time:67.14
# loss:1.57e-04, loss_ics:4.31e-07, loss_res:4.43e+00, loss_energy_value:1.641512e-01
# Epoch #  47000/600000    time:64.70
# loss:1.82e-04, loss_ics:7.21e-07, loss_res:4.41e+00, loss_energy_value:1.625783e-01
# Epoch #  48000/600000    time:67.34
# loss:3.32e-04, loss_ics:2.21e-06, loss_res:4.38e+00, loss_energy_value:1.678759e-01
# Epoch #  49000/600000    time:68.59
# loss:2.25e-04, loss_ics:1.14e-06, loss_res:4.51e+00, loss_energy_value:1.630198e-01
# Epoch #  50000/600000    time:73.20
# loss:2.06e-04, loss_ics:9.53e-07, loss_res:4.54e+00, loss_energy_value:1.639714e-01
# Epoch #  51000/600000    time:71.04
# loss:2.39e-04, loss_ics:1.30e-06, loss_res:4.79e+00, loss_energy_value:1.592241e-01
# Epoch #  52000/600000    time:73.65
# loss:1.34e-04, loss_ics:2.54e-07, loss_res:4.80e+00, loss_energy_value:1.585751e-01
# Epoch #  53000/600000    time:71.59
# loss:1.59e-04, loss_ics:4.74e-07, loss_res:4.82e+00, loss_energy_value:1.595475e-01
# Epoch #  54000/600000    time:71.70
# loss:2.08e-04, loss_ics:9.67e-07, loss_res:4.91e+00, loss_energy_value:1.596183e-01
# Epoch #  55000/600000    time:72.85
# loss:1.40e-04, loss_ics:3.08e-07, loss_res:5.06e+00, loss_energy_value:1.568491e-01
# Epoch #  56000/600000    time:64.92
# loss:3.57e-04, loss_ics:2.36e-06, loss_res:5.16e+00, loss_energy_value:1.555979e-01
# Epoch #  57000/600000    time:72.10
# loss:3.71e-04, loss_ics:2.62e-06, loss_res:5.35e+00, loss_energy_value:1.529578e-01
# Epoch #  58000/600000    time:68.32
# loss:1.97e-04, loss_ics:8.09e-07, loss_res:5.43e+00, loss_energy_value:1.532447e-01
# Epoch #  59000/600000    time:66.21
# loss:1.57e-04, loss_ics:4.81e-07, loss_res:5.32e+00, loss_energy_value:1.526372e-01
# Epoch #  60000/600000    time:71.81
# loss:1.94e-04, loss_ics:8.49e-07, loss_res:5.51e+00, loss_energy_value:1.503991e-01
# Epoch #  61000/600000    time:69.01
# loss:1.51e-04, loss_ics:4.43e-07, loss_res:6.00e+00, loss_energy_value:1.447274e-01
# Epoch #  62000/600000    time:72.28
# loss:1.44e-04, loss_ics:3.52e-07, loss_res:6.34e+00, loss_energy_value:1.394783e-01
# Epoch #  63000/600000    time:71.77
# loss:1.46e-04, loss_ics:3.52e-07, loss_res:6.59e+00, loss_energy_value:1.366948e-01
# Epoch #  64000/600000    time:71.53
# loss:1.48e-04, loss_ics:4.04e-07, loss_res:7.04e+00, loss_energy_value:1.309666e-01
# Epoch #  65000/600000    time:70.63
# loss:1.79e-04, loss_ics:7.17e-07, loss_res:7.24e+00, loss_energy_value:1.292107e-01
# Epoch #  66000/600000    time:70.72
# loss:3.23e-04, loss_ics:2.16e-06, loss_res:7.59e+00, loss_energy_value:1.253740e-01
# Epoch #  67000/600000    time:71.88
# loss:2.48e-04, loss_ics:1.41e-06, loss_res:7.64e+00, loss_energy_value:1.208404e-01
# Epoch #  68000/600000    time:75.75
# loss:1.96e-04, loss_ics:8.84e-07, loss_res:7.86e+00, loss_energy_value:1.163808e-01
# Epoch #  69000/600000    time:70.93
# loss:3.33e-04, loss_ics:2.23e-06, loss_res:8.57e+00, loss_energy_value:1.132919e-01
# Epoch #  70000/600000    time:72.80
# loss:2.05e-04, loss_ics:9.66e-07, loss_res:8.49e+00, loss_energy_value:1.109162e-01
# Epoch #  71000/600000    time:69.50
# loss:1.51e-04, loss_ics:4.34e-07, loss_res:8.98e+00, loss_energy_value:1.055434e-01
# Epoch #  72000/600000    time:69.17
# loss:1.39e-04, loss_ics:2.87e-07, loss_res:9.48e+00, loss_energy_value:1.030656e-01
# Epoch #  73000/600000    time:69.38
# loss:4.12e-04, loss_ics:2.97e-06, loss_res:9.48e+00, loss_energy_value:9.563514e-02
# Epoch #  74000/600000    time:67.47
# loss:1.42e-04, loss_ics:3.62e-07, loss_res:9.81e+00, loss_energy_value:9.194347e-02
# Epoch #  75000/600000    time:69.13
# loss:1.58e-04, loss_ics:4.50e-07, loss_res:9.94e+00, loss_energy_value:8.808579e-02
# Epoch #  76000/600000    time:74.36
# loss:1.41e-04, loss_ics:3.03e-07, loss_res:1.09e+01, loss_energy_value:8.822316e-02
# Epoch #  77000/600000    time:69.20
# loss:2.85e-04, loss_ics:1.66e-06, loss_res:1.04e+01, loss_energy_value:8.401018e-02
# Epoch #  78000/600000    time:72.03
# loss:2.78e-04, loss_ics:1.65e-06, loss_res:1.04e+01, loss_energy_value:8.088920e-02
# Epoch #  79000/600000    time:70.44
# loss:1.83e-04, loss_ics:7.61e-07, loss_res:1.04e+01, loss_energy_value:7.865264e-02
# Epoch #  80000/600000    time:70.03
# loss:1.30e-04, loss_ics:2.12e-07, loss_res:1.07e+01, loss_energy_value:7.799818e-02
# Epoch #  81000/600000    time:68.71
# loss:1.51e-04, loss_ics:4.33e-07, loss_res:1.09e+01, loss_energy_value:7.399713e-02
# Epoch #  82000/600000    time:70.00
# loss:1.19e-04, loss_ics:1.19e-07, loss_res:1.06e+01, loss_energy_value:6.944418e-02
# Epoch #  83000/600000    time:70.68
# loss:1.56e-04, loss_ics:4.68e-07, loss_res:1.12e+01, loss_energy_value:6.853487e-02
# Epoch #  84000/600000    time:69.17
# loss:1.46e-04, loss_ics:3.80e-07, loss_res:1.13e+01, loss_energy_value:6.620273e-02
# Epoch #  85000/600000    time:72.32
# loss:1.71e-04, loss_ics:6.50e-07, loss_res:1.11e+01, loss_energy_value:6.511965e-02
# Epoch #  86000/600000    time:72.53
# loss:1.74e-04, loss_ics:6.46e-07, loss_res:1.12e+01, loss_energy_value:6.364546e-02
# Epoch #  87000/600000    time:72.64
# loss:2.28e-04, loss_ics:1.19e-06, loss_res:1.14e+01, loss_energy_value:6.291467e-02
# Epoch #  88000/600000    time:70.01
# loss:3.83e-04, loss_ics:2.77e-06, loss_res:1.14e+01, loss_energy_value:6.212302e-02
# Epoch #  89000/600000    time:74.90
# loss:1.74e-04, loss_ics:6.86e-07, loss_res:1.12e+01, loss_energy_value:6.081365e-02
# Epoch #  90000/600000    time:73.01
# loss:1.71e-04, loss_ics:6.47e-07, loss_res:1.14e+01, loss_energy_value:6.090644e-02
# Epoch #  91000/600000    time:74.86
# loss:1.83e-04, loss_ics:7.68e-07, loss_res:1.13e+01, loss_energy_value:5.786949e-02
# Epoch #  92000/600000    time:72.54
# loss:1.57e-04, loss_ics:4.69e-07, loss_res:1.14e+01, loss_energy_value:5.580929e-02
# Epoch #  93000/600000    time:75.14
# loss:1.91e-04, loss_ics:8.25e-07, loss_res:1.13e+01, loss_energy_value:5.331748e-02
# Epoch #  94000/600000    time:76.20
# loss:1.32e-04, loss_ics:2.69e-07, loss_res:1.16e+01, loss_energy_value:5.293027e-02
# Epoch #  95000/600000    time:78.78
# loss:2.08e-04, loss_ics:1.01e-06, loss_res:1.13e+01, loss_energy_value:5.204413e-02
# Epoch #  96000/600000    time:77.08
# loss:1.54e-04, loss_ics:4.63e-07, loss_res:1.12e+01, loss_energy_value:5.003707e-02
# Epoch #  97000/600000    time:76.09
# loss:1.71e-04, loss_ics:5.88e-07, loss_res:1.14e+01, loss_energy_value:4.866140e-02
# Epoch #  98000/600000    time:73.22
# loss:1.83e-04, loss_ics:7.78e-07, loss_res:1.10e+01, loss_energy_value:4.669468e-02
# Epoch #  99000/600000    time:77.93
# loss:1.54e-04, loss_ics:4.60e-07, loss_res:1.12e+01, loss_energy_value:4.564775e-02
# Epoch #  100000/600000    time:74.03
# loss:1.26e-04, loss_ics:1.22e-07, loss_res:1.10e+01, loss_energy_value:4.487884e-02
# Epoch #  101000/600000    time:76.99
# loss:1.60e-04, loss_ics:5.37e-07, loss_res:1.09e+01, loss_energy_value:4.242669e-02
# Epoch #  102000/600000    time:72.38
# loss:1.34e-04, loss_ics:2.52e-07, loss_res:1.09e+01, loss_energy_value:4.145095e-02
# Epoch #  103000/600000    time:74.69
# loss:1.44e-04, loss_ics:2.59e-07, loss_res:1.10e+01, loss_energy_value:4.131790e-02
# Epoch #  104000/600000    time:72.76
# loss:1.24e-04, loss_ics:1.79e-07, loss_res:1.10e+01, loss_energy_value:4.225435e-02
# Epoch #  105000/600000    time:72.05
# loss:1.50e-04, loss_ics:4.43e-07, loss_res:1.05e+01, loss_energy_value:3.956473e-02
# Epoch #  106000/600000    time:76.17
# loss:1.40e-04, loss_ics:3.52e-07, loss_res:1.04e+01, loss_energy_value:3.874426e-02
# Epoch #  107000/600000    time:69.88
# loss:1.69e-04, loss_ics:6.13e-07, loss_res:1.04e+01, loss_energy_value:4.092746e-02
# Epoch #  108000/600000    time:71.93
# loss:1.76e-04, loss_ics:7.00e-07, loss_res:1.02e+01, loss_energy_value:3.927756e-02
# Epoch #  109000/600000    time:77.96
# loss:1.26e-04, loss_ics:1.46e-07, loss_res:9.97e+00, loss_energy_value:3.834303e-02
# Epoch #  110000/600000    time:79.01
# loss:1.17e-04, loss_ics:1.03e-07, loss_res:9.90e+00, loss_energy_value:3.818446e-02
# Epoch #  111000/600000    time:74.82
# loss:1.26e-04, loss_ics:1.74e-07, loss_res:9.83e+00, loss_energy_value:3.827461e-02
# Epoch #  112000/600000    time:76.22
# loss:1.43e-04, loss_ics:3.76e-07, loss_res:9.42e+00, loss_energy_value:3.613206e-02
# Epoch #  113000/600000    time:76.74
# loss:1.29e-04, loss_ics:2.29e-07, loss_res:9.27e+00, loss_energy_value:3.498204e-02
# Epoch #  114000/600000    time:76.55
# loss:1.50e-04, loss_ics:4.21e-07, loss_res:8.91e+00, loss_energy_value:3.471181e-02
# Epoch #  115000/600000    time:75.68
# loss:1.47e-04, loss_ics:4.01e-07, loss_res:8.65e+00, loss_energy_value:3.294662e-02
# Epoch #  116000/600000    time:78.30
# loss:1.40e-04, loss_ics:3.14e-07, loss_res:8.62e+00, loss_energy_value:3.258424e-02
# Epoch #  117000/600000    time:75.04
# loss:1.24e-04, loss_ics:1.91e-07, loss_res:8.51e+00, loss_energy_value:3.356167e-02
# Epoch #  118000/600000    time:70.85
# loss:1.55e-04, loss_ics:4.74e-07, loss_res:8.82e+00, loss_energy_value:3.597178e-02
# Epoch #  119000/600000    time:69.68
# loss:1.61e-04, loss_ics:5.60e-07, loss_res:8.49e+00, loss_energy_value:3.372341e-02
# Epoch #  120000/600000    time:73.52
# loss:1.59e-04, loss_ics:5.02e-07, loss_res:8.36e+00, loss_energy_value:3.509028e-02
# Epoch #  121000/600000    time:76.83
# loss:1.31e-04, loss_ics:2.54e-07, loss_res:7.85e+00, loss_energy_value:3.210235e-02
# Epoch #  122000/600000    time:75.16
# loss:1.24e-04, loss_ics:1.74e-07, loss_res:7.67e+00, loss_energy_value:3.133721e-02
# Epoch #  123000/600000    time:72.61
# loss:1.28e-04, loss_ics:1.85e-07, loss_res:7.66e+00, loss_energy_value:3.112946e-02
# Epoch #  124000/600000    time:74.22
# loss:1.29e-04, loss_ics:2.34e-07, loss_res:7.34e+00, loss_energy_value:3.128163e-02
# Epoch #  125000/600000    time:75.96
# loss:1.32e-04, loss_ics:2.24e-07, loss_res:7.23e+00, loss_energy_value:2.927463e-02
# Epoch #  126000/600000    time:75.38
# loss:1.22e-04, loss_ics:1.56e-07, loss_res:7.20e+00, loss_energy_value:3.057698e-02
# Epoch #  127000/600000    time:75.40
# loss:1.27e-04, loss_ics:1.32e-07, loss_res:7.16e+00, loss_energy_value:2.978529e-02
# Epoch #  128000/600000    time:76.92
# loss:1.31e-04, loss_ics:2.31e-07, loss_res:7.00e+00, loss_energy_value:2.846534e-02
# Epoch #  129000/600000    time:77.15
# loss:1.42e-04, loss_ics:3.71e-07, loss_res:6.98e+00, loss_energy_value:2.869218e-02
# Epoch #  130000/600000    time:73.27
# loss:1.29e-04, loss_ics:1.46e-07, loss_res:6.92e+00, loss_energy_value:2.840019e-02
# Epoch #  131000/600000    time:76.93
# loss:1.21e-04, loss_ics:1.55e-07, loss_res:6.85e+00, loss_energy_value:2.874251e-02
# Epoch #  132000/600000    time:74.29
# loss:1.23e-04, loss_ics:1.82e-07, loss_res:6.46e+00, loss_energy_value:2.676794e-02
# Epoch #  133000/600000    time:72.18
# loss:1.25e-04, loss_ics:1.32e-07, loss_res:6.60e+00, loss_energy_value:2.629708e-02
# Epoch #  134000/600000    time:73.55
# loss:1.26e-04, loss_ics:1.77e-07, loss_res:6.31e+00, loss_energy_value:2.597911e-02
# Epoch #  135000/600000    time:75.38
# loss:1.27e-04, loss_ics:2.02e-07, loss_res:6.43e+00, loss_energy_value:2.573900e-02
# Epoch #  136000/600000    time:75.84
# loss:1.52e-04, loss_ics:3.67e-07, loss_res:6.29e+00, loss_energy_value:2.515074e-02
# Epoch #  137000/600000    time:72.36
# loss:1.25e-04, loss_ics:1.66e-07, loss_res:6.19e+00, loss_energy_value:2.518664e-02
# Epoch #  138000/600000    time:76.16
# loss:1.35e-04, loss_ics:2.42e-07, loss_res:5.82e+00, loss_energy_value:2.096686e-02
# Epoch #  139000/600000    time:74.64
# loss:1.33e-04, loss_ics:2.69e-07, loss_res:6.25e+00, loss_energy_value:2.398417e-02
# Epoch #  140000/600000    time:68.71
# loss:1.31e-04, loss_ics:1.52e-07, loss_res:6.04e+00, loss_energy_value:2.389568e-02
# Epoch #  141000/600000    time:71.14
# loss:1.42e-04, loss_ics:3.31e-07, loss_res:5.90e+00, loss_energy_value:2.272403e-02
# Epoch #  142000/600000    time:77.00
# loss:1.27e-04, loss_ics:1.72e-07, loss_res:5.89e+00, loss_energy_value:2.198750e-02
# Epoch #  143000/600000    time:77.70
# loss:1.42e-04, loss_ics:3.39e-07, loss_res:5.94e+00, loss_energy_value:2.267846e-02
# Epoch #  144000/600000    time:75.58
# loss:1.29e-04, loss_ics:1.74e-07, loss_res:5.93e+00, loss_energy_value:2.159380e-02
# Epoch #  145000/600000    time:75.92
# loss:1.61e-04, loss_ics:5.42e-07, loss_res:5.67e+00, loss_energy_value:2.024091e-02
# Epoch #  146000/600000    time:76.40
# loss:1.14e-04, loss_ics:7.78e-08, loss_res:5.81e+00, loss_energy_value:2.021321e-02
# Epoch #  147000/600000    time:72.24
# loss:1.22e-04, loss_ics:1.60e-07, loss_res:5.76e+00, loss_energy_value:2.002352e-02
# Epoch #  148000/600000    time:77.48
# loss:1.88e-04, loss_ics:7.29e-07, loss_res:5.69e+00, loss_energy_value:1.956505e-02
# Epoch #  149000/600000    time:72.59
# loss:1.38e-04, loss_ics:3.21e-07, loss_res:5.72e+00, loss_energy_value:1.889096e-02
# Epoch #  150000/600000    time:74.96
# loss:1.24e-04, loss_ics:1.37e-07, loss_res:5.60e+00, loss_energy_value:1.936309e-02
# Epoch #  151000/600000    time:77.38
# loss:1.28e-04, loss_ics:1.96e-07, loss_res:5.63e+00, loss_energy_value:1.789394e-02
# Epoch #  152000/600000    time:74.93
# loss:1.37e-04, loss_ics:2.31e-07, loss_res:5.52e+00, loss_energy_value:1.717950e-02
# Epoch #  153000/600000    time:74.40
# loss:1.21e-04, loss_ics:1.29e-07, loss_res:5.57e+00, loss_energy_value:1.745452e-02
# Epoch #  154000/600000    time:76.80
# loss:1.20e-04, loss_ics:1.29e-07, loss_res:5.47e+00, loss_energy_value:1.644280e-02
# Epoch #  155000/600000    time:78.16
# loss:1.26e-04, loss_ics:1.86e-07, loss_res:5.46e+00, loss_energy_value:1.608075e-02
# Epoch #  156000/600000    time:75.62
# loss:1.76e-04, loss_ics:6.13e-07, loss_res:5.47e+00, loss_energy_value:1.613808e-02
# Epoch #  157000/600000    time:75.81
# loss:1.28e-04, loss_ics:1.94e-07, loss_res:5.21e+00, loss_energy_value:1.455172e-02
# Epoch #  158000/600000    time:73.67
# loss:1.27e-04, loss_ics:2.20e-07, loss_res:5.51e+00, loss_energy_value:1.505274e-02
# Epoch #  159000/600000    time:75.89
# loss:1.17e-04, loss_ics:1.15e-07, loss_res:5.38e+00, loss_energy_value:1.481248e-02
# Epoch #  160000/600000    time:77.54
# loss:1.16e-04, loss_ics:7.47e-08, loss_res:5.37e+00, loss_energy_value:1.450877e-02
# Epoch #  161000/600000    time:76.54
# loss:1.18e-04, loss_ics:8.26e-08, loss_res:5.26e+00, loss_energy_value:1.388756e-02
# Epoch #  162000/600000    time:76.18
# loss:1.33e-04, loss_ics:1.64e-07, loss_res:5.23e+00, loss_energy_value:1.316109e-02
# Epoch #  163000/600000    time:75.58
# loss:1.24e-04, loss_ics:1.84e-07, loss_res:5.22e+00, loss_energy_value:1.318065e-02
# Epoch #  164000/600000    time:76.13
# loss:1.24e-04, loss_ics:1.59e-07, loss_res:5.16e+00, loss_energy_value:1.156843e-02
# Epoch #  165000/600000    time:75.04
# loss:1.21e-04, loss_ics:1.41e-07, loss_res:5.17e+00, loss_energy_value:1.191368e-02
# Epoch #  166000/600000    time:75.70
# loss:1.19e-04, loss_ics:1.12e-07, loss_res:5.24e+00, loss_energy_value:1.177262e-02
# Epoch #  167000/600000    time:75.97
# loss:1.37e-04, loss_ics:3.09e-07, loss_res:5.03e+00, loss_energy_value:1.085567e-02
# Epoch #  168000/600000    time:76.05
# loss:1.49e-04, loss_ics:4.15e-07, loss_res:4.90e+00, loss_energy_value:1.017837e-02
# Epoch #  169000/600000    time:75.21
# loss:1.20e-04, loss_ics:1.50e-07, loss_res:5.01e+00, loss_energy_value:1.061647e-02
# Epoch #  170000/600000    time:75.20
# loss:1.32e-04, loss_ics:2.44e-07, loss_res:5.05e+00, loss_energy_value:1.082497e-02
# Epoch #  171000/600000    time:77.54
# loss:1.19e-04, loss_ics:1.22e-07, loss_res:4.96e+00, loss_energy_value:9.926033e-03
# Epoch #  172000/600000    time:74.00
# loss:1.38e-04, loss_ics:3.02e-07, loss_res:4.80e+00, loss_energy_value:8.637309e-03
# Epoch #  173000/600000    time:76.27
# loss:1.77e-04, loss_ics:6.95e-07, loss_res:4.81e+00, loss_energy_value:8.832606e-03
# Epoch #  174000/600000    time:75.34
# loss:1.10e-04, loss_ics:3.86e-08, loss_res:4.79e+00, loss_energy_value:8.855851e-03
# Epoch #  175000/600000    time:75.53
# loss:1.18e-04, loss_ics:1.13e-07, loss_res:4.74e+00, loss_energy_value:8.273422e-03
# Epoch #  176000/600000    time:75.59
# loss:1.23e-04, loss_ics:1.71e-07, loss_res:4.73e+00, loss_energy_value:8.445255e-03
# Epoch #  177000/600000    time:75.59
# loss:1.18e-04, loss_ics:9.10e-08, loss_res:4.71e+00, loss_energy_value:8.718467e-03
# Epoch #  178000/600000    time:73.17
# loss:1.25e-04, loss_ics:1.92e-07, loss_res:4.55e+00, loss_energy_value:7.026925e-03
# Epoch #  179000/600000    time:75.60
# loss:1.24e-04, loss_ics:1.86e-07, loss_res:4.62e+00, loss_energy_value:7.466331e-03
# Epoch #  180000/600000    time:73.03
# loss:1.20e-04, loss_ics:1.28e-07, loss_res:4.59e+00, loss_energy_value:7.220551e-03
# Epoch #  181000/600000    time:77.09
# loss:1.27e-04, loss_ics:1.41e-07, loss_res:4.47e+00, loss_energy_value:6.878823e-03
# Epoch #  182000/600000    time:74.99
# loss:1.12e-04, loss_ics:4.50e-08, loss_res:4.37e+00, loss_energy_value:5.936588e-03
# Epoch #  183000/600000    time:76.13
# loss:1.11e-04, loss_ics:4.26e-08, loss_res:4.37e+00, loss_energy_value:6.310351e-03
# Epoch #  184000/600000    time:76.68
# loss:1.36e-04, loss_ics:2.51e-07, loss_res:4.27e+00, loss_energy_value:5.773400e-03
# Epoch #  185000/600000    time:76.12
# loss:1.27e-04, loss_ics:2.12e-07, loss_res:4.21e+00, loss_energy_value:5.541686e-03
# Epoch #  186000/600000    time:77.17
# loss:1.23e-04, loss_ics:1.59e-07, loss_res:4.17e+00, loss_energy_value:5.331790e-03
# Epoch #  187000/600000    time:75.29
# loss:1.19e-04, loss_ics:1.15e-07, loss_res:4.11e+00, loss_energy_value:5.001488e-03
# Epoch #  188000/600000    time:78.45
# loss:1.48e-04, loss_ics:3.51e-07, loss_res:4.11e+00, loss_energy_value:5.091903e-03
# Epoch #  189000/600000    time:74.92
# loss:1.30e-04, loss_ics:1.31e-07, loss_res:4.06e+00, loss_energy_value:5.002709e-03
# Epoch #  190000/600000    time:73.89
# loss:1.21e-04, loss_ics:1.36e-07, loss_res:4.00e+00, loss_energy_value:4.768559e-03
# Epoch #  191000/600000    time:73.60
# loss:1.22e-04, loss_ics:1.44e-07, loss_res:3.99e+00, loss_energy_value:4.750601e-03
# Epoch #  192000/600000    time:73.93
# loss:1.15e-04, loss_ics:9.67e-08, loss_res:3.93e+00, loss_energy_value:4.622541e-03
# Epoch #  193000/600000    time:75.29
# loss:1.19e-04, loss_ics:1.38e-07, loss_res:3.83e+00, loss_energy_value:4.146472e-03
# Epoch #  194000/600000    time:77.04
# loss:1.18e-04, loss_ics:7.97e-08, loss_res:3.76e+00, loss_energy_value:3.706961e-03
# Epoch #  195000/600000    time:71.24
# loss:1.16e-04, loss_ics:1.05e-07, loss_res:3.70e+00, loss_energy_value:3.530895e-03
# Epoch #  196000/600000    time:78.05
# loss:1.20e-04, loss_ics:1.08e-07, loss_res:3.67e+00, loss_energy_value:3.534308e-03
# Epoch #  197000/600000    time:76.93
# loss:1.18e-04, loss_ics:1.07e-07, loss_res:3.63e+00, loss_energy_value:3.230139e-03
# Epoch #  198000/600000    time:77.79
# loss:1.20e-04, loss_ics:1.48e-07, loss_res:3.57e+00, loss_energy_value:3.216150e-03
# Epoch #  199000/600000    time:74.80
# loss:1.45e-04, loss_ics:3.83e-07, loss_res:3.51e+00, loss_energy_value:2.912004e-03
# Epoch #  200000/600000    time:76.53
# loss:1.21e-04, loss_ics:1.47e-07, loss_res:3.52e+00, loss_energy_value:3.053329e-03
# Epoch #  201000/600000    time:77.59
# loss:1.11e-04, loss_ics:3.31e-08, loss_res:3.41e+00, loss_energy_value:2.656864e-03
# Epoch #  202000/600000    time:73.37
# loss:1.15e-04, loss_ics:9.33e-08, loss_res:3.37e+00, loss_energy_value:2.801380e-03
# Epoch #  203000/600000    time:76.87
# loss:1.21e-04, loss_ics:1.51e-07, loss_res:3.31e+00, loss_energy_value:2.390685e-03
# Epoch #  204000/600000    time:74.88
# loss:1.46e-04, loss_ics:3.92e-07, loss_res:3.23e+00, loss_energy_value:2.088076e-03
# Epoch #  205000/600000    time:77.66
# loss:1.20e-04, loss_ics:1.35e-07, loss_res:3.22e+00, loss_energy_value:2.465796e-03
# Epoch #  206000/600000    time:77.10
# loss:1.21e-04, loss_ics:9.05e-08, loss_res:3.15e+00, loss_energy_value:2.035032e-03
# Epoch #  207000/600000    time:75.93
# loss:1.25e-04, loss_ics:1.86e-07, loss_res:3.12e+00, loss_energy_value:1.909309e-03
# Epoch #  208000/600000    time:74.98
# loss:1.19e-04, loss_ics:1.21e-07, loss_res:3.10e+00, loss_energy_value:1.772077e-03
# Epoch #  209000/600000    time:75.59
# loss:1.18e-04, loss_ics:3.85e-08, loss_res:3.01e+00, loss_energy_value:1.742435e-03
# Epoch #  210000/600000    time:77.27
# loss:1.21e-04, loss_ics:8.53e-08, loss_res:2.99e+00, loss_energy_value:1.637167e-03
# Epoch #  211000/600000    time:74.69
# loss:1.26e-04, loss_ics:5.39e-08, loss_res:2.96e+00, loss_energy_value:1.459631e-03
# Epoch #  212000/600000    time:73.25
# loss:1.26e-04, loss_ics:7.08e-08, loss_res:2.87e+00, loss_energy_value:1.458831e-03
# Epoch #  213000/600000    time:72.39
# loss:1.24e-04, loss_ics:1.80e-07, loss_res:2.85e+00, loss_energy_value:1.370370e-03
# Epoch #  214000/600000    time:74.38
# loss:1.16e-04, loss_ics:1.08e-07, loss_res:2.84e+00, loss_energy_value:1.391253e-03
# Epoch #  215000/600000    time:76.36
# loss:1.29e-04, loss_ics:6.84e-08, loss_res:2.76e+00, loss_energy_value:1.198223e-03
# Epoch #  216000/600000    time:75.92
# loss:1.12e-04, loss_ics:7.48e-08, loss_res:2.75e+00, loss_energy_value:1.323979e-03
# Epoch #  217000/600000    time:73.92
# loss:1.16e-04, loss_ics:1.00e-07, loss_res:2.71e+00, loss_energy_value:1.191332e-03
# Epoch #  218000/600000    time:75.13
# loss:1.16e-04, loss_ics:8.29e-08, loss_res:2.65e+00, loss_energy_value:9.636694e-04
# Epoch #  219000/600000    time:77.92
# loss:1.12e-04, loss_ics:3.76e-08, loss_res:2.63e+00, loss_energy_value:9.552059e-04
# Epoch #  220000/600000    time:75.08
# loss:1.15e-04, loss_ics:8.93e-08, loss_res:2.60e+00, loss_energy_value:8.666198e-04
# Epoch #  221000/600000    time:76.84
# loss:1.35e-04, loss_ics:1.12e-07, loss_res:2.59e+00, loss_energy_value:8.638179e-04
# Epoch #  222000/600000    time:76.23
# loss:1.48e-04, loss_ics:4.20e-07, loss_res:2.57e+00, loss_energy_value:8.646717e-04
# Epoch #  223000/600000    time:75.57
# loss:1.22e-04, loss_ics:1.02e-07, loss_res:2.52e+00, loss_energy_value:7.435164e-04
# Epoch #  224000/600000    time:76.31
# loss:1.22e-04, loss_ics:1.60e-07, loss_res:2.49e+00, loss_energy_value:7.058992e-04
# Epoch #  225000/600000    time:76.11
# loss:1.27e-04, loss_ics:2.08e-07, loss_res:2.52e+00, loss_energy_value:7.900892e-04
# Epoch #  226000/600000    time:73.99
# loss:1.23e-04, loss_ics:1.07e-07, loss_res:2.44e+00, loss_energy_value:5.944741e-04
# Epoch #  227000/600000    time:77.14
# loss:1.28e-04, loss_ics:1.91e-07, loss_res:2.44e+00, loss_energy_value:5.576577e-04
# Epoch #  228000/600000    time:76.16
# loss:1.26e-04, loss_ics:1.25e-07, loss_res:2.42e+00, loss_energy_value:5.342687e-04
# Epoch #  229000/600000    time:74.43
# loss:1.35e-04, loss_ics:2.58e-07, loss_res:2.42e+00, loss_energy_value:4.677339e-04
# Epoch #  230000/600000    time:76.20
# loss:1.21e-04, loss_ics:1.50e-07, loss_res:2.39e+00, loss_energy_value:4.489705e-04
# Epoch #  231000/600000    time:73.79
# loss:1.26e-04, loss_ics:3.29e-08, loss_res:2.37e+00, loss_energy_value:4.110490e-04
# Epoch #  232000/600000    time:78.47
# loss:1.19e-04, loss_ics:3.44e-08, loss_res:2.37e+00, loss_energy_value:4.024261e-04
# Epoch #  233000/600000    time:78.24
# loss:1.25e-04, loss_ics:1.89e-07, loss_res:2.34e+00, loss_energy_value:3.450700e-04
# Epoch #  234000/600000    time:73.82
# loss:1.16e-04, loss_ics:9.10e-08, loss_res:2.34e+00, loss_energy_value:3.578547e-04
# Epoch #  235000/600000    time:75.97
# loss:1.29e-04, loss_ics:1.34e-08, loss_res:2.31e+00, loss_energy_value:2.981943e-04
# Epoch #  236000/600000    time:77.73
# loss:1.38e-04, loss_ics:3.12e-07, loss_res:2.29e+00, loss_energy_value:2.465297e-04
# Epoch #  237000/600000    time:76.00
# loss:1.10e-04, loss_ics:5.24e-08, loss_res:2.30e+00, loss_energy_value:2.601100e-04
# Epoch #  238000/600000    time:73.87
# loss:1.18e-04, loss_ics:1.11e-07, loss_res:2.26e+00, loss_energy_value:1.679089e-04
# Epoch #  239000/600000    time:77.37
# loss:1.17e-04, loss_ics:7.83e-08, loss_res:2.27e+00, loss_energy_value:1.954297e-04
# Epoch #  240000/600000    time:76.76
# loss:1.17e-04, loss_ics:7.20e-08, loss_res:2.24e+00, loss_energy_value:1.890774e-04
# Epoch #  241000/600000    time:77.34
# loss:1.19e-04, loss_ics:7.33e-08, loss_res:2.25e+00, loss_energy_value:1.468596e-04
# Epoch #  242000/600000    time:77.82
# loss:1.17e-04, loss_ics:1.07e-07, loss_res:2.24e+00, loss_energy_value:1.299557e-04
# Epoch #  243000/600000    time:75.93
# loss:1.29e-04, loss_ics:2.15e-07, loss_res:2.21e+00, loss_energy_value:1.115063e-04
# Epoch #  244000/600000    time:74.68
# loss:1.12e-04, loss_ics:2.07e-08, loss_res:2.15e+00, loss_energy_value:8.311611e-05
# Epoch #  245000/600000    time:77.28
# loss:1.24e-04, loss_ics:3.33e-08, loss_res:2.09e+00, loss_energy_value:7.264696e-05
# Epoch #  246000/600000    time:75.57
# loss:1.19e-04, loss_ics:1.12e-08, loss_res:2.03e+00, loss_energy_value:5.009071e-05
# Epoch #  247000/600000    time:73.43
# loss:1.22e-04, loss_ics:1.29e-08, loss_res:1.96e+00, loss_energy_value:3.289747e-05
# Epoch #  248000/600000    time:74.28
# loss:1.23e-04, loss_ics:9.29e-09, loss_res:1.89e+00, loss_energy_value:1.620149e-05
# Epoch #  249000/600000    time:75.21
# loss:1.24e-04, loss_ics:1.99e-08, loss_res:1.85e+00, loss_energy_value:1.481644e-05
# Epoch #  250000/600000    time:76.37
# loss:1.15e-04, loss_ics:7.67e-08, loss_res:1.84e+00, loss_energy_value:9.635473e-06
# Epoch #  251000/600000    time:75.22
# loss:1.19e-04, loss_ics:1.01e-08, loss_res:1.76e+00, loss_energy_value:1.224059e-05
# Epoch #  252000/600000    time:73.81
# loss:1.21e-04, loss_ics:2.47e-08, loss_res:1.67e+00, loss_energy_value:3.667069e-06
# Epoch #  253000/600000    time:71.88
# loss:1.19e-04, loss_ics:9.82e-09, loss_res:1.59e+00, loss_energy_value:2.278000e-06
# Epoch #  254000/600000    time:75.08
# loss:1.19e-04, loss_ics:3.14e-08, loss_res:1.51e+00, loss_energy_value:1.010916e-06
# Epoch #  255000/600000    time:78.45
# loss:1.13e-04, loss_ics:2.42e-08, loss_res:1.43e+00, loss_energy_value:4.853948e-06
# Epoch #  256000/600000    time:76.67
# loss:1.18e-04, loss_ics:2.28e-08, loss_res:1.34e+00, loss_energy_value:1.844224e-06
# Epoch #  257000/600000    time:76.22
# loss:1.22e-04, loss_ics:1.14e-08, loss_res:1.29e+00, loss_energy_value:7.350090e-07
# Epoch #  258000/600000    time:75.60
# loss:1.14e-04, loss_ics:9.05e-08, loss_res:1.23e+00, loss_energy_value:3.620446e-07
# Epoch #  259000/600000    time:76.68
# loss:1.10e-04, loss_ics:2.65e-08, loss_res:1.20e+00, loss_energy_value:6.867946e-07
# Epoch #  260000/600000    time:77.99
# loss:1.21e-04, loss_ics:8.55e-08, loss_res:1.19e+00, loss_energy_value:1.528812e-06
# Epoch #  261000/600000    time:76.84
# loss:1.23e-04, loss_ics:1.01e-07, loss_res:1.15e+00, loss_energy_value:3.781262e-06
# Epoch #  262000/600000    time:78.47
# loss:1.20e-04, loss_ics:8.19e-09, loss_res:1.07e+00, loss_energy_value:3.108297e-07
# Epoch #  263000/600000    time:75.56
# loss:1.19e-04, loss_ics:1.32e-08, loss_res:9.95e-01, loss_energy_value:2.833725e-07
# Epoch #  264000/600000    time:74.29
# loss:1.20e-04, loss_ics:2.18e-08, loss_res:9.26e-01, loss_energy_value:1.945541e-07
# Epoch #  265000/600000    time:75.94
# loss:1.19e-04, loss_ics:1.14e-08, loss_res:8.60e-01, loss_energy_value:2.815468e-07
# Epoch #  266000/600000    time:77.05
# loss:1.22e-04, loss_ics:3.01e-08, loss_res:8.00e-01, loss_energy_value:3.138867e-07
# Epoch #  267000/600000    time:76.28
# loss:1.09e-04, loss_ics:1.75e-08, loss_res:7.47e-01, loss_energy_value:1.306995e-07
# Epoch #  268000/600000    time:77.67
# loss:1.14e-04, loss_ics:2.66e-08, loss_res:7.12e-01, loss_energy_value:3.266214e-06
# Epoch #  269000/600000    time:76.08
# loss:1.23e-04, loss_ics:2.86e-08, loss_res:7.01e-01, loss_energy_value:1.742356e-06
# Epoch #  270000/600000    time:74.51
# loss:1.18e-04, loss_ics:7.27e-08, loss_res:6.91e-01, loss_energy_value:2.875417e-07
# Epoch #  271000/600000    time:70.77
# loss:1.19e-04, loss_ics:9.45e-09, loss_res:6.43e-01, loss_energy_value:2.922225e-06
# Epoch #  272000/600000    time:73.22
# loss:1.19e-04, loss_ics:8.81e-09, loss_res:5.98e-01, loss_energy_value:2.693131e-07
# Epoch #  273000/600000    time:74.44
# loss:1.19e-04, loss_ics:1.65e-08, loss_res:5.58e-01, loss_energy_value:5.526243e-07
# Epoch #  274000/600000    time:75.96
# loss:1.18e-04, loss_ics:8.20e-09, loss_res:5.22e-01, loss_energy_value:2.066923e-07
# Epoch #  275000/600000    time:74.12
# loss:1.19e-04, loss_ics:1.79e-08, loss_res:4.89e-01, loss_energy_value:2.537494e-06
# Epoch #  276000/600000    time:73.95
# loss:1.20e-04, loss_ics:2.54e-08, loss_res:4.57e-01, loss_energy_value:1.623871e-06
# Epoch #  277000/600000    time:75.54
# loss:1.17e-04, loss_ics:1.70e-08, loss_res:4.28e-01, loss_energy_value:2.355166e-06
# Epoch #  278000/600000    time:74.87
# loss:1.17e-04, loss_ics:1.50e-08, loss_res:4.01e-01, loss_energy_value:2.531903e-06
# Epoch #  279000/600000    time:77.20
# loss:1.15e-04, loss_ics:2.30e-08, loss_res:3.74e-01, loss_energy_value:2.780579e-06
# Epoch #  280000/600000    time:75.04
# loss:1.21e-04, loss_ics:8.03e-09, loss_res:3.50e-01, loss_energy_value:3.221235e-07
# Epoch #  281000/600000    time:77.01
# loss:1.19e-04, loss_ics:2.27e-08, loss_res:3.25e-01, loss_energy_value:2.422736e-06
# Epoch #  282000/600000    time:76.99
# loss:1.18e-04, loss_ics:7.32e-09, loss_res:3.02e-01, loss_energy_value:1.803942e-07
# Epoch #  283000/600000    time:74.77
# loss:1.17e-04, loss_ics:1.04e-08, loss_res:2.82e-01, loss_energy_value:2.197004e-06
# Epoch #  284000/600000    time:73.63
# loss:1.17e-04, loss_ics:8.88e-09, loss_res:2.63e-01, loss_energy_value:2.078696e-07
# Epoch #  285000/600000    time:78.61
# loss:1.19e-04, loss_ics:2.31e-08, loss_res:2.45e-01, loss_energy_value:2.315441e-06
# Epoch #  286000/600000    time:77.26
# loss:1.18e-04, loss_ics:1.67e-08, loss_res:2.28e-01, loss_energy_value:2.202349e-06
# Epoch #  287000/600000    time:77.87
# loss:1.16e-04, loss_ics:6.92e-09, loss_res:2.12e-01, loss_energy_value:1.132288e-06
# Epoch #  288000/600000    time:75.76
# loss:1.17e-04, loss_ics:5.87e-09, loss_res:1.98e-01, loss_energy_value:1.264008e-07
# Epoch #  289000/600000    time:75.45
# loss:1.18e-04, loss_ics:2.02e-08, loss_res:1.84e-01, loss_energy_value:1.538792e-07
# Epoch #  290000/600000    time:72.95
# loss:1.20e-04, loss_ics:1.01e-08, loss_res:1.72e-01, loss_energy_value:1.749648e-07
# Epoch #  291000/600000    time:74.90
# loss:1.18e-04, loss_ics:8.29e-09, loss_res:1.57e-01, loss_energy_value:1.713373e-07
# Epoch #  292000/600000    time:76.34
# loss:1.19e-04, loss_ics:1.56e-08, loss_res:1.45e-01, loss_energy_value:2.660969e-07
# Epoch #  293000/600000    time:74.52
# loss:1.18e-04, loss_ics:1.84e-08, loss_res:1.34e-01, loss_energy_value:1.966434e-06
# Epoch #  294000/600000    time:76.45
# loss:1.17e-04, loss_ics:1.10e-08, loss_res:1.24e-01, loss_energy_value:2.112996e-06
# Epoch #  295000/600000    time:74.77
# loss:1.17e-04, loss_ics:9.31e-09, loss_res:1.14e-01, loss_energy_value:1.931425e-07
# Epoch #  296000/600000    time:75.59
# loss:1.20e-04, loss_ics:3.10e-08, loss_res:1.06e-01, loss_energy_value:1.866064e-06
# Epoch #  297000/600000    time:75.46
# loss:1.17e-04, loss_ics:9.38e-09, loss_res:9.76e-02, loss_energy_value:3.385885e-07
# Epoch #  298000/600000    time:76.45
# loss:1.18e-04, loss_ics:1.66e-08, loss_res:8.96e-02, loss_energy_value:1.775190e-07
# Epoch #  299000/600000    time:75.68
# loss:1.17e-04, loss_ics:8.54e-09, loss_res:8.27e-02, loss_energy_value:2.163782e-07
# Epoch #  300000/600000    time:77.79
# loss:1.19e-04, loss_ics:1.12e-08, loss_res:7.59e-02, loss_energy_value:1.999261e-06
# Epoch #  301000/600000    time:74.21
# loss:1.18e-04, loss_ics:5.66e-09, loss_res:6.83e-02, loss_energy_value:3.131508e-07
# Epoch #  302000/600000    time:75.74
# loss:1.18e-04, loss_ics:1.33e-08, loss_res:6.22e-02, loss_energy_value:4.039066e-07
# Epoch #  303000/600000    time:78.31
# loss:1.17e-04, loss_ics:1.01e-08, loss_res:5.67e-02, loss_energy_value:3.089803e-07
# Epoch #  304000/600000    time:74.80
# loss:1.17e-04, loss_ics:1.13e-08, loss_res:5.13e-02, loss_energy_value:2.187794e-06
# Epoch #  305000/600000    time:77.32
# loss:1.17e-04, loss_ics:1.34e-08, loss_res:4.66e-02, loss_energy_value:2.210110e-06
# Epoch #  306000/600000    time:76.67
# loss:1.18e-04, loss_ics:1.97e-08, loss_res:4.22e-02, loss_energy_value:2.138681e-06
# Epoch #  307000/600000    time:76.62
# loss:1.17e-04, loss_ics:1.10e-08, loss_res:3.83e-02, loss_energy_value:2.334717e-06
# Epoch #  308000/600000    time:77.35
# loss:1.18e-04, loss_ics:2.58e-08, loss_res:3.47e-02, loss_energy_value:5.517069e-07
# Epoch #  309000/600000    time:74.97
# loss:1.16e-04, loss_ics:1.03e-08, loss_res:3.11e-02, loss_energy_value:2.349658e-06
# Epoch #  310000/600000    time:76.62
# loss:1.18e-04, loss_ics:9.50e-09, loss_res:2.81e-02, loss_energy_value:2.108818e-06
# Epoch #  311000/600000    time:76.33
# loss:1.17e-04, loss_ics:1.29e-08, loss_res:2.45e-02, loss_energy_value:2.434570e-06
# Epoch #  312000/600000    time:75.90
# loss:1.17e-04, loss_ics:1.37e-08, loss_res:2.19e-02, loss_energy_value:2.415265e-06
# Epoch #  313000/600000    time:73.52
# loss:1.17e-04, loss_ics:7.75e-09, loss_res:1.94e-02, loss_energy_value:4.264149e-07
# Epoch #  314000/600000    time:77.65
# loss:1.19e-04, loss_ics:2.64e-08, loss_res:1.72e-02, loss_energy_value:6.360819e-07
# Epoch #  315000/600000    time:74.48
# loss:1.16e-04, loss_ics:1.08e-08, loss_res:1.51e-02, loss_energy_value:2.207366e-06
# Epoch #  316000/600000    time:77.83
# loss:1.17e-04, loss_ics:1.10e-08, loss_res:1.33e-02, loss_energy_value:2.267789e-06
# Epoch #  317000/600000    time:74.81
# loss:1.17e-04, loss_ics:2.04e-08, loss_res:1.17e-02, loss_energy_value:2.625101e-06
# Epoch #  318000/600000    time:70.81
# loss:1.16e-04, loss_ics:9.32e-09, loss_res:1.02e-02, loss_energy_value:2.406328e-06
# Epoch #  319000/600000    time:73.22
# loss:1.17e-04, loss_ics:1.36e-08, loss_res:8.95e-03, loss_energy_value:1.181974e-06
# Epoch #  320000/600000    time:75.84
# loss:1.19e-04, loss_ics:1.56e-08, loss_res:7.76e-03, loss_energy_value:2.281999e-06
# Epoch #  321000/600000    time:76.35
# loss:1.18e-04, loss_ics:1.76e-08, loss_res:6.56e-03, loss_energy_value:9.393842e-07
# Epoch #  322000/600000    time:71.61
# loss:1.17e-04, loss_ics:1.27e-08, loss_res:5.60e-03, loss_energy_value:2.476120e-06
# Epoch #  323000/600000    time:75.89
# loss:1.17e-04, loss_ics:8.80e-09, loss_res:4.80e-03, loss_energy_value:1.287425e-06
# Epoch #  324000/600000    time:75.86
# loss:1.17e-04, loss_ics:1.03e-08, loss_res:4.06e-03, loss_energy_value:2.425370e-06
# Epoch #  325000/600000    time:76.51
# loss:1.16e-04, loss_ics:7.24e-09, loss_res:3.48e-03, loss_energy_value:7.033989e-07
# Epoch #  326000/600000    time:75.10
# loss:1.17e-04, loss_ics:1.50e-08, loss_res:2.93e-03, loss_energy_value:2.556212e-06
# Epoch #  327000/600000    time:75.25
# loss:1.16e-04, loss_ics:1.51e-08, loss_res:2.48e-03, loss_energy_value:2.657154e-06
# Epoch #  328000/600000    time:77.14
# loss:1.18e-04, loss_ics:1.95e-08, loss_res:2.11e-03, loss_energy_value:4.881212e-07
# Epoch #  329000/600000    time:76.73
# loss:1.18e-04, loss_ics:2.43e-08, loss_res:1.75e-03, loss_energy_value:2.543507e-06
# Epoch #  330000/600000    time:73.67
# loss:1.18e-04, loss_ics:8.01e-09, loss_res:1.47e-03, loss_energy_value:2.238311e-06
# Epoch #  331000/600000    time:69.47
# loss:1.17e-04, loss_ics:1.14e-08, loss_res:1.20e-03, loss_energy_value:2.588911e-06
# Epoch #  332000/600000    time:71.91
# loss:1.20e-04, loss_ics:3.37e-08, loss_res:9.97e-04, loss_energy_value:2.296925e-06
# Epoch #  333000/600000    time:70.10
# loss:1.16e-04, loss_ics:7.98e-09, loss_res:8.47e-04, loss_energy_value:2.051470e-06
# Epoch #  334000/600000    time:75.32
# loss:1.16e-04, loss_ics:1.28e-08, loss_res:7.20e-04, loss_energy_value:5.508690e-07
# Epoch #  335000/600000    time:76.68
# loss:1.15e-04, loss_ics:1.17e-08, loss_res:6.15e-04, loss_energy_value:5.335730e-07
# Epoch #  336000/600000    time:77.11
# loss:1.16e-04, loss_ics:3.50e-08, loss_res:5.24e-04, loss_energy_value:2.722252e-06
# Epoch #  337000/600000    time:76.19
# loss:1.13e-04, loss_ics:1.72e-08, loss_res:4.61e-04, loss_energy_value:2.452285e-06
# Epoch #  338000/600000    time:75.67
# loss:1.12e-04, loss_ics:1.85e-08, loss_res:4.14e-04, loss_energy_value:4.296511e-07
# Epoch #  339000/600000    time:77.16
# loss:1.08e-04, loss_ics:1.14e-08, loss_res:3.73e-04, loss_energy_value:2.115390e-06
# Epoch #  340000/600000    time:75.61
# loss:1.07e-04, loss_ics:1.19e-08, loss_res:3.31e-04, loss_energy_value:4.399391e-07
# Epoch #  341000/600000    time:76.93
# loss:1.04e-04, loss_ics:1.57e-08, loss_res:3.00e-04, loss_energy_value:1.915643e-06
# Epoch #  342000/600000    time:77.12
# loss:1.02e-04, loss_ics:1.46e-08, loss_res:2.76e-04, loss_energy_value:7.250925e-07
# Epoch #  343000/600000    time:74.29
# loss:9.98e-05, loss_ics:8.46e-09, loss_res:2.64e-04, loss_energy_value:2.919653e-07
# Epoch #  344000/600000    time:71.47
# loss:9.83e-05, loss_ics:1.23e-08, loss_res:2.49e-04, loss_energy_value:2.245731e-07
# Epoch #  345000/600000    time:77.57
# loss:9.52e-05, loss_ics:5.95e-09, loss_res:2.27e-04, loss_energy_value:3.407328e-07
# Epoch #  346000/600000    time:75.88
# loss:9.46e-05, loss_ics:1.71e-08, loss_res:2.19e-04, loss_energy_value:1.609084e-06
# Epoch #  347000/600000    time:73.55
# loss:9.26e-05, loss_ics:8.92e-09, loss_res:2.11e-04, loss_energy_value:1.795818e-07
# Epoch #  348000/600000    time:76.49
# loss:9.04e-05, loss_ics:9.83e-09, loss_res:1.97e-04, loss_energy_value:1.328262e-06
# Epoch #  349000/600000    time:73.32
# loss:8.92e-05, loss_ics:1.01e-08, loss_res:1.91e-04, loss_energy_value:1.327505e-06
# Epoch #  350000/600000    time:76.58
# loss:8.66e-05, loss_ics:7.61e-09, loss_res:1.76e-04, loss_energy_value:9.228521e-07
# Epoch #  351000/600000    time:76.53
# loss:8.55e-05, loss_ics:6.06e-09, loss_res:1.73e-04, loss_energy_value:1.643843e-07
# Epoch #  352000/600000    time:75.18
# loss:8.43e-05, loss_ics:8.06e-09, loss_res:1.67e-04, loss_energy_value:1.051357e-06
# Epoch #  353000/600000    time:76.71
# loss:8.24e-05, loss_ics:6.51e-09, loss_res:1.58e-04, loss_energy_value:1.507678e-07
# Epoch #  354000/600000    time:74.33
# loss:8.22e-05, loss_ics:1.16e-08, loss_res:1.56e-04, loss_energy_value:1.081724e-06
# Epoch #  355000/600000    time:74.57
# loss:8.07e-05, loss_ics:9.75e-09, loss_res:1.51e-04, loss_energy_value:8.147742e-08
# Epoch #  356000/600000    time:74.29
# loss:7.93e-05, loss_ics:5.93e-09, loss_res:1.47e-04, loss_energy_value:1.415331e-07
# Epoch #  357000/600000    time:76.68
# loss:7.91e-05, loss_ics:8.23e-09, loss_res:1.45e-04, loss_energy_value:1.037163e-07
# Epoch #  358000/600000    time:76.78
# loss:7.78e-05, loss_ics:5.91e-09, loss_res:1.41e-04, loss_energy_value:1.179872e-07
# Epoch #  359000/600000    time:76.68
# loss:7.62e-05, loss_ics:8.57e-09, loss_res:1.34e-04, loss_energy_value:7.941942e-07
# Epoch #  360000/600000    time:75.14
# loss:7.32e-05, loss_ics:5.01e-09, loss_res:1.25e-04, loss_energy_value:1.311106e-07
# Epoch #  361000/600000    time:77.89
# loss:7.28e-05, loss_ics:6.28e-09, loss_res:1.23e-04, loss_energy_value:7.611983e-08
# Epoch #  362000/600000    time:74.90
# loss:7.21e-05, loss_ics:9.35e-09, loss_res:1.20e-04, loss_energy_value:7.285814e-07
# Epoch #  363000/600000    time:77.78
# loss:7.11e-05, loss_ics:5.56e-09, loss_res:1.18e-04, loss_energy_value:6.821530e-08
# Epoch #  364000/600000    time:74.83
# loss:7.06e-05, loss_ics:1.09e-08, loss_res:1.15e-04, loss_energy_value:7.436075e-07
# Epoch #  365000/600000    time:76.00
# loss:6.97e-05, loss_ics:6.81e-09, loss_res:1.14e-04, loss_energy_value:6.281107e-07
# Epoch #  366000/600000    time:77.49
# loss:6.86e-05, loss_ics:9.62e-09, loss_res:1.10e-04, loss_energy_value:4.231957e-08
# Epoch #  367000/600000    time:76.13
# loss:6.78e-05, loss_ics:8.13e-09, loss_res:1.08e-04, loss_energy_value:7.038668e-08
# Epoch #  368000/600000    time:77.76
# loss:6.72e-05, loss_ics:1.20e-08, loss_res:1.05e-04, loss_energy_value:6.971934e-07
# Epoch #  369000/600000    time:74.46
# loss:6.69e-05, loss_ics:5.58e-09, loss_res:1.06e-04, loss_energy_value:7.064438e-08
# Epoch #  370000/600000    time:75.13
# loss:6.27e-05, loss_ics:6.34e-09, loss_res:9.47e-05, loss_energy_value:8.098514e-08
# Epoch #  371000/600000    time:77.47
# loss:6.38e-05, loss_ics:6.31e-09, loss_res:9.79e-05, loss_energy_value:5.319675e-07
# Epoch #  372000/600000    time:75.63
# loss:6.33e-05, loss_ics:5.92e-09, loss_res:9.67e-05, loss_energy_value:4.946700e-07
# Epoch #  373000/600000    time:74.62
# loss:6.34e-05, loss_ics:1.19e-08, loss_res:9.53e-05, loss_energy_value:5.830249e-07
# Epoch #  374000/600000    time:75.70
# loss:6.22e-05, loss_ics:8.47e-09, loss_res:9.34e-05, loss_energy_value:5.420952e-07
# Epoch #  375000/600000    time:73.11
# loss:6.16e-05, loss_ics:6.76e-09, loss_res:9.22e-05, loss_energy_value:2.783359e-08
# Epoch #  376000/600000    time:74.25
# loss:6.08e-05, loss_ics:5.52e-09, loss_res:9.07e-05, loss_energy_value:3.057223e-08
# Epoch #  377000/600000    time:74.14
# loss:6.10e-05, loss_ics:8.31e-09, loss_res:9.05e-05, loss_energy_value:2.867458e-08
# Epoch #  378000/600000    time:73.12
# loss:6.03e-05, loss_ics:5.13e-09, loss_res:8.96e-05, loss_energy_value:4.849998e-08
# Epoch #  379000/600000    time:75.46
# loss:5.93e-05, loss_ics:5.77e-09, loss_res:8.70e-05, loss_energy_value:2.537160e-08
# Epoch #  380000/600000    time:73.62
# loss:5.68e-05, loss_ics:5.57e-09, loss_res:8.14e-05, loss_energy_value:3.609491e-07
# Epoch #  381000/600000    time:72.89
# loss:5.77e-05, loss_ics:5.89e-09, loss_res:8.33e-05, loss_energy_value:3.928397e-07
# Epoch #  382000/600000    time:74.12
# loss:5.64e-05, loss_ics:5.15e-09, loss_res:8.06e-05, loss_energy_value:2.861313e-08
# Epoch #  383000/600000    time:74.92
# loss:5.47e-05, loss_ics:5.49e-09, loss_res:7.69e-05, loss_energy_value:4.548411e-08
# Epoch #  384000/600000    time:73.03
# loss:5.57e-05, loss_ics:6.68e-09, loss_res:7.87e-05, loss_energy_value:3.786222e-07
# Epoch #  385000/600000    time:71.61
# loss:5.51e-05, loss_ics:5.41e-09, loss_res:7.79e-05, loss_energy_value:2.442663e-08
# Epoch #  386000/600000    time:74.41
# loss:5.38e-05, loss_ics:9.16e-09, loss_res:7.43e-05, loss_energy_value:2.287303e-07
# Epoch #  387000/600000    time:72.62
# loss:5.42e-05, loss_ics:5.04e-09, loss_res:7.60e-05, loss_energy_value:2.198556e-08
# Epoch #  388000/600000    time:75.97
# loss:5.45e-05, loss_ics:5.96e-09, loss_res:7.64e-05, loss_energy_value:2.298338e-08
# Epoch #  389000/600000    time:73.87
# loss:5.36e-05, loss_ics:6.72e-09, loss_res:7.45e-05, loss_energy_value:3.650608e-07
# Epoch #  390000/600000    time:68.79
# loss:5.20e-05, loss_ics:1.09e-08, loss_res:7.03e-05, loss_energy_value:1.208941e-08
# Epoch #  391000/600000    time:73.32
# loss:5.06e-05, loss_ics:7.02e-09, loss_res:6.83e-05, loss_energy_value:2.578254e-07
# Epoch #  392000/600000    time:73.94
# loss:5.26e-05, loss_ics:5.88e-09, loss_res:7.26e-05, loss_energy_value:1.528553e-08
# Epoch #  393000/600000    time:73.36
# loss:5.05e-05, loss_ics:5.20e-09, loss_res:6.86e-05, loss_energy_value:1.794287e-08
# Epoch #  394000/600000    time:72.96
# loss:5.02e-05, loss_ics:6.31e-09, loss_res:6.77e-05, loss_energy_value:1.387068e-08
# Epoch #  395000/600000    time:74.18
# loss:4.75e-05, loss_ics:4.72e-09, loss_res:6.29e-05, loss_energy_value:1.170570e-07
# Epoch #  396000/600000    time:75.19
# loss:4.99e-05, loss_ics:5.84e-09, loss_res:6.73e-05, loss_energy_value:1.355207e-08
# Epoch #  397000/600000    time:72.09
# ...
# Epoch #  468000/600000    time:71.91
# loss:2.84e-05, loss_ics:3.85e-09, loss_res:3.27e-05, loss_energy_value:1.388909e-08
# Epoch #  469000/600000    time:73.21
# loss:2.85e-05, loss_ics:3.53e-09, loss_res:3.29e-05, loss_energy_value:7.529073e-09
# Epoch #  470000/600000    time:70.54
# loss:2.81e-05, loss_ics:3.45e-09, loss_res:3.24e-05, loss_energy_value:9.282949e-09
# Epoch #  471000/600000    time:71.74
# loss:2.84e-05, loss_ics:3.92e-09, loss_res:3.28e-05, loss_energy_value:5.854642e-08
# Epoch #  472000/600000    time:70.94
# loss:2.83e-05, loss_ics:3.51e-09, loss_res:3.27e-05, loss_energy_value:5.227070e-08
# Epoch #  473000/600000    time:71.32
# loss:2.77e-05, loss_ics:3.94e-09, loss_res:3.18e-05, loss_energy_value:4.216716e-08
# Epoch #  474000/600000    time:74.47
# loss:3.01e-05, loss_ics:4.23e-09, loss_res:3.50e-05, loss_energy_value:7.744199e-08
# Epoch #  475000/600000    time:69.25
# loss:2.84e-05, loss_ics:3.84e-09, loss_res:3.28e-05, loss_energy_value:6.035346e-08
# Epoch #  476000/600000    time:73.72
# loss:2.78e-05, loss_ics:3.45e-09, loss_res:3.19e-05, loss_energy_value:4.777303e-08
# Epoch #  477000/600000    time:68.20
# loss:2.78e-05, loss_ics:3.90e-09, loss_res:3.20e-05, loss_energy_value:5.818800e-08
# Epoch #  478000/600000    time:70.17
# loss:2.75e-05, loss_ics:3.61e-09, loss_res:3.16e-05, loss_energy_value:5.101597e-08
# Epoch #  479000/600000    time:72.82
# loss:2.69e-05, loss_ics:3.43e-09, loss_res:3.07e-05, loss_energy_value:4.279943e-08
# Epoch #  480000/600000    time:73.51
# loss:2.65e-05, loss_ics:3.57e-09, loss_res:3.02e-05, loss_energy_value:4.104227e-08
# Epoch #  481000/600000    time:71.90
# loss:2.72e-05, loss_ics:3.36e-09, loss_res:3.12e-05, loss_energy_value:5.737935e-09
# Epoch #  482000/600000    time:72.61
# loss:2.70e-05, loss_ics:3.47e-09, loss_res:3.09e-05, loss_energy_value:3.576259e-08
# Epoch #  483000/600000    time:72.61
# loss:2.70e-05, loss_ics:3.53e-09, loss_res:3.09e-05, loss_energy_value:4.746301e-09
# Epoch #  484000/600000    time:72.17
# loss:2.60e-05, loss_ics:3.35e-09, loss_res:2.95e-05, loss_energy_value:3.510575e-08
# Epoch #  485000/600000    time:73.70
# loss:2.57e-05, loss_ics:3.30e-09, loss_res:2.92e-05, loss_energy_value:1.215835e-08
# Epoch #  486000/600000    time:71.69
# loss:2.65e-05, loss_ics:3.44e-09, loss_res:3.02e-05, loss_energy_value:4.421090e-08
# Epoch #  487000/600000    time:73.50
# loss:2.61e-05, loss_ics:3.59e-09, loss_res:2.97e-05, loss_energy_value:4.053799e-08
# Epoch #  488000/600000    time:70.31
# loss:2.70e-05, loss_ics:3.49e-09, loss_res:3.09e-05, loss_energy_value:5.663805e-09
# Epoch #  489000/600000    time:67.65
# loss:2.53e-05, loss_ics:3.60e-09, loss_res:2.87e-05, loss_energy_value:7.743060e-09
# Epoch #  490000/600000    time:74.71
# loss:2.57e-05, loss_ics:3.27e-09, loss_res:2.92e-05, loss_energy_value:6.211771e-09
# Epoch #  491000/600000    time:69.62
# loss:2.69e-05, loss_ics:3.60e-09, loss_res:3.07e-05, loss_energy_value:4.198892e-08
# Epoch #  492000/600000    time:74.03
# loss:2.47e-05, loss_ics:3.18e-09, loss_res:2.78e-05, loss_energy_value:1.528311e-08
# Epoch #  493000/600000    time:70.50
# loss:2.56e-05, loss_ics:3.37e-09, loss_res:2.90e-05, loss_energy_value:4.356217e-09
# Epoch #  494000/600000    time:72.56
# loss:2.72e-05, loss_ics:4.01e-09, loss_res:3.11e-05, loss_energy_value:7.175757e-08
# Epoch #  495000/600000    time:71.94
# loss:2.48e-05, loss_ics:3.23e-09, loss_res:2.80e-05, loss_energy_value:3.069566e-08
# Epoch #  496000/600000    time:69.18
# loss:2.57e-05, loss_ics:3.52e-09, loss_res:2.91e-05, loss_energy_value:4.311403e-08
# Epoch #  497000/600000    time:71.55
# loss:2.42e-05, loss_ics:3.17e-09, loss_res:2.72e-05, loss_energy_value:2.096295e-08
# Epoch #  498000/600000    time:68.13
# loss:2.48e-05, loss_ics:3.21e-09, loss_res:2.81e-05, loss_energy_value:6.489135e-09
# Epoch #  499000/600000    time:72.73
# loss:2.41e-05, loss_ics:3.15e-09, loss_res:2.71e-05, loss_energy_value:1.785149e-08
# Epoch #  500000/600000    time:70.64
# loss:2.40e-05, loss_ics:3.15e-09, loss_res:2.69e-05, loss_energy_value:1.112279e-08
# Epoch #  501000/600000    time:74.69
# loss:2.63e-05, loss_ics:3.72e-09, loss_res:2.99e-05, loss_energy_value:6.207171e-08
# Epoch #  502000/600000    time:74.55
# loss:2.45e-05, loss_ics:3.34e-09, loss_res:2.76e-05, loss_energy_value:3.237347e-08
# Epoch #  503000/600000    time:67.58
# loss:2.37e-05, loss_ics:3.10e-09, loss_res:2.65e-05, loss_energy_value:1.005859e-08
# Epoch #  504000/600000    time:75.31
# loss:2.48e-05, loss_ics:3.68e-09, loss_res:2.80e-05, loss_energy_value:3.093533e-09
# Epoch #  505000/600000    time:72.04
# loss:2.34e-05, loss_ics:3.11e-09, loss_res:2.62e-05, loss_energy_value:1.758339e-08
# Epoch #  506000/600000    time:69.59
# loss:2.55e-05, loss_ics:3.41e-09, loss_res:2.90e-05, loss_energy_value:4.644819e-09
# Epoch #  507000/600000    time:73.20
# loss:2.38e-05, loss_ics:3.29e-09, loss_res:2.67e-05, loss_energy_value:6.196681e-09
# Epoch #  508000/600000    time:73.28
# loss:2.36e-05, loss_ics:3.34e-09, loss_res:2.64e-05, loss_energy_value:4.508908e-09
# Epoch #  509000/600000    time:74.71
# loss:2.31e-05, loss_ics:3.10e-09, loss_res:2.57e-05, loss_energy_value:1.428063e-08
# Epoch #  510000/600000    time:67.20
# loss:2.36e-05, loss_ics:3.31e-09, loss_res:2.64e-05, loss_energy_value:3.412903e-08
# Epoch #  511000/600000    time:71.88
# loss:2.32e-05, loss_ics:3.07e-09, loss_res:2.60e-05, loss_energy_value:6.202672e-09
# Epoch #  512000/600000    time:71.12
# loss:2.31e-05, loss_ics:3.13e-09, loss_res:2.58e-05, loss_energy_value:7.525471e-09
# Epoch #  513000/600000    time:65.76
# loss:2.29e-05, loss_ics:3.05e-09, loss_res:2.55e-05, loss_energy_value:2.150336e-08
# Epoch #  514000/600000    time:71.75
# loss:2.37e-05, loss_ics:3.10e-09, loss_res:2.66e-05, loss_energy_value:4.097519e-09
# Epoch #  515000/600000    time:73.12
# loss:2.26e-05, loss_ics:2.99e-09, loss_res:2.51e-05, loss_energy_value:9.387978e-09
# Epoch #  516000/600000    time:71.19
# loss:2.26e-05, loss_ics:2.98e-09, loss_res:2.52e-05, loss_energy_value:7.568057e-09
# Epoch #  517000/600000    time:68.04
# loss:2.40e-05, loss_ics:3.12e-09, loss_res:2.70e-05, loss_energy_value:4.259520e-09
# Epoch #  518000/600000    time:73.75
# loss:2.29e-05, loss_ics:3.06e-09, loss_res:2.56e-05, loss_energy_value:6.222161e-09
# Epoch #  519000/600000    time:71.78
# loss:2.29e-05, loss_ics:3.28e-09, loss_res:2.55e-05, loss_energy_value:1.928637e-08
# Epoch #  520000/600000    time:71.95
# loss:2.22e-05, loss_ics:2.94e-09, loss_res:2.46e-05, loss_energy_value:9.788988e-09
# Epoch #  521000/600000    time:73.81
# loss:2.20e-05, loss_ics:2.95e-09, loss_res:2.45e-05, loss_energy_value:1.405308e-08
# Epoch #  522000/600000    time:72.53
# loss:2.24e-05, loss_ics:2.97e-09, loss_res:2.50e-05, loss_energy_value:5.715113e-09
# Epoch #  523000/600000    time:72.84
# loss:2.23e-05, loss_ics:2.94e-09, loss_res:2.48e-05, loss_energy_value:5.801286e-09
# Epoch #  524000/600000    time:75.55
# loss:2.26e-05, loss_ics:3.11e-09, loss_res:2.52e-05, loss_energy_value:4.091607e-09
# Epoch #  525000/600000    time:72.55
# loss:2.20e-05, loss_ics:2.97e-09, loss_res:2.44e-05, loss_energy_value:1.942614e-08
# Epoch #  526000/600000    time:72.91
# loss:2.33e-05, loss_ics:3.08e-09, loss_res:2.61e-05, loss_energy_value:3.864600e-09
# Epoch #  527000/600000    time:69.46
# loss:2.25e-05, loss_ics:3.06e-09, loss_res:2.51e-05, loss_energy_value:3.025623e-08
# Epoch #  528000/600000    time:72.34
# loss:2.19e-05, loss_ics:2.92e-09, loss_res:2.43e-05, loss_energy_value:4.955090e-09
# Epoch #  529000/600000    time:70.42
# loss:2.25e-05, loss_ics:3.58e-09, loss_res:2.50e-05, loss_energy_value:3.575659e-08
# Epoch #  530000/600000    time:63.58
# loss:2.19e-05, loss_ics:3.03e-09, loss_res:2.43e-05, loss_energy_value:5.168654e-09
# Epoch #  531000/600000    time:73.14
# loss:2.13e-05, loss_ics:2.87e-09, loss_res:2.35e-05, loss_energy_value:8.763412e-09
# Epoch #  532000/600000    time:72.94
# loss:2.12e-05, loss_ics:2.89e-09, loss_res:2.34e-05, loss_energy_value:1.172684e-08
# Epoch #  533000/600000    time:71.80
# loss:2.12e-05, loss_ics:2.91e-09, loss_res:2.33e-05, loss_energy_value:1.115485e-08
# Epoch #  534000/600000    time:68.12
# loss:2.17e-05, loss_ics:2.96e-09, loss_res:2.41e-05, loss_energy_value:3.823969e-09
# Epoch #  535000/600000    time:67.20
# loss:2.10e-05, loss_ics:2.88e-09, loss_res:2.32e-05, loss_energy_value:8.521947e-09
# Epoch #  536000/600000    time:69.16
# loss:2.09e-05, loss_ics:2.84e-09, loss_res:2.31e-05, loss_energy_value:1.258248e-08
# Epoch #  537000/600000    time:73.47
# loss:2.25e-05, loss_ics:3.02e-09, loss_res:2.50e-05, loss_energy_value:3.057850e-09
# Epoch #  538000/600000    time:71.29
# loss:2.14e-05, loss_ics:2.83e-09, loss_res:2.36e-05, loss_energy_value:4.431470e-09
# Epoch #  539000/600000    time:75.16
# loss:2.31e-05, loss_ics:3.50e-09, loss_res:2.58e-05, loss_energy_value:4.813325e-09
# Epoch #  540000/600000    time:72.63
# loss:2.08e-05, loss_ics:2.81e-09, loss_res:2.29e-05, loss_energy_value:7.311413e-09
# Epoch #  541000/600000    time:74.23
# loss:2.06e-05, loss_ics:2.81e-09, loss_res:2.27e-05, loss_energy_value:1.024015e-08
# Epoch #  542000/600000    time:68.56
# loss:2.22e-05, loss_ics:3.14e-09, loss_res:2.46e-05, loss_energy_value:3.695651e-08
# Epoch #  543000/600000    time:65.19
# loss:2.04e-05, loss_ics:2.78e-09, loss_res:2.25e-05, loss_energy_value:8.216050e-09
# Epoch #  544000/600000    time:72.62
# loss:2.09e-05, loss_ics:3.01e-09, loss_res:2.30e-05, loss_energy_value:2.017412e-08
# Epoch #  545000/600000    time:70.01
# loss:2.08e-05, loss_ics:2.88e-09, loss_res:2.29e-05, loss_energy_value:2.210856e-08
# Epoch #  546000/600000    time:73.69
# loss:2.04e-05, loss_ics:2.79e-09, loss_res:2.24e-05, loss_energy_value:1.571440e-08
# Epoch #  547000/600000    time:69.66
# loss:2.03e-05, loss_ics:2.77e-09, loss_res:2.22e-05, loss_energy_value:6.807640e-09
# Epoch #  548000/600000    time:72.27
# loss:2.04e-05, loss_ics:2.81e-09, loss_res:2.24e-05, loss_energy_value:1.550778e-08
# Epoch #  549000/600000    time:75.76
# loss:2.02e-05, loss_ics:2.74e-09, loss_res:2.22e-05, loss_energy_value:6.026700e-09
# Epoch #  550000/600000    time:70.71
# loss:2.03e-05, loss_ics:2.83e-09, loss_res:2.23e-05, loss_energy_value:1.988325e-08
# Epoch #  551000/600000    time:72.94
# loss:1.99e-05, loss_ics:2.73e-09, loss_res:2.18e-05, loss_energy_value:9.236025e-09
# Epoch #  552000/600000    time:67.81
# loss:1.99e-05, loss_ics:2.72e-09, loss_res:2.18e-05, loss_energy_value:9.253577e-09
# Epoch #  553000/600000    time:71.73
# loss:1.98e-05, loss_ics:2.72e-09, loss_res:2.17e-05, loss_energy_value:9.239805e-09
# Epoch #  554000/600000    time:71.54
# loss:1.98e-05, loss_ics:2.71e-09, loss_res:2.16e-05, loss_energy_value:9.298296e-09
# Epoch #  555000/600000    time:68.19
# loss:1.97e-05, loss_ics:2.71e-09, loss_res:2.16e-05, loss_energy_value:9.120128e-09
# Epoch #  556000/600000    time:74.67
# loss:1.97e-05, loss_ics:2.70e-09, loss_res:2.15e-05, loss_energy_value:9.354258e-09
# Epoch #  557000/600000    time:71.49
# loss:1.96e-05, loss_ics:2.70e-09, loss_res:2.15e-05, loss_energy_value:9.127435e-09
# Epoch #  558000/600000    time:72.18
# loss:1.96e-05, loss_ics:2.69e-09, loss_res:2.14e-05, loss_energy_value:9.080192e-09
# Epoch #  559000/600000    time:71.79
# loss:1.95e-05, loss_ics:2.69e-09, loss_res:2.13e-05, loss_energy_value:9.031941e-09
# Epoch #  560000/600000    time:73.17
# loss:1.95e-05, loss_ics:2.67e-09, loss_res:2.13e-05, loss_energy_value:9.662083e-09
# Epoch #  561000/600000    time:69.35
# loss:1.94e-05, loss_ics:2.68e-09, loss_res:2.12e-05, loss_energy_value:9.003189e-09
# Epoch #  562000/600000    time:74.86
# loss:1.94e-05, loss_ics:2.67e-09, loss_res:2.12e-05, loss_energy_value:8.890367e-09
# Epoch #  563000/600000    time:69.00
# loss:1.93e-05, loss_ics:2.67e-09, loss_res:2.11e-05, loss_energy_value:8.793897e-09
# Epoch #  564000/600000    time:71.53
# loss:1.93e-05, loss_ics:2.66e-09, loss_res:2.11e-05, loss_energy_value:8.908831e-09
# Epoch #  565000/600000    time:72.80
# loss:1.92e-05, loss_ics:2.66e-09, loss_res:2.10e-05, loss_energy_value:8.718995e-09
# Epoch #  566000/600000    time:72.20
# loss:1.92e-05, loss_ics:2.65e-09, loss_res:2.09e-05, loss_energy_value:8.721368e-09
# Epoch #  567000/600000    time:72.27
# loss:1.91e-05, loss_ics:2.64e-09, loss_res:2.09e-05, loss_energy_value:8.591743e-09
# Epoch #  568000/600000    time:74.75
# loss:1.91e-05, loss_ics:2.64e-09, loss_res:2.08e-05, loss_energy_value:8.584892e-09
# Epoch #  569000/600000    time:69.18
# loss:1.91e-05, loss_ics:2.64e-09, loss_res:2.08e-05, loss_energy_value:8.905713e-09
# Epoch #  570000/600000    time:74.20
# loss:1.90e-05, loss_ics:2.63e-09, loss_res:2.07e-05, loss_energy_value:8.496287e-09
# Epoch #  571000/600000    time:70.60
# loss:1.90e-05, loss_ics:2.63e-09, loss_res:2.07e-05, loss_energy_value:8.465470e-09
# Epoch #  572000/600000    time:72.96
# loss:1.89e-05, loss_ics:2.62e-09, loss_res:2.06e-05, loss_energy_value:8.391481e-09
# Epoch #  573000/600000    time:70.16
# loss:1.89e-05, loss_ics:2.62e-09, loss_res:2.06e-05, loss_energy_value:8.361734e-09
# Epoch #  574000/600000    time:71.46
# loss:1.89e-05, loss_ics:2.61e-09, loss_res:2.06e-05, loss_energy_value:6.044950e-09
# Epoch #  575000/600000    time:73.95
# loss:1.88e-05, loss_ics:2.60e-09, loss_res:2.05e-05, loss_energy_value:9.440170e-09
# Epoch #  576000/600000    time:70.50
# loss:1.88e-05, loss_ics:2.60e-09, loss_res:2.04e-05, loss_energy_value:8.278053e-09
# Epoch #  577000/600000    time:72.12
# loss:1.87e-05, loss_ics:2.60e-09, loss_res:2.04e-05, loss_energy_value:8.230310e-09
# Epoch #  578000/600000    time:71.23
# loss:1.87e-05, loss_ics:2.59e-09, loss_res:2.03e-05, loss_energy_value:8.153058e-09
# Epoch #  579000/600000    time:68.33
# loss:1.87e-05, loss_ics:2.61e-09, loss_res:2.03e-05, loss_energy_value:7.138067e-09
# Epoch #  580000/600000    time:73.86
# loss:1.86e-05, loss_ics:2.58e-09, loss_res:2.02e-05, loss_energy_value:8.088052e-09
# Epoch #  581000/600000    time:72.95
# loss:1.86e-05, loss_ics:2.58e-09, loss_res:2.02e-05, loss_energy_value:8.076063e-09
# Epoch #  582000/600000    time:70.23
# loss:1.85e-05, loss_ics:2.57e-09, loss_res:2.01e-05, loss_energy_value:8.022762e-09
# Epoch #  583000/600000    time:74.36
# loss:1.85e-05, loss_ics:2.57e-09, loss_res:2.01e-05, loss_energy_value:7.884196e-09
# Epoch #  584000/600000    time:73.49
# loss:1.84e-05, loss_ics:2.57e-09, loss_res:2.00e-05, loss_energy_value:7.926491e-09
# Epoch #  585000/600000    time:71.42
# loss:1.84e-05, loss_ics:2.56e-09, loss_res:2.00e-05, loss_energy_value:7.925575e-09
# Epoch #  586000/600000    time:75.72
# loss:1.84e-05, loss_ics:2.56e-09, loss_res:1.99e-05, loss_energy_value:7.864308e-09
# Epoch #  587000/600000    time:71.84
# loss:1.83e-05, loss_ics:2.55e-09, loss_res:1.99e-05, loss_energy_value:7.822530e-09
# Epoch #  588000/600000    time:66.23
# loss:1.83e-05, loss_ics:2.55e-09, loss_res:1.98e-05, loss_energy_value:7.713036e-09
# Epoch #  589000/600000    time:73.26
# loss:1.82e-05, loss_ics:2.54e-09, loss_res:1.98e-05, loss_energy_value:7.717641e-09
# Epoch #  590000/600000    time:71.92
# loss:1.82e-05, loss_ics:2.54e-09, loss_res:1.97e-05, loss_energy_value:7.706175e-09
# Epoch #  591000/600000    time:65.20
# loss:1.82e-05, loss_ics:2.54e-09, loss_res:1.97e-05, loss_energy_value:7.728406e-09
# Epoch #  592000/600000    time:72.59
# loss:1.81e-05, loss_ics:2.53e-09, loss_res:1.97e-05, loss_energy_value:7.579176e-09
# Epoch #  593000/600000    time:70.01
# loss:1.81e-05, loss_ics:2.53e-09, loss_res:1.96e-05, loss_energy_value:7.571977e-09
# Epoch #  594000/600000    time:71.81
# loss:1.80e-05, loss_ics:2.52e-09, loss_res:1.96e-05, loss_energy_value:7.636266e-09
# Epoch #  595000/600000    time:74.82
# loss:1.80e-05, loss_ics:2.52e-09, loss_res:1.95e-05, loss_energy_value:7.580273e-09
# Epoch #  596000/600000    time:73.90
# loss:1.80e-05, loss_ics:2.51e-09, loss_res:1.95e-05, loss_energy_value:7.493333e-09
# Epoch #  597000/600000    time:70.94
# loss:1.80e-05, loss_ics:2.96e-09, loss_res:1.95e-05, loss_energy_value:5.318010e-09
# Epoch #  598000/600000    time:73.69
# loss:1.79e-05, loss_ics:2.51e-09, loss_res:1.94e-05, loss_energy_value:7.615709e-09
# Epoch #  599000/600000    time:70.92
# loss:1.79e-05, loss_ics:2.50e-09, loss_res:1.93e-05, loss_energy_value:7.572415e-09

# %%
file = f'{args.epochs_Adam}epoch,{args.step_size}step_size,{args.tol}tol'
if os.path.exists(file)==False:
    os.mkdir(file)

# %%
plt.plot(trainer.epoch_log, trainer.loss_ics_log, label='loss_ic')
plt.plot(trainer.epoch_log, trainer.loss_res_log, label='loss_r')
plt.yscale('log')
plt.legend()
plt.savefig(f'{file}/loss.jpg')

# %%
# load the data
data = scipy.io.loadmat('./KdV.mat')
usol = data['uu']

# Grid
t_star = data['tt'][0]
x_star = data['x'][0]
TT, XX = np.meshgrid(t_star, x_star)

# Reference solution
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
# Out:
# Text(0,0.5,'$x$')

# %%
# Get trained network parameters
TX = np.hstack((TT.reshape(-1,1), XX.reshape(-1,1)))
TX = torch.from_numpy(TX).double()

model = trainer.model.cpu().double()
u_pred = model(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

error = np.linalg.norm(u_pred - usol) / np.linalg.norm(usol) 
print('Relative l2 error: {:.3e}'.format(error))
# Out:
# Relative l2 error: 2.594e-03

# %%
fig = plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Exact $u(x)$')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.pcolor(TT, XX, u_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Predicted $u(x)$')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.pcolor(TT, XX, np.abs(usol - u_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.savefig(f'{file}/predict.jpg')
plt.show()

# %%
fig = plt.figure(figsize=(13, 4))
plt.subplot(1, 3, 1)
plt.plot(x_star, usol[:,0], color='blue')
plt.plot(x_star, u_pred[:,0], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 0$')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.plot(x_star, usol[:,25], color='blue')
plt.plot(x_star, u_pred[:,25], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 0.5$')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.plot(x_star, usol[:,-1], color='blue')
plt.plot(x_star, u_pred[:,-1], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 1.0$')
plt.tight_layout()
plt.savefig(f'{file}/check_t.jpg')
plt.show()

# %%
L_t = trainer.L_t_log[-1].numpy()
W = trainer.W_log[-1].numpy()
t_r = np.linspace(0, 1, 100)

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(t_r, W)
plt.xlabel('$t$')
plt.ylabel('$w(t)$')
# Out:
# Text(0, 0.5, '$w(t)$')

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(t_r, L_t)
plt.xlabel('$t$')
plt.ylabel('$\mathcal{L}(t, \\theta)$')
# Out:
# Text(0, 0.5, '$\\mathcal{L}(t, \\theta)$')

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

fig = plt.figure()
ims = []
for i in range(len(trainer.W_log)):
    im = plt.plot(t_r, trainer.W_log[i],'b')
    ims.append(im)
ani = animation.ArtistAnimation(fig, ims, interval=20, repeat_delay=50)
ani.save(f"{file}/weight.gif",writer='pillow')

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

fig = plt.figure()
ims = []
for i in range(len(trainer.L_t_log)):
    im = plt.plot(t_r, trainer.L_t_log[i],'b')
    plt.yscale('log')
    ims.append(im)
ani = animation.ArtistAnimation(fig, ims, interval=20, repeat_delay=50)
ani.save(f"{file}/loss_t.gif",writer='pillow')
