# %% [markdown]
# step_size=5000

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import scipy.io
import matplotlib.gridspec as gridspec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.interpolate import griddata

import torch
from torch import nn
import torch.optim as optim
from torch.optim import lr_scheduler

import argparse
import random
import os
import math

os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
# CUDA support
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %%
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed) # 为了禁止hash随机化，使得实验可复现
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed) # if you are using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
    random.seed(seed)

def grad(outputs, inputs):
    """ compute the derivative of outputs associated with inputs

    Params
    ======
    outputs: (N, 1) tensor
    inputs: (N, D) tensor
    """
    return torch.autograd.grad(outputs, inputs,
                               grad_outputs=torch.ones_like(outputs),
                               create_graph=True)

def activation(name):
    if name in ['tanh', 'Tanh']:
        return nn.Tanh()
    elif name in ['relu', 'ReLU']:
        return nn.ReLU(inplace=True)
    elif name in ['leaky_relu', 'LeakyReLU']:
        return nn.LeakyReLU(inplace=True)
    elif name in ['sigmoid', 'Sigmoid']:
        return nn.Sigmoid()
    elif name in ['softplus', 'Softplus']:
        return nn.Softplus()
    else:
        raise ValueError(f'unknown activation function: {name}')

# %%
seed_torch(24)

# %% [markdown]
# ## 网络模型

# %%
class MLP(nn.Module):
    """Deep Neural Network"""

    def __init__(self, L, M, dim_hidden, hidden_layers, dim_out,
                 act_name='tanh', init_name='xavier_normal'):
        super().__init__()
        
        dim_in = M * 2 + 2
        
        model = nn.Sequential()
        
        model.add_module('fc0', nn.Linear(dim_in, dim_hidden, bias=True))
        model.add_module('act0', activation(act_name))
        for i in range(1, hidden_layers):
            model.add_module(f'fc{i}', nn.Linear(dim_hidden, dim_hidden, bias=True))
            model.add_module(f'act{i}', activation(act_name))
        model.add_module(f'fc{hidden_layers}', nn.Linear(dim_hidden, dim_out, bias=True))
            
        self.model = model
        
        self.L = L
        self.M = M
        
        if init_name is not None:
            self.init_weight(init_name)

            
        self.k = nn.Parameter(torch.arange(1, self.M+1), requires_grad=False)
                    
    def init_weight(self, name):
        if name == 'xavier_normal':
            nn_init = nn.init.xavier_normal_
        elif name == 'xavier_uniform':
            nn_init = nn.init.xavier_uniform_
        elif name == 'kaiming_normal':
            nn_init = nn.init.kaiming_normal_
        elif name == 'kaiming_uniform':
            nn_init = nn.init.kaiming_uniform_
        else:
            raise ValueError(f'unknown initialization function: {name}')

        for param in self.parameters():
            if len(param.shape) > 1:
                nn_init(param)
                
#         for layer, param in enumerate(self.parameters()):
#             if layer % 2 == 1:
#                 nn.init.constant_(param, 0.0)
#             else:
#                 nn_init(param)
                
    def input_encoding(self, t, x):
        w = 2.0 * math.pi / self.L
        out = torch.cat([t, torch.ones_like(t), 
                            torch.cos(self.k * w * x), torch.sin(self.k * w * x)], dim = 1) 
        
        return out    
            
    def forward(self, H):
        t = H[:, 0:1]
        x = H[:, 1:2]
        
        H = self.input_encoding(t, x)
        H = self.model(H)
        
        return H
    
    def forward_test(self, x):
        print(f"{'input':<20}{str(x.shape):<40}")
        for name, module in self.model._modules.items():
            x = module(x)
            print(f"{name:<20}{str(x.shape):<40}")
        return x

    def model_size(self):
        n_params = 0
        for param in self.parameters():
            n_params += param.numel()
        return n_params
    
    def print(self):
        print(self.bias)

# %%
model = MLP(L=2.0, M=10, dim_hidden=128, hidden_layers=4, dim_out=1)

# %% [markdown]
# ## PDE部分

# %% [markdown]
# KDV方程：
# $$
# \left\{\begin{matrix}
# &u_{t}+ \lambda_1 u u_{x} + \lambda_2 u_{xxx}=0  ,(t,x)\in (0,1)\times (-1,1),  \\
# &u(0,x)= cos(\pi x),  \\
# &u(t,-1)=u(t,1),t\in [0,1],  \\
# &u_x(t,-1)=u_x(t,1),x\in [0,1].
# \end{matrix}\right.
# $$
# $\lambda_1 = 1.000$, $\lambda_2 = 0.0025$.

# %%
def net_r(self, tx):
    tx.requires_grad_(True)

    u = self.model(tx)

    grad_u = grad(u, tx)[0]
    u_t = grad_u[:,[0]]
    u_x = grad_u[:,[1]]
    u_xx = grad(u_x, tx)[0][:, [1]]
    u_xxx = grad(u_xx, tx)[0][:, [1]]

    residual = u_t  + u * u_x + 0.0025 * u_xxx

    return residual

def net_u(self, tx):
    u = self.model(tx)
    return u

# %% [markdown]
# ## Options

# %%
import argparse
class Options_KDV(object):
    def __init__(self):
        parser = argparse.ArgumentParser()
        parser.add_argument('--no_cuda', action='store_true', default=False, help='disable CUDA or not')
        parser.add_argument('--dim_hidden', type=int, default=12, help='neurons in hidden layers')     # 10 9
        parser.add_argument('--hidden_layers', type=int, default=9, help='number of hidden layers')    # 4  20
        parser.add_argument('--lam', type=float, default=1, help='weight in loss function')
        parser.add_argument('--lr', type=float, default=0.001, help='initial learning rate')
        parser.add_argument('--epochs_Adam', type=int, default=600000, help='epochs for Adam optimizer')
        parser.add_argument('--epochs_LBFGS', type=int, default=1000, help='epochs for LBFGS optimizer')
        parser.add_argument('--newton_iter', type=int, default=100, help='newton_iter for LBFGS optimizer')
        parser.add_argument('--step_size', type=int, default=10000, help='step size in lr_scheduler for Adam optimizer')
        parser.add_argument('--gamma', type=float, default=0.9, help='gamma in lr_scheduler for Adam optimizer')
        parser.add_argument('--tol', type=float, default=100, help='the annealing scheme')
        parser.add_argument('--resume', type=bool, default=False, help='resume or not')
        parser.add_argument('--sample_method', type=str, default='uniform', help='sample method')

        self.parser = parser

    def parse(self):
        arg = self.parser.parse_args(args=[])
        arg.load_model = False
        arg.cuda = not arg.no_cuda and torch.cuda.is_available()
        # arg.cuda = False
        arg.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        print(arg.cuda)
        print(arg.device)
        return arg

args = Options_KDV().parse()
print(args.hidden_layers)

def save_model(state, is_best=None, save_dir=None):
    last_model = os.path.join(save_dir, 'last_model.pth.tar')
    torch.save(state, last_model)
    if is_best:
        best_model = os.path.join(save_dir, 'best_model.pth.tar')
        shutil.copyfile(last_model, best_model)
# Out:
# True
# cuda
# 9

# %%
model.cuda()
args.model=model

# %% [markdown]
# ## 数据集生成

# %%
class Trainset_KDV():
    '''
    训练点:时间剖分 100 段， 空间上分成25段，每段上取4个高斯点
    '''
    def __init__(self, *args):
        self.args = args
        self.shape = (self.args[1], self.args[0])
        
    def __call__(self):
        return self.data()
    
    def data(self):
        gp = np.array([0.8611363116,-0.8611363116,0.3399810436,-0.3399810436])
        gc = np.array([0.3478548451,0.3478548451,0.6521451549,0.6521451549])
        n_t = self.args[0]
        n_x = self.args[1]
        n_ics = self.args[2]
        
        # 生成初值训练点
        t = np.linspace(0, 1, n_t)
        x = np.linspace(-1, 1, n_x)
        t, x = np.meshgrid(t, x)
        tx = np.hstack((t.reshape(-1,1), x.reshape(-1,1)))
        
        t_ics = np.zeros(n_ics)
        x_ics = np.linspace(-1, 1, n_ics)
        tx_ics = np.hstack([t_ics.reshape(-1,1),x_ics.reshape(-1,1)])
        
        u_ics = np.cos(math.pi*x_ics)
        u_ics = u_ics.reshape(-1,1)
        M = np.triu(np.ones([n_t, n_t]),k=1).T
        
        # 生成tgx(高斯训练点)
        l = np.linspace(-1, 1, 26)[:, None]
        l = np.hstack([l[:-1], l[1:]])
        c = (l[:, 1] - l[:, 0])/2
        c = c[:, None]
        gp = gp[None, :]
        d = ((l[:, 1] + l[:, 0])/2)
        d = d[:, None]
        n_p = c * gp + d  # n_p是100个高斯积分点
        n_p = n_p.reshape(100, 1)
        gcl = c * gc     # gcl是这100个高斯积分点对应的权重  
        gcl = gcl.reshape(100, 1)
        t = np.linspace(0, 1, n_t)
        t = np.random.choice(t, 5, False)
        t = t[:, None]
        x, t = np.meshgrid(n_p, t)
        print(t.shape, x.shape)
        txg = np.hstack([t.reshape(-1, 1), x.reshape(-1, 1)])
        
        # 计算一下初始能量
        E2 =  np.cos(math.pi*n_p) ** 2 * gcl
        E2 = np.sum(E2)
        
        txg = np.hstack((t.reshape(-1,1), x.reshape(-1,1)))
        
        tx = torch.from_numpy(tx).float().to(device)
        txg = torch.from_numpy(txg).float().to(device)
        tx_ics = torch.from_numpy(tx_ics).float().to(device)
        u_ics = torch.from_numpy(u_ics).float().to(device)
        M = torch.from_numpy(M).float().to(device)
        
        return tx, tx_ics, u_ics, M, gcl, txg, E2

# %%
trainset = Trainset_KDV(100, 256, 512)
args.trainset = trainset
tx, tx_ics, u_ics, M, gcl, txg, E2 = trainset()
# Out:
# (5, 100) (5, 100)

# %%
tx.shape
# Out:
# torch.Size([25600, 2])

# %%
txg.shape
# Out:
# torch.Size([500, 2])

# %%
E2
# Out:
# 0.9999999999999998

# %%
gcl.shape
# Out:
# (100, 1)

# %% [markdown]
# ## 训练

# %%
class Trainer_Wave(object):
    def __init__(self, args):
        self.model = args.model
        self.lr = args.lr
        self.gamma = args.gamma
        self.trainset = args.trainset
        self.step_size = args.step_size
        self.model_name = self.model.__class__.__name__     
        self.optimizer_Adam = optim.Adam(self.model.parameters(), lr=self.lr, betas=(0.9, 0.999))
        self.scheduler = lr_scheduler.ExponentialLR(self.optimizer_Adam, gamma=self.gamma)
        self.epochs_Adam = args.epochs_Adam
        self.tol = args.tol
        
        # data
        self.tx, self.tx_ics, self.u_ics, self.M,  self.gcl, self.txg, self.E2 = self.trainset()
        self.gcl = torch.from_numpy(self.gcl).float().to(device)
        self.E2 = torch.tensor(self.E2).float().to(device)
        
        # Logger
        self.loss_log = []
        self.loss_ics_log = []
        self.loss_res_log = []
        self.W_log = []
        self.L_t_log = []
        self.epoch_log = []
        

    def net_r(self, tx):
        tx.requires_grad_(True).to(device)
        u = self.model(tx)
        grad_u = grad(u, tx)[0]
        u_t = grad_u[:,[0]]
        u_x = grad_u[:,[1]]
        u_xx = grad(u_x, tx)[0][:, [1]]
        u_xxx = grad(u_xx, tx)[0][:, [1]]

        residual = u_t  + u * u_x + 0.0025 * u_xxx

        return residual

    def net_u(self, tx):
        u = self.model(tx)  
        return u
    
    def residuals_and_weights(self):
        r_pred = self.net_r(self.tx) 
        r_pred = r_pred.reshape(self.trainset.shape[0], self.trainset.shape[1]) # :shape(100,100)
        L_t = torch.mean(r_pred**2, axis=0) 
        L_t = L_t
        W = torch.exp(-self.tol * (self.M @ L_t.detach()))
        
        return L_t, W
    
    def loss_ics(self):
        u_pred = self.net_u(self.tx_ics)
        loss_ics = torch.mean((u_pred - self.u_ics)**2)
        return loss_ics
    
    def loss_res(self):
        r_pred = self.net_r(self.tx)
        loss_r = torch.mean(r_pred**2)
        return loss_r
    
    def loss(self):
        L0 = 100 * self.loss_ics()
        LE = self.energy_loss()
        L_t, W = self.residuals_and_weights()
        loss = torch.mean(W * L_t) + L0 + LE  
        return loss
    
    def energy_loss(self):
        q_pred = self.net_u(self.txg)
        q_pred = q_pred.reshape(-1, 100)
        gcl = self.gcl.reshape(1, 100)
        
        q_pred = q_pred ** 2 * gcl
        q_pred = torch.sum(q_pred, axis=1)
        q_pred = (q_pred - self.E2)
        loss_q = torch.mean(q_pred ** 2)
        return loss_q
    
    def train(self):
        start = time.time()
        for epoch in range(self.epochs_Adam):
            self.optimizer_Adam.zero_grad()
            loss_value = self.loss()
            loss_value.backward()
            self.optimizer_Adam.step()
            
            if (epoch+1) % self.step_size == 0:
                self.scheduler.step()            
            
            if epoch % 1000 == 0:
                loss_value = self.loss()
                loss_ics_value = self.loss_ics()
                loss_res_value = self.loss_res()
                loss_energy_value = self.energy_loss()
                L_t_value, W_value = self.residuals_and_weights()
                
                self.loss_log.append(loss_value.detach().cpu())
                self.loss_ics_log.append(loss_ics_value.detach().cpu())
                self.loss_res_log.append(loss_res_value.detach().cpu())
                self.W_log.append(W_value.detach().cpu())
                self.L_t_log.append(L_t_value.detach().cpu())
                self.epoch_log.append(epoch)
                
                end = time.time()
                running_time = end - start
                start = time.time()
                
                print(f'Epoch #  {epoch}/{self.epochs_Adam}' + f'    time:{running_time:.2f}' + '\n' + \
                      f'loss:{loss_value:.2e}, loss_ics:{loss_ics_value:.2e}, loss_res:{loss_res_value:.2e}, loss_energy_value:{loss_energy_value:2e}')

# %%
trainer = Trainer_Wave(args)
trainer.train()
# Out:
# (5, 100) (5, 100)
# Epoch #  0/600000    time:0.14
# loss:3.91e+01, loss_ics:3.71e-01, loss_res:1.14e+02, loss_energy_value:7.941740e-01
# Epoch #  1000/600000    time:47.78
# loss:1.20e-02, loss_ics:2.21e-07, loss_res:5.06e+00, loss_energy_value:1.130415e-05
# Epoch #  2000/600000    time:47.84
# loss:1.09e-02, loss_ics:2.06e-07, loss_res:9.21e+00, loss_energy_value:3.710069e-05
# Epoch #  3000/600000    time:47.93
# loss:3.75e-03, loss_ics:1.64e-07, loss_res:3.18e+01, loss_energy_value:4.096685e-04
# Epoch #  4000/600000    time:47.91
# loss:7.95e-04, loss_ics:5.04e-06, loss_res:3.65e+01, loss_energy_value:1.840137e-05
# Epoch #  5000/600000    time:48.08
# loss:6.88e-04, loss_ics:4.52e-06, loss_res:3.10e+01, loss_energy_value:8.317906e-06
# Epoch #  6000/600000    time:47.64
# loss:3.90e-03, loss_ics:3.59e-05, loss_res:2.80e+01, loss_energy_value:5.410760e-05
# Epoch #  7000/600000    time:47.84
# loss:4.02e-03, loss_ics:3.78e-05, loss_res:2.63e+01, loss_energy_value:3.223522e-05
# Epoch #  8000/600000    time:47.69
# loss:2.07e-02, loss_ics:1.99e-04, loss_res:2.46e+01, loss_energy_value:5.946117e-04
# Epoch #  9000/600000    time:47.70
# loss:1.43e-03, loss_ics:1.20e-05, loss_res:2.44e+01, loss_energy_value:4.447196e-05
# Epoch #  10000/600000    time:47.74
# loss:2.02e-03, loss_ics:1.81e-05, loss_res:2.26e+01, loss_energy_value:3.064610e-05
# Epoch #  11000/600000    time:45.92
# loss:5.29e-04, loss_ics:3.62e-06, loss_res:2.08e+01, loss_energy_value:2.329392e-06
# Epoch #  12000/600000    time:48.04
# loss:4.75e-03, loss_ics:4.45e-05, loss_res:1.91e+01, loss_energy_value:1.407983e-04
# Epoch #  13000/600000    time:46.95
# loss:1.07e-03, loss_ics:9.17e-06, loss_res:1.62e+01, loss_energy_value:4.561201e-06
# Epoch #  14000/600000    time:46.96
# loss:7.57e-04, loss_ics:6.15e-06, loss_res:1.32e+01, loss_energy_value:3.183480e-06
# Epoch #  15000/600000    time:47.73
# loss:2.02e-03, loss_ics:1.80e-05, loss_res:1.10e+01, loss_energy_value:9.057450e-05
# Epoch #  16000/600000    time:47.75
# loss:3.85e-04, loss_ics:2.53e-06, loss_res:9.87e+00, loss_energy_value:8.767815e-07
# Epoch #  17000/600000    time:47.72
# loss:4.85e-04, loss_ics:3.54e-06, loss_res:8.95e+00, loss_energy_value:9.330453e-07
# Epoch #  18000/600000    time:47.84
# loss:2.70e-04, loss_ics:1.39e-06, loss_res:8.39e+00, loss_energy_value:2.045120e-06
# Epoch #  19000/600000    time:47.88
# loss:1.21e-03, loss_ics:1.05e-05, loss_res:7.91e+00, loss_energy_value:3.303581e-05
# Epoch #  20000/600000    time:48.00
# loss:3.62e-04, loss_ics:2.35e-06, loss_res:7.46e+00, loss_energy_value:6.913071e-07
# Epoch #  21000/600000    time:48.03
# loss:1.87e-04, loss_ics:6.17e-07, loss_res:7.35e+00, loss_energy_value:5.385575e-08
# Epoch #  22000/600000    time:47.91
# loss:4.10e-04, loss_ics:2.71e-06, loss_res:7.06e+00, loss_energy_value:1.719019e-05
# Epoch #  23000/600000    time:48.73
# loss:9.19e-04, loss_ics:7.70e-06, loss_res:7.07e+00, loss_energy_value:2.537636e-05
# Epoch #  24000/600000    time:48.61
# loss:2.27e-04, loss_ics:1.03e-06, loss_res:6.95e+00, loss_energy_value:3.083933e-06
# Epoch #  25000/600000    time:48.05
# loss:1.41e-04, loss_ics:2.15e-07, loss_res:6.89e+00, loss_energy_value:5.820443e-08
# Epoch #  26000/600000    time:47.88
# loss:2.16e-04, loss_ics:9.64e-07, loss_res:6.57e+00, loss_energy_value:4.290215e-07
# Epoch #  27000/600000    time:47.91
# loss:1.79e-04, loss_ics:6.23e-07, loss_res:6.20e+00, loss_energy_value:1.627772e-08
# Epoch #  28000/600000    time:47.83
# loss:3.49e-04, loss_ics:2.18e-06, loss_res:5.78e+00, loss_energy_value:9.768482e-06
# Epoch #  29000/600000    time:47.80
# loss:1.52e-03, loss_ics:1.24e-05, loss_res:5.24e+00, loss_energy_value:1.617404e-04
# Epoch #  30000/600000    time:47.81
# loss:2.23e-04, loss_ics:9.97e-07, loss_res:4.94e+00, loss_energy_value:5.965010e-06
# Epoch #  31000/600000    time:47.83
# loss:1.57e-04, loss_ics:4.26e-07, loss_res:4.55e+00, loss_energy_value:5.499296e-07
# Epoch #  32000/600000    time:47.68
# loss:1.51e-04, loss_ics:3.55e-07, loss_res:4.29e+00, loss_energy_value:9.734985e-07
# Epoch #  33000/600000    time:48.08
# loss:3.69e-04, loss_ics:2.46e-06, loss_res:4.06e+00, loss_energy_value:8.884126e-06
# Epoch #  34000/600000    time:47.89
# loss:2.39e-04, loss_ics:1.24e-06, loss_res:3.91e+00, loss_energy_value:2.099674e-06
# Epoch #  35000/600000    time:47.86
# loss:2.10e-04, loss_ics:9.29e-07, loss_res:3.84e+00, loss_energy_value:2.782673e-07
# Epoch #  36000/600000    time:47.76
# loss:1.77e-04, loss_ics:5.62e-07, loss_res:3.74e+00, loss_energy_value:8.049623e-06
# Epoch #  37000/600000    time:48.07
# loss:2.07e-04, loss_ics:9.22e-07, loss_res:3.83e+00, loss_energy_value:3.007174e-06
# Epoch #  38000/600000    time:47.67
# loss:1.85e-04, loss_ics:7.02e-07, loss_res:3.93e+00, loss_energy_value:1.478285e-06
# Epoch #  39000/600000    time:47.69
# loss:1.56e-04, loss_ics:3.90e-07, loss_res:4.07e+00, loss_energy_value:6.969014e-07
# Epoch #  40000/600000    time:47.77
# loss:1.95e-04, loss_ics:8.02e-07, loss_res:4.22e+00, loss_energy_value:1.751656e-07
# Epoch #  41000/600000    time:47.74
# loss:1.80e-04, loss_ics:6.69e-07, loss_res:4.65e+00, loss_energy_value:2.283274e-06
# Epoch #  42000/600000    time:47.73
# loss:1.86e-04, loss_ics:6.42e-07, loss_res:5.19e+00, loss_energy_value:9.703249e-06
# Epoch #  43000/600000    time:47.67
# loss:1.77e-04, loss_ics:6.16e-07, loss_res:5.45e+00, loss_energy_value:4.200012e-06
# Epoch #  44000/600000    time:47.69
# loss:2.11e-04, loss_ics:9.46e-07, loss_res:6.00e+00, loss_energy_value:5.720803e-06
# Epoch #  45000/600000    time:47.83
# loss:6.89e-04, loss_ics:5.08e-06, loss_res:6.53e+00, loss_energy_value:5.383517e-05
# Epoch #  46000/600000    time:48.02
# loss:6.75e-04, loss_ics:5.59e-06, loss_res:7.17e+00, loss_energy_value:2.025916e-06
# Epoch #  47000/600000    time:47.98
# loss:1.71e-04, loss_ics:5.45e-07, loss_res:7.55e+00, loss_energy_value:3.791582e-06
# Epoch #  48000/600000    time:47.79
# loss:1.49e-04, loss_ics:3.95e-07, loss_res:8.34e+00, loss_energy_value:4.433583e-07
# Epoch #  49000/600000    time:47.93
# loss:1.77e-04, loss_ics:6.41e-07, loss_res:8.56e+00, loss_energy_value:3.599200e-06
# Epoch #  50000/600000    time:47.99
# loss:2.35e-04, loss_ics:1.08e-06, loss_res:9.43e+00, loss_energy_value:1.216811e-05
# Epoch #  51000/600000    time:47.87
# loss:4.79e-04, loss_ics:3.52e-06, loss_res:1.02e+01, loss_energy_value:1.538862e-05
# Epoch #  52000/600000    time:47.81
# loss:7.37e-04, loss_ics:6.03e-06, loss_res:1.10e+01, loss_energy_value:1.370354e-05
# Epoch #  53000/600000    time:47.91
# loss:4.35e-04, loss_ics:2.95e-06, loss_res:1.16e+01, loss_energy_value:3.020969e-05
# Epoch #  54000/600000    time:47.87
# loss:1.54e-04, loss_ics:4.22e-07, loss_res:1.25e+01, loss_energy_value:5.283795e-07
# Epoch #  55000/600000    time:47.84
# loss:1.45e-04, loss_ics:3.65e-07, loss_res:1.28e+01, loss_energy_value:6.295755e-07
# Epoch #  56000/600000    time:47.85
# loss:1.62e-04, loss_ics:4.56e-07, loss_res:1.30e+01, loss_energy_value:1.111729e-06
# Epoch #  57000/600000    time:47.68
# loss:1.61e-04, loss_ics:4.64e-07, loss_res:1.36e+01, loss_energy_value:6.671634e-06
# Epoch #  58000/600000    time:48.07
# loss:2.02e-04, loss_ics:8.68e-07, loss_res:1.36e+01, loss_energy_value:2.496532e-06
# Epoch #  59000/600000    time:48.18
# loss:2.02e-04, loss_ics:9.06e-07, loss_res:1.48e+01, loss_energy_value:1.695412e-06
# Epoch #  60000/600000    time:48.01
# loss:1.61e-04, loss_ics:4.16e-07, loss_res:1.47e+01, loss_energy_value:6.655352e-06
# Epoch #  61000/600000    time:47.72
# loss:1.70e-04, loss_ics:3.53e-07, loss_res:1.52e+01, loss_energy_value:2.643811e-05
# Epoch #  62000/600000    time:47.82
# loss:1.52e-04, loss_ics:3.94e-07, loss_res:1.57e+01, loss_energy_value:3.152299e-06
# Epoch #  63000/600000    time:47.68
# loss:1.51e-04, loss_ics:3.56e-07, loss_res:1.59e+01, loss_energy_value:2.830653e-06
# Epoch #  64000/600000    time:47.70
# loss:1.63e-04, loss_ics:4.96e-07, loss_res:1.60e+01, loss_energy_value:3.638375e-06
# Epoch #  65000/600000    time:47.80
# loss:1.67e-04, loss_ics:5.13e-07, loss_res:1.61e+01, loss_energy_value:6.340860e-06
# Epoch #  66000/600000    time:48.22
# loss:3.59e-04, loss_ics:2.21e-06, loss_res:1.64e+01, loss_energy_value:3.120545e-05
# Epoch #  67000/600000    time:48.23
# loss:2.30e-04, loss_ics:1.18e-06, loss_res:1.68e+01, loss_energy_value:3.911771e-06
# Epoch #  68000/600000    time:47.80
# loss:1.67e-04, loss_ics:5.49e-07, loss_res:1.68e+01, loss_energy_value:3.603586e-06
# Epoch #  69000/600000    time:47.83
# loss:1.57e-04, loss_ics:4.49e-07, loss_res:1.70e+01, loss_energy_value:4.277846e-07
# Epoch #  70000/600000    time:47.85
# loss:2.71e-04, loss_ics:1.13e-06, loss_res:1.78e+01, loss_energy_value:2.567128e-05
# Epoch #  71000/600000    time:47.83
# loss:4.61e-04, loss_ics:3.51e-06, loss_res:1.81e+01, loss_energy_value:2.348934e-06
# Epoch #  72000/600000    time:47.87
# loss:1.39e-04, loss_ics:2.86e-07, loss_res:1.88e+01, loss_energy_value:3.280014e-06
# Epoch #  73000/600000    time:48.09
# loss:1.49e-04, loss_ics:3.90e-07, loss_res:1.92e+01, loss_energy_value:7.233870e-07
# Epoch #  74000/600000    time:47.88
# loss:2.00e-04, loss_ics:8.68e-07, loss_res:1.93e+01, loss_energy_value:3.753973e-06
# Epoch #  75000/600000    time:47.86
# loss:1.41e-04, loss_ics:3.24e-07, loss_res:1.94e+01, loss_energy_value:2.299613e-06
# Epoch #  76000/600000    time:48.07
# loss:3.48e-04, loss_ics:2.23e-06, loss_res:1.97e+01, loss_energy_value:5.132777e-06
# Epoch #  77000/600000    time:48.18
# loss:1.21e-04, loss_ics:1.11e-07, loss_res:1.99e+01, loss_energy_value:2.876184e-06
# Epoch #  78000/600000    time:48.06
# loss:2.22e-04, loss_ics:1.09e-06, loss_res:1.99e+01, loss_energy_value:2.947371e-06
# Epoch #  79000/600000    time:47.89
# loss:2.64e-04, loss_ics:1.56e-06, loss_res:2.00e+01, loss_energy_value:1.594087e-06
# Epoch #  80000/600000    time:48.01
# loss:1.44e-04, loss_ics:2.53e-07, loss_res:2.03e+01, loss_energy_value:1.803778e-06
# Epoch #  81000/600000    time:47.92
# loss:2.24e-04, loss_ics:1.15e-06, loss_res:2.04e+01, loss_energy_value:2.822126e-06
# Epoch #  82000/600000    time:47.94
# loss:1.35e-04, loss_ics:2.12e-07, loss_res:1.98e+01, loss_energy_value:1.172791e-06
# Epoch #  83000/600000    time:48.33
# loss:1.59e-04, loss_ics:5.11e-07, loss_res:1.97e+01, loss_energy_value:4.839891e-07
# Epoch #  84000/600000    time:48.76
# loss:1.69e-04, loss_ics:6.17e-07, loss_res:1.94e+01, loss_energy_value:4.355930e-07
# Epoch #  85000/600000    time:47.76
# loss:7.83e-04, loss_ics:6.68e-06, loss_res:1.89e+01, loss_energy_value:8.413644e-06
# Epoch #  86000/600000    time:47.92
# loss:1.34e-04, loss_ics:2.40e-07, loss_res:1.90e+01, loss_energy_value:3.657492e-07
# Epoch #  87000/600000    time:48.05
# loss:1.28e-04, loss_ics:2.07e-07, loss_res:1.81e+01, loss_energy_value:4.786388e-07
# Epoch #  88000/600000    time:47.58
# loss:1.76e-04, loss_ics:6.83e-07, loss_res:1.80e+01, loss_energy_value:5.814652e-07
# Epoch #  89000/600000    time:46.54
# loss:1.44e-04, loss_ics:3.76e-07, loss_res:1.80e+01, loss_energy_value:6.336615e-07
# Epoch #  90000/600000    time:46.53
# loss:1.47e-04, loss_ics:3.65e-07, loss_res:1.75e+01, loss_energy_value:3.098588e-06
# Epoch #  91000/600000    time:46.54
# loss:1.32e-04, loss_ics:2.29e-07, loss_res:1.70e+01, loss_energy_value:7.522112e-07
# Epoch #  92000/600000    time:46.55
# loss:1.28e-04, loss_ics:1.69e-07, loss_res:1.64e+01, loss_energy_value:3.410474e-06
# Epoch #  93000/600000    time:46.61
# loss:1.46e-04, loss_ics:3.67e-07, loss_res:1.61e+01, loss_energy_value:4.124541e-07
# Epoch #  94000/600000    time:47.75
# loss:1.43e-04, loss_ics:2.97e-07, loss_res:1.55e+01, loss_energy_value:3.681148e-06
# Epoch #  95000/600000    time:47.90
# loss:2.57e-04, loss_ics:1.33e-06, loss_res:1.51e+01, loss_energy_value:1.824015e-05
# Epoch #  96000/600000    time:48.04
# loss:1.43e-04, loss_ics:3.56e-07, loss_res:1.48e+01, loss_energy_value:1.836432e-06
# Epoch #  97000/600000    time:47.22
# loss:1.72e-04, loss_ics:5.78e-07, loss_res:1.42e+01, loss_energy_value:4.131555e-06
# Epoch #  98000/600000    time:47.98
# loss:1.68e-04, loss_ics:5.81e-07, loss_res:1.41e+01, loss_energy_value:2.983287e-06
# Epoch #  99000/600000    time:48.13
# loss:1.37e-04, loss_ics:2.63e-07, loss_res:1.36e+01, loss_energy_value:6.330186e-07
# Epoch #  100000/600000    time:48.18
# loss:2.40e-04, loss_ics:1.02e-06, loss_res:1.33e+01, loss_energy_value:3.127847e-05
# Epoch #  101000/600000    time:47.36
# loss:1.53e-04, loss_ics:4.37e-07, loss_res:1.32e+01, loss_energy_value:7.407710e-07
# Epoch #  102000/600000    time:46.29
# loss:1.49e-04, loss_ics:4.17e-07, loss_res:1.27e+01, loss_energy_value:2.374348e-07
# Epoch #  103000/600000    time:48.05
# loss:1.64e-04, loss_ics:4.44e-07, loss_res:1.24e+01, loss_energy_value:1.344418e-05
# Epoch #  104000/600000    time:47.95
# loss:1.39e-04, loss_ics:2.62e-07, loss_res:1.22e+01, loss_energy_value:1.112860e-06
# Epoch #  105000/600000    time:48.37
# loss:1.25e-04, loss_ics:1.84e-07, loss_res:1.19e+01, loss_energy_value:2.182926e-07
# Epoch #  106000/600000    time:48.80
# loss:1.45e-04, loss_ics:3.22e-07, loss_res:1.20e+01, loss_energy_value:4.456631e-06
# Epoch #  107000/600000    time:48.77
# loss:1.55e-04, loss_ics:4.27e-07, loss_res:1.16e+01, loss_energy_value:6.212416e-06
# Epoch #  108000/600000    time:47.97
# loss:1.46e-04, loss_ics:2.18e-07, loss_res:1.15e+01, loss_energy_value:1.648741e-05
# Epoch #  109000/600000    time:47.89
# loss:1.73e-04, loss_ics:6.16e-07, loss_res:1.13e+01, loss_energy_value:1.778367e-06
# Epoch #  110000/600000    time:48.27
# loss:1.51e-04, loss_ics:1.89e-07, loss_res:1.15e+01, loss_energy_value:2.129172e-05
# Epoch #  111000/600000    time:47.77
# loss:1.47e-04, loss_ics:2.44e-07, loss_res:1.12e+01, loss_energy_value:1.471188e-05
# Epoch #  112000/600000    time:47.84
# loss:1.57e-04, loss_ics:4.14e-07, loss_res:1.12e+01, loss_energy_value:3.600618e-06
# Epoch #  113000/600000    time:48.03
# loss:1.37e-04, loss_ics:3.11e-07, loss_res:1.11e+01, loss_energy_value:1.456457e-06
# Epoch #  114000/600000    time:47.94
# loss:1.52e-04, loss_ics:3.02e-07, loss_res:1.11e+01, loss_energy_value:1.351797e-05
# Epoch #  115000/600000    time:47.88
# loss:1.23e-04, loss_ics:1.19e-07, loss_res:1.11e+01, loss_energy_value:2.929864e-06
# Epoch #  116000/600000    time:47.73
# loss:1.39e-04, loss_ics:2.23e-07, loss_res:1.12e+01, loss_energy_value:3.693087e-06
# Epoch #  117000/600000    time:47.93
# loss:1.56e-04, loss_ics:4.55e-07, loss_res:1.11e+01, loss_energy_value:2.714378e-06
# Epoch #  118000/600000    time:47.88
# loss:1.39e-04, loss_ics:2.67e-07, loss_res:1.11e+01, loss_energy_value:5.676830e-06
# Epoch #  119000/600000    time:47.96
# loss:1.22e-04, loss_ics:1.25e-07, loss_res:1.12e+01, loss_energy_value:3.929242e-06
# Epoch #  120000/600000    time:48.42
# loss:1.84e-04, loss_ics:7.00e-07, loss_res:1.14e+01, loss_energy_value:8.660651e-06
# Epoch #  121000/600000    time:48.04
# loss:1.74e-04, loss_ics:3.54e-07, loss_res:1.11e+01, loss_energy_value:2.756239e-05
# Epoch #  122000/600000    time:47.95
# loss:1.49e-04, loss_ics:3.06e-07, loss_res:1.14e+01, loss_energy_value:6.970351e-06
# Epoch #  123000/600000    time:48.14
# loss:1.50e-04, loss_ics:2.94e-07, loss_res:1.14e+01, loss_energy_value:1.533441e-05
# Epoch #  124000/600000    time:48.22
# loss:1.88e-04, loss_ics:7.61e-07, loss_res:1.14e+01, loss_energy_value:5.263875e-06
# Epoch #  125000/600000    time:48.10
# loss:2.03e-04, loss_ics:6.55e-07, loss_res:1.16e+01, loss_energy_value:2.839640e-05
# Epoch #  126000/600000    time:47.95
# loss:1.28e-04, loss_ics:1.71e-07, loss_res:1.17e+01, loss_energy_value:2.689359e-06
# Epoch #  127000/600000    time:47.80
# loss:1.56e-04, loss_ics:4.31e-07, loss_res:1.18e+01, loss_energy_value:7.004793e-06
# Epoch #  128000/600000    time:47.48
# loss:2.08e-04, loss_ics:8.54e-07, loss_res:1.17e+01, loss_energy_value:1.365440e-05
# Epoch #  129000/600000    time:47.34
# loss:1.26e-04, loss_ics:1.87e-07, loss_res:1.18e+01, loss_energy_value:2.195946e-06
# Epoch #  130000/600000    time:47.95
# loss:1.67e-04, loss_ics:5.56e-07, loss_res:1.20e+01, loss_energy_value:4.017424e-07
# Epoch #  131000/600000    time:47.88
# loss:1.24e-04, loss_ics:1.55e-07, loss_res:1.21e+01, loss_energy_value:1.711928e-06
# Epoch #  132000/600000    time:47.96
# loss:1.42e-04, loss_ics:1.74e-07, loss_res:1.20e+01, loss_energy_value:2.002214e-05
# Epoch #  133000/600000    time:47.33
# loss:1.48e-04, loss_ics:3.93e-07, loss_res:1.21e+01, loss_energy_value:2.329931e-06
# Epoch #  134000/600000    time:47.90
# loss:1.22e-04, loss_ics:1.17e-07, loss_res:1.21e+01, loss_energy_value:1.881403e-07
# Epoch #  135000/600000    time:48.00
# loss:1.52e-04, loss_ics:3.78e-07, loss_res:1.22e+01, loss_energy_value:8.082107e-06
# Epoch #  136000/600000    time:47.87
# loss:1.35e-04, loss_ics:2.45e-07, loss_res:1.21e+01, loss_energy_value:2.671366e-06
# Epoch #  137000/600000    time:48.03
# loss:1.33e-04, loss_ics:1.62e-07, loss_res:1.22e+01, loss_energy_value:7.775131e-06
# Epoch #  138000/600000    time:47.82
# loss:1.98e-04, loss_ics:7.84e-07, loss_res:1.20e+01, loss_energy_value:1.351718e-05
# Epoch #  139000/600000    time:48.06
# loss:1.25e-04, loss_ics:1.48e-07, loss_res:1.21e+01, loss_energy_value:2.490403e-06
# Epoch #  140000/600000    time:48.01
# loss:1.31e-04, loss_ics:1.33e-07, loss_res:1.21e+01, loss_energy_value:1.581758e-06
# Epoch #  141000/600000    time:47.88
# loss:1.22e-04, loss_ics:1.24e-07, loss_res:1.21e+01, loss_energy_value:1.304104e-06
# Epoch #  142000/600000    time:47.99
# loss:1.50e-04, loss_ics:2.92e-07, loss_res:1.21e+01, loss_energy_value:1.442237e-05
# Epoch #  143000/600000    time:47.96
# loss:1.83e-04, loss_ics:6.65e-07, loss_res:1.21e+01, loss_energy_value:8.358743e-06
# Epoch #  144000/600000    time:48.59
# loss:1.75e-04, loss_ics:5.25e-07, loss_res:1.19e+01, loss_energy_value:1.766971e-06
# Epoch #  145000/600000    time:47.89
# loss:1.25e-04, loss_ics:1.88e-07, loss_res:1.20e+01, loss_energy_value:1.833972e-06
# Epoch #  146000/600000    time:47.98
# loss:2.35e-04, loss_ics:1.13e-06, loss_res:1.18e+01, loss_energy_value:3.421932e-06
# Epoch #  147000/600000    time:48.01
# loss:1.63e-04, loss_ics:3.67e-07, loss_res:1.18e+01, loss_energy_value:1.853137e-05
# Epoch #  148000/600000    time:48.14
# loss:1.29e-04, loss_ics:2.05e-07, loss_res:1.17e+01, loss_energy_value:2.529654e-06
# Epoch #  149000/600000    time:48.03
# loss:1.24e-04, loss_ics:1.29e-07, loss_res:1.18e+01, loss_energy_value:3.546770e-06
# Epoch #  150000/600000    time:47.83
# loss:1.29e-04, loss_ics:2.13e-07, loss_res:1.18e+01, loss_energy_value:4.022381e-07
# Epoch #  151000/600000    time:48.04
# loss:1.24e-04, loss_ics:1.59e-07, loss_res:1.16e+01, loss_energy_value:1.821802e-06
# Epoch #  152000/600000    time:47.82
# loss:1.20e-04, loss_ics:6.81e-08, loss_res:1.16e+01, loss_energy_value:3.343518e-06
# Epoch #  153000/600000    time:48.01
# loss:1.25e-04, loss_ics:1.79e-07, loss_res:1.15e+01, loss_energy_value:1.252665e-06
# Epoch #  154000/600000    time:48.14
# loss:1.36e-04, loss_ics:1.68e-07, loss_res:1.16e+01, loss_energy_value:1.408262e-05
# Epoch #  155000/600000    time:48.08
# loss:1.28e-04, loss_ics:1.62e-07, loss_res:1.14e+01, loss_energy_value:1.361933e-06
# Epoch #  156000/600000    time:47.87
# loss:1.81e-04, loss_ics:7.49e-07, loss_res:1.14e+01, loss_energy_value:7.271560e-07
# Epoch #  157000/600000    time:47.72
# loss:1.31e-04, loss_ics:2.13e-07, loss_res:1.14e+01, loss_energy_value:2.105852e-06
# Epoch #  158000/600000    time:48.26
# loss:1.37e-04, loss_ics:2.34e-07, loss_res:1.13e+01, loss_energy_value:6.460137e-06
# Epoch #  159000/600000    time:48.22
# loss:1.23e-04, loss_ics:1.01e-07, loss_res:1.13e+01, loss_energy_value:1.528262e-06
# Epoch #  160000/600000    time:48.01
# loss:1.19e-04, loss_ics:1.14e-07, loss_res:1.12e+01, loss_energy_value:2.540926e-07
# Epoch #  161000/600000    time:47.89
# loss:1.34e-04, loss_ics:2.33e-07, loss_res:1.11e+01, loss_energy_value:5.040738e-06
# Epoch #  162000/600000    time:47.90
# loss:1.17e-04, loss_ics:8.19e-08, loss_res:1.12e+01, loss_energy_value:1.623597e-06
# Epoch #  163000/600000    time:48.02
# loss:1.21e-04, loss_ics:1.08e-07, loss_res:1.10e+01, loss_energy_value:3.856527e-06
# Epoch #  164000/600000    time:47.91
# loss:1.25e-04, loss_ics:1.63e-07, loss_res:1.10e+01, loss_energy_value:6.059539e-07
# Epoch #  165000/600000    time:47.91
# loss:1.24e-04, loss_ics:1.62e-07, loss_res:1.10e+01, loss_energy_value:1.141112e-06
# Epoch #  166000/600000    time:48.40
# loss:1.41e-04, loss_ics:3.44e-07, loss_res:1.08e+01, loss_energy_value:8.618032e-07
# Epoch #  167000/600000    time:48.18
# loss:1.26e-04, loss_ics:1.62e-07, loss_res:1.08e+01, loss_energy_value:2.681375e-06
# Epoch #  168000/600000    time:48.07
# loss:1.26e-04, loss_ics:1.71e-07, loss_res:1.08e+01, loss_energy_value:1.203936e-06
# Epoch #  169000/600000    time:47.95
# loss:1.47e-04, loss_ics:2.26e-07, loss_res:1.08e+01, loss_energy_value:4.567225e-06
# Epoch #  170000/600000    time:48.34
# loss:1.24e-04, loss_ics:1.70e-07, loss_res:1.07e+01, loss_energy_value:8.119727e-07
# Epoch #  171000/600000    time:47.71
# loss:1.33e-04, loss_ics:2.26e-07, loss_res:1.05e+01, loss_energy_value:1.416200e-06
# Epoch #  172000/600000    time:47.93
# loss:1.45e-04, loss_ics:1.46e-07, loss_res:1.03e+01, loss_energy_value:1.504320e-06
# Epoch #  173000/600000    time:47.88
# loss:1.52e-04, loss_ics:3.82e-07, loss_res:1.01e+01, loss_energy_value:1.247274e-06
# Epoch #  174000/600000    time:47.92
# loss:1.46e-04, loss_ics:3.24e-07, loss_res:1.00e+01, loss_energy_value:1.771386e-06
# Epoch #  175000/600000    time:47.94
# loss:1.32e-04, loss_ics:1.56e-07, loss_res:9.91e+00, loss_energy_value:1.024929e-06
# Epoch #  176000/600000    time:48.09
# loss:1.31e-04, loss_ics:2.09e-07, loss_res:9.82e+00, loss_energy_value:6.015886e-07
# Epoch #  177000/600000    time:47.99
# loss:1.24e-04, loss_ics:1.24e-07, loss_res:9.88e+00, loss_energy_value:2.306074e-06
# Epoch #  178000/600000    time:47.87
# loss:1.24e-04, loss_ics:1.52e-07, loss_res:9.60e+00, loss_energy_value:3.047516e-06
# Epoch #  179000/600000    time:48.06
# loss:1.35e-04, loss_ics:1.02e-07, loss_res:9.58e+00, loss_energy_value:4.202144e-07
# Epoch #  180000/600000    time:47.91
# loss:1.29e-04, loss_ics:1.94e-07, loss_res:9.53e+00, loss_energy_value:5.139893e-07
# Epoch #  181000/600000    time:47.85
# loss:1.13e-04, loss_ics:8.14e-08, loss_res:9.40e+00, loss_energy_value:3.386957e-07
# Epoch #  182000/600000    time:47.88
# loss:1.19e-04, loss_ics:1.00e-07, loss_res:9.22e+00, loss_energy_value:1.351959e-06
# Epoch #  183000/600000    time:47.77
# loss:1.20e-04, loss_ics:1.23e-07, loss_res:9.03e+00, loss_energy_value:2.042938e-06
# Epoch #  184000/600000    time:47.95
# loss:1.26e-04, loss_ics:1.15e-07, loss_res:8.92e+00, loss_energy_value:7.123575e-07
# Epoch #  185000/600000    time:47.88
# loss:1.47e-04, loss_ics:3.73e-07, loss_res:8.94e+00, loss_energy_value:2.657300e-06
# Epoch #  186000/600000    time:48.01
# loss:1.27e-04, loss_ics:7.33e-08, loss_res:8.59e+00, loss_energy_value:8.427343e-07
# Epoch #  187000/600000    time:48.03
# loss:1.31e-04, loss_ics:1.59e-07, loss_res:8.46e+00, loss_energy_value:6.506798e-07
# Epoch #  188000/600000    time:48.21
# loss:1.25e-04, loss_ics:1.78e-07, loss_res:8.44e+00, loss_energy_value:7.566421e-07
# Epoch #  189000/600000    time:48.21
# loss:1.31e-04, loss_ics:1.88e-07, loss_res:8.32e+00, loss_energy_value:1.439656e-06
# Epoch #  190000/600000    time:48.02
# loss:1.28e-04, loss_ics:1.39e-07, loss_res:8.28e+00, loss_energy_value:1.096833e-06
# Epoch #  191000/600000    time:47.92
# loss:1.25e-04, loss_ics:3.57e-08, loss_res:8.09e+00, loss_energy_value:2.951292e-07
# Epoch #  192000/600000    time:48.17
# loss:1.40e-04, loss_ics:2.55e-07, loss_res:7.87e+00, loss_energy_value:6.404167e-06
# Epoch #  193000/600000    time:47.89
# loss:1.24e-04, loss_ics:1.78e-07, loss_res:7.77e+00, loss_energy_value:1.485509e-06
# Epoch #  194000/600000    time:47.87
# loss:1.40e-04, loss_ics:2.07e-07, loss_res:7.60e+00, loss_energy_value:1.015759e-05
# Epoch #  195000/600000    time:48.26
# loss:1.45e-04, loss_ics:2.43e-07, loss_res:7.45e+00, loss_energy_value:4.305254e-07
# Epoch #  196000/600000    time:47.87
# loss:1.34e-04, loss_ics:2.44e-07, loss_res:7.33e+00, loss_energy_value:3.359414e-06
# Epoch #  197000/600000    time:48.10
# loss:1.37e-04, loss_ics:1.97e-07, loss_res:7.26e+00, loss_energy_value:5.884112e-07
# Epoch #  198000/600000    time:48.16
# loss:1.36e-04, loss_ics:1.57e-07, loss_res:7.09e+00, loss_energy_value:1.232102e-06
# Epoch #  199000/600000    time:47.97
# loss:1.29e-04, loss_ics:1.90e-07, loss_res:6.97e+00, loss_energy_value:4.294854e-07
# Epoch #  200000/600000    time:48.02
# loss:1.25e-04, loss_ics:3.58e-08, loss_res:6.91e+00, loss_energy_value:3.474717e-07
# Epoch #  201000/600000    time:47.98
# loss:1.21e-04, loss_ics:1.14e-07, loss_res:6.74e+00, loss_energy_value:2.171984e-06
# Epoch #  202000/600000    time:48.08
# loss:1.58e-04, loss_ics:3.85e-07, loss_res:6.57e+00, loss_energy_value:1.599378e-06
# Epoch #  203000/600000    time:48.16
# loss:1.34e-04, loss_ics:1.39e-07, loss_res:6.39e+00, loss_energy_value:1.278170e-06
# Epoch #  204000/600000    time:48.01
# loss:1.23e-04, loss_ics:1.43e-08, loss_res:6.19e+00, loss_energy_value:5.659750e-07
# Epoch #  205000/600000    time:48.02
# loss:1.27e-04, loss_ics:1.37e-07, loss_res:6.03e+00, loss_energy_value:2.429992e-06
# Epoch #  206000/600000    time:47.89
# loss:1.32e-04, loss_ics:2.08e-07, loss_res:5.93e+00, loss_energy_value:1.725595e-06
# Epoch #  207000/600000    time:47.92
# loss:1.21e-04, loss_ics:1.25e-07, loss_res:5.75e+00, loss_energy_value:3.799295e-06
# Epoch #  208000/600000    time:47.79
# loss:1.53e-04, loss_ics:3.86e-07, loss_res:5.61e+00, loss_energy_value:1.884396e-06
# Epoch #  209000/600000    time:47.85
# loss:1.28e-04, loss_ics:1.32e-07, loss_res:5.45e+00, loss_energy_value:1.067487e-05
# Epoch #  210000/600000    time:47.84
# loss:1.18e-04, loss_ics:9.12e-08, loss_res:5.35e+00, loss_energy_value:2.901350e-06
# Epoch #  211000/600000    time:47.76
# loss:1.32e-04, loss_ics:4.05e-08, loss_res:5.03e+00, loss_energy_value:7.039403e-07
# Epoch #  212000/600000    time:47.74
# loss:1.15e-04, loss_ics:2.55e-08, loss_res:4.69e+00, loss_energy_value:1.318298e-06
# Epoch #  213000/600000    time:47.65
# loss:1.21e-04, loss_ics:3.76e-08, loss_res:4.32e+00, loss_energy_value:1.249037e-06
# Epoch #  214000/600000    time:47.61
# loss:1.27e-04, loss_ics:5.22e-08, loss_res:4.03e+00, loss_energy_value:7.023592e-07
# Epoch #  215000/600000    time:47.82
# loss:1.13e-04, loss_ics:4.36e-08, loss_res:3.79e+00, loss_energy_value:7.145655e-07
# Epoch #  216000/600000    time:47.94
# loss:1.21e-04, loss_ics:1.37e-07, loss_res:3.66e+00, loss_energy_value:2.520010e-06
# Epoch #  217000/600000    time:48.04
# loss:1.19e-04, loss_ics:9.48e-08, loss_res:3.64e+00, loss_energy_value:1.299803e-07
# Epoch #  218000/600000    time:47.95
# loss:1.26e-04, loss_ics:1.39e-07, loss_res:3.58e+00, loss_energy_value:6.091490e-07
# Epoch #  219000/600000    time:47.87
# loss:1.29e-04, loss_ics:1.85e-07, loss_res:3.52e+00, loss_energy_value:7.399543e-08
# Epoch #  220000/600000    time:47.96
# loss:1.38e-04, loss_ics:2.18e-07, loss_res:3.47e+00, loss_energy_value:2.295427e-07
# Epoch #  221000/600000    time:47.97
# loss:1.22e-04, loss_ics:1.40e-07, loss_res:3.37e+00, loss_energy_value:1.435383e-06
# Epoch #  222000/600000    time:47.80
# loss:1.18e-04, loss_ics:7.26e-08, loss_res:3.29e+00, loss_energy_value:5.912959e-07
# Epoch #  223000/600000    time:47.88
# loss:1.29e-04, loss_ics:2.02e-07, loss_res:3.19e+00, loss_energy_value:3.029009e-06
# Epoch #  224000/600000    time:47.80
# loss:1.31e-04, loss_ics:1.48e-07, loss_res:3.07e+00, loss_energy_value:8.298309e-08
# Epoch #  225000/600000    time:48.79
# loss:1.35e-04, loss_ics:1.35e-07, loss_res:2.98e+00, loss_energy_value:3.742739e-07
# Epoch #  226000/600000    time:47.78
# loss:1.17e-04, loss_ics:9.09e-08, loss_res:2.91e+00, loss_energy_value:7.376317e-08
# Epoch #  227000/600000    time:48.11
# loss:1.22e-04, loss_ics:5.21e-08, loss_res:2.82e+00, loss_energy_value:1.465249e-07
# Epoch #  228000/600000    time:47.85
# loss:1.27e-04, loss_ics:1.70e-07, loss_res:2.78e+00, loss_energy_value:1.318754e-07
# Epoch #  229000/600000    time:48.02
# loss:1.16e-04, loss_ics:5.84e-08, loss_res:2.72e+00, loss_energy_value:2.459536e-07
# Epoch #  230000/600000    time:48.12
# loss:1.43e-04, loss_ics:3.34e-07, loss_res:2.64e+00, loss_energy_value:2.413246e-06
# Epoch #  231000/600000    time:47.70
# loss:1.15e-04, loss_ics:5.79e-08, loss_res:2.53e+00, loss_energy_value:2.087149e-06
# Epoch #  232000/600000    time:47.73
# loss:1.26e-04, loss_ics:1.94e-07, loss_res:2.42e+00, loss_energy_value:2.282910e-07
# Epoch #  233000/600000    time:47.78
# loss:1.22e-04, loss_ics:1.44e-07, loss_res:2.37e+00, loss_energy_value:2.207700e-06
# Epoch #  234000/600000    time:47.85
# loss:1.31e-04, loss_ics:4.71e-08, loss_res:2.24e+00, loss_energy_value:3.069603e-07
# Epoch #  235000/600000    time:47.95
# loss:1.22e-04, loss_ics:7.30e-08, loss_res:2.13e+00, loss_energy_value:4.393708e-07
# Epoch #  236000/600000    time:47.94
# loss:1.19e-04, loss_ics:1.48e-08, loss_res:2.03e+00, loss_energy_value:8.504470e-07
# Epoch #  237000/600000    time:47.84
# loss:1.19e-04, loss_ics:2.71e-08, loss_res:1.95e+00, loss_energy_value:2.832207e-07
# Epoch #  238000/600000    time:47.70
# loss:1.27e-04, loss_ics:4.80e-08, loss_res:1.87e+00, loss_energy_value:1.360308e-07
# Epoch #  239000/600000    time:47.76
# loss:1.26e-04, loss_ics:8.42e-08, loss_res:1.81e+00, loss_energy_value:8.668650e-07
# Epoch #  240000/600000    time:47.79
# loss:1.40e-04, loss_ics:1.39e-07, loss_res:1.75e+00, loss_energy_value:2.011467e-07
# Epoch #  241000/600000    time:47.63
# loss:1.20e-04, loss_ics:2.53e-08, loss_res:1.67e+00, loss_energy_value:1.437546e-07
# Epoch #  242000/600000    time:47.90
# loss:1.20e-04, loss_ics:3.46e-08, loss_res:1.59e+00, loss_energy_value:8.387883e-07
# Epoch #  243000/600000    time:47.79
# loss:1.24e-04, loss_ics:4.33e-08, loss_res:1.53e+00, loss_energy_value:5.900274e-07
# Epoch #  244000/600000    time:47.75
# loss:1.18e-04, loss_ics:1.81e-08, loss_res:1.46e+00, loss_energy_value:6.506619e-08
# Epoch #  245000/600000    time:47.84
# loss:1.21e-04, loss_ics:2.81e-08, loss_res:1.40e+00, loss_energy_value:1.124946e-07
# Epoch #  246000/600000    time:47.74
# loss:1.18e-04, loss_ics:3.97e-08, loss_res:1.34e+00, loss_energy_value:6.580300e-07
# Epoch #  247000/600000    time:47.76
# loss:1.15e-04, loss_ics:1.42e-08, loss_res:1.28e+00, loss_energy_value:7.442816e-07
# Epoch #  248000/600000    time:48.40
# loss:1.19e-04, loss_ics:1.47e-08, loss_res:1.23e+00, loss_energy_value:5.767577e-07
# Epoch #  249000/600000    time:48.08
# loss:1.19e-04, loss_ics:5.10e-08, loss_res:1.17e+00, loss_energy_value:9.373376e-07
# Epoch #  250000/600000    time:47.73
# loss:1.26e-04, loss_ics:7.60e-08, loss_res:1.12e+00, loss_energy_value:7.558878e-08
# Epoch #  251000/600000    time:47.82
# loss:1.20e-04, loss_ics:2.28e-08, loss_res:1.06e+00, loss_energy_value:1.014602e-07
# Epoch #  252000/600000    time:47.78
# loss:1.23e-04, loss_ics:6.60e-08, loss_res:1.01e+00, loss_energy_value:2.738046e-07
# Epoch #  253000/600000    time:47.96
# loss:1.17e-04, loss_ics:4.35e-08, loss_res:9.63e-01, loss_energy_value:2.360792e-07
# Epoch #  254000/600000    time:47.73
# loss:1.19e-04, loss_ics:3.78e-08, loss_res:9.18e-01, loss_energy_value:2.324418e-07
# Epoch #  255000/600000    time:47.80
# loss:1.26e-04, loss_ics:7.37e-08, loss_res:8.73e-01, loss_energy_value:1.515762e-07
# Epoch #  256000/600000    time:47.80
# loss:1.31e-04, loss_ics:1.54e-07, loss_res:8.32e-01, loss_energy_value:4.286640e-07
# Epoch #  257000/600000    time:47.84
# loss:1.21e-04, loss_ics:2.02e-08, loss_res:7.96e-01, loss_energy_value:5.143693e-07
# Epoch #  258000/600000    time:47.98
# loss:1.17e-04, loss_ics:3.61e-08, loss_res:7.60e-01, loss_energy_value:7.000368e-07
# Epoch #  259000/600000    time:47.86
# loss:1.24e-04, loss_ics:7.84e-08, loss_res:7.25e-01, loss_energy_value:2.697173e-07
# Epoch #  260000/600000    time:47.79
# loss:1.26e-04, loss_ics:6.55e-08, loss_res:6.87e-01, loss_energy_value:6.757245e-07
# Epoch #  261000/600000    time:48.01
# loss:1.22e-04, loss_ics:4.95e-08, loss_res:6.46e-01, loss_energy_value:8.335051e-07
# Epoch #  262000/600000    time:47.99
# loss:1.18e-04, loss_ics:1.62e-08, loss_res:6.11e-01, loss_energy_value:1.311802e-07
# Epoch #  263000/600000    time:48.08
# loss:1.21e-04, loss_ics:4.59e-08, loss_res:5.77e-01, loss_energy_value:1.853794e-07
# Epoch #  264000/600000    time:48.07
# loss:1.17e-04, loss_ics:5.67e-09, loss_res:5.45e-01, loss_energy_value:8.622521e-08
# Epoch #  265000/600000    time:49.61
# loss:1.20e-04, loss_ics:4.01e-08, loss_res:5.13e-01, loss_energy_value:8.609172e-08
# Epoch #  266000/600000    time:49.67
# loss:1.25e-04, loss_ics:8.67e-08, loss_res:4.84e-01, loss_energy_value:9.159457e-07
# Epoch #  267000/600000    time:47.94
# loss:1.28e-04, loss_ics:1.18e-07, loss_res:4.57e-01, loss_energy_value:3.631684e-07
# Epoch #  268000/600000    time:47.89
# loss:1.24e-04, loss_ics:7.13e-08, loss_res:4.30e-01, loss_energy_value:4.831880e-07
# Epoch #  269000/600000    time:47.74
# loss:1.21e-04, loss_ics:3.72e-08, loss_res:4.06e-01, loss_energy_value:7.724105e-07
# Epoch #  270000/600000    time:48.31
# loss:1.23e-04, loss_ics:2.45e-08, loss_res:3.83e-01, loss_energy_value:4.322767e-08
# Epoch #  271000/600000    time:47.69
# loss:1.18e-04, loss_ics:1.51e-08, loss_res:3.56e-01, loss_energy_value:5.317168e-07
# Epoch #  272000/600000    time:47.87
# loss:1.20e-04, loss_ics:2.82e-08, loss_res:3.35e-01, loss_energy_value:3.743336e-08
# Epoch #  273000/600000    time:47.85
# loss:1.21e-04, loss_ics:4.17e-08, loss_res:3.13e-01, loss_energy_value:6.790104e-07
# Epoch #  274000/600000    time:47.88
# loss:1.26e-04, loss_ics:1.05e-07, loss_res:2.93e-01, loss_energy_value:2.250038e-07
# Epoch #  275000/600000    time:48.43
# loss:1.31e-04, loss_ics:1.39e-07, loss_res:2.76e-01, loss_energy_value:5.038029e-08
# Epoch #  276000/600000    time:48.40
# loss:1.18e-04, loss_ics:2.00e-08, loss_res:2.57e-01, loss_energy_value:5.023653e-07
# Epoch #  277000/600000    time:47.95
# loss:1.17e-04, loss_ics:1.29e-08, loss_res:2.41e-01, loss_energy_value:4.236450e-07
# Epoch #  278000/600000    time:48.19
# loss:1.22e-04, loss_ics:5.80e-08, loss_res:2.25e-01, loss_energy_value:8.281675e-07
# Epoch #  279000/600000    time:47.91
# loss:1.18e-04, loss_ics:2.37e-08, loss_res:2.10e-01, loss_energy_value:6.974125e-07
# Epoch #  280000/600000    time:47.76
# loss:1.23e-04, loss_ics:5.30e-08, loss_res:1.97e-01, loss_energy_value:1.209290e-07
# Epoch #  281000/600000    time:47.57
# loss:1.18e-04, loss_ics:1.66e-08, loss_res:1.81e-01, loss_energy_value:5.164225e-07
# Epoch #  282000/600000    time:47.46
# loss:1.23e-04, loss_ics:7.19e-08, loss_res:1.68e-01, loss_energy_value:7.858062e-08
# Epoch #  283000/600000    time:47.46
# loss:1.21e-04, loss_ics:4.84e-08, loss_res:1.55e-01, loss_energy_value:5.818378e-07
# Epoch #  284000/600000    time:47.40
# loss:1.19e-04, loss_ics:2.86e-08, loss_res:1.44e-01, loss_energy_value:8.467878e-08
# Epoch #  285000/600000    time:47.41
# loss:1.18e-04, loss_ics:1.81e-08, loss_res:1.33e-01, loss_energy_value:7.087257e-08
# Epoch #  286000/600000    time:47.61
# loss:1.18e-04, loss_ics:2.71e-08, loss_res:1.23e-01, loss_energy_value:7.791372e-08
# Epoch #  287000/600000    time:47.75
# loss:1.17e-04, loss_ics:1.21e-08, loss_res:1.12e-01, loss_energy_value:4.348603e-07
# Epoch #  288000/600000    time:47.49
# loss:1.25e-04, loss_ics:9.46e-08, loss_res:1.04e-01, loss_energy_value:1.315428e-07
# Epoch #  289000/600000    time:47.64
# loss:1.24e-04, loss_ics:8.05e-08, loss_res:9.52e-02, loss_energy_value:6.895097e-07
# Epoch #  290000/600000    time:47.74
# loss:1.19e-04, loss_ics:2.08e-08, loss_res:8.69e-02, loss_energy_value:2.982862e-07
# Epoch #  291000/600000    time:47.61
# loss:1.18e-04, loss_ics:1.87e-08, loss_res:7.81e-02, loss_energy_value:5.773708e-08
# Epoch #  292000/600000    time:47.73
# loss:1.19e-04, loss_ics:2.60e-08, loss_res:7.04e-02, loss_energy_value:5.792960e-07
# Epoch #  293000/600000    time:47.66
# loss:1.21e-04, loss_ics:4.40e-08, loss_res:6.34e-02, loss_energy_value:6.887085e-07
# Epoch #  294000/600000    time:47.57
# loss:1.18e-04, loss_ics:1.39e-08, loss_res:5.72e-02, loss_energy_value:1.438072e-08
# Epoch #  295000/600000    time:47.59
# loss:1.16e-04, loss_ics:1.23e-08, loss_res:5.10e-02, loss_energy_value:5.023717e-07
# Epoch #  296000/600000    time:47.68
# loss:1.38e-04, loss_ics:2.34e-07, loss_res:4.59e-02, loss_energy_value:2.524676e-07
# Epoch #  297000/600000    time:47.69
# loss:1.25e-04, loss_ics:1.08e-07, loss_res:4.10e-02, loss_energy_value:4.649635e-08
# Epoch #  298000/600000    time:47.69
# loss:1.17e-04, loss_ics:1.88e-08, loss_res:3.63e-02, loss_energy_value:3.613830e-08
# Epoch #  299000/600000    time:47.62
# loss:1.17e-04, loss_ics:1.26e-08, loss_res:3.24e-02, loss_energy_value:2.796102e-08
# Epoch #  300000/600000    time:47.70
# loss:1.18e-04, loss_ics:1.20e-08, loss_res:2.83e-02, loss_energy_value:4.052911e-07
# Epoch #  301000/600000    time:47.49
# loss:1.17e-04, loss_ics:8.22e-09, loss_res:2.43e-02, loss_energy_value:3.397423e-07
# Epoch #  302000/600000    time:47.68
# loss:1.23e-04, loss_ics:7.26e-08, loss_res:2.11e-02, loss_energy_value:4.745041e-07
# Epoch #  303000/600000    time:47.52
# loss:1.17e-04, loss_ics:1.45e-08, loss_res:1.82e-02, loss_energy_value:4.752445e-07
# Epoch #  304000/600000    time:47.83
# loss:1.17e-04, loss_ics:1.05e-08, loss_res:1.57e-02, loss_energy_value:3.623152e-07
# Epoch #  305000/600000    time:48.21
# loss:1.17e-04, loss_ics:1.73e-08, loss_res:1.36e-02, loss_energy_value:3.084417e-08
# Epoch #  306000/600000    time:47.84
# loss:1.22e-04, loss_ics:6.52e-08, loss_res:1.16e-02, loss_energy_value:5.910642e-07
# Epoch #  307000/600000    time:47.75
# loss:1.31e-04, loss_ics:1.48e-07, loss_res:9.87e-03, loss_energy_value:9.089610e-07
# Epoch #  308000/600000    time:47.74
# loss:1.17e-04, loss_ics:1.69e-08, loss_res:8.47e-03, loss_energy_value:1.345406e-08
# Epoch #  309000/600000    time:46.00
# loss:1.23e-04, loss_ics:7.23e-08, loss_res:7.07e-03, loss_energy_value:3.301671e-07
# Epoch #  310000/600000    time:47.19
# loss:1.19e-04, loss_ics:2.32e-08, loss_res:6.02e-03, loss_energy_value:2.380427e-08
# Epoch #  311000/600000    time:47.92
# loss:1.18e-04, loss_ics:2.76e-08, loss_res:4.86e-03, loss_energy_value:5.162726e-07
# Epoch #  312000/600000    time:47.82
# loss:1.28e-04, loss_ics:1.19e-07, loss_res:4.03e-03, loss_energy_value:5.001564e-07
# Epoch #  313000/600000    time:47.54
# loss:1.17e-04, loss_ics:1.09e-08, loss_res:3.30e-03, loss_energy_value:6.277043e-09
# Epoch #  314000/600000    time:47.77
# loss:1.17e-04, loss_ics:1.57e-08, loss_res:2.69e-03, loss_energy_value:4.074944e-07
# Epoch #  315000/600000    time:47.58
# loss:1.19e-04, loss_ics:4.23e-08, loss_res:2.20e-03, loss_energy_value:4.930616e-07
# Epoch #  316000/600000    time:47.74
# loss:1.20e-04, loss_ics:4.19e-08, loss_res:1.77e-03, loss_energy_value:2.764172e-07
# Epoch #  317000/600000    time:47.76
# loss:1.19e-04, loss_ics:3.81e-08, loss_res:1.45e-03, loss_energy_value:4.918911e-07
# Epoch #  318000/600000    time:47.65
# loss:1.29e-04, loss_ics:1.33e-07, loss_res:1.18e-03, loss_energy_value:5.290917e-07
# Epoch #  319000/600000    time:47.57
# loss:1.16e-04, loss_ics:1.06e-08, loss_res:9.70e-04, loss_energy_value:3.020730e-08
# Epoch #  320000/600000    time:47.75
# loss:1.17e-04, loss_ics:1.16e-08, loss_res:7.69e-04, loss_energy_value:2.443121e-07
# Epoch #  321000/600000    time:47.66
# loss:1.15e-04, loss_ics:9.11e-09, loss_res:6.19e-04, loss_energy_value:3.030022e-07
# Epoch #  322000/600000    time:47.84
# loss:1.14e-04, loss_ics:2.25e-08, loss_res:5.30e-04, loss_energy_value:3.867520e-08
# Epoch #  323000/600000    time:47.77
# loss:1.16e-04, loss_ics:5.71e-08, loss_res:4.48e-04, loss_energy_value:1.827634e-08
# Epoch #  324000/600000    time:47.77
# loss:1.12e-04, loss_ics:4.74e-08, loss_res:3.98e-04, loss_energy_value:3.068801e-08
# Epoch #  325000/600000    time:48.20
# loss:1.07e-04, loss_ics:2.06e-08, loss_res:3.47e-04, loss_energy_value:3.719811e-07
# Epoch #  326000/600000    time:48.54
# loss:1.06e-04, loss_ics:2.83e-08, loss_res:3.14e-04, loss_energy_value:3.205646e-07
# Epoch #  327000/600000    time:47.93
# loss:1.02e-04, loss_ics:1.45e-08, loss_res:2.85e-04, loss_energy_value:3.649627e-08
# Epoch #  328000/600000    time:47.52
# loss:1.00e-04, loss_ics:1.55e-08, loss_res:2.70e-04, loss_energy_value:5.358522e-08
# Epoch #  329000/600000    time:47.58
# loss:1.00e-04, loss_ics:4.00e-08, loss_res:2.45e-04, loss_energy_value:2.863704e-07
# Epoch #  330000/600000    time:47.41
# loss:9.50e-05, loss_ics:1.49e-08, loss_res:2.22e-04, loss_energy_value:2.210366e-07
# Epoch #  331000/600000    time:47.48
# loss:9.70e-05, loss_ics:5.26e-08, loss_res:2.11e-04, loss_energy_value:2.797040e-07
# Epoch #  332000/600000    time:47.51
# loss:9.13e-05, loss_ics:9.42e-09, loss_res:2.04e-04, loss_energy_value:5.150956e-08
# Epoch #  333000/600000    time:47.63
# loss:9.75e-05, loss_ics:8.65e-08, loss_res:1.93e-04, loss_energy_value:4.662430e-07
# Epoch #  334000/600000    time:47.52
# loss:8.92e-05, loss_ics:2.82e-08, loss_res:1.82e-04, loss_energy_value:1.123126e-07
# Epoch #  335000/600000    time:47.65
# loss:8.85e-05, loss_ics:2.88e-08, loss_res:1.78e-04, loss_energy_value:8.845014e-08
# Epoch #  336000/600000    time:47.67
# loss:8.61e-05, loss_ics:1.85e-08, loss_res:1.72e-04, loss_energy_value:1.882566e-07
# Epoch #  337000/600000    time:47.62
# loss:8.50e-05, loss_ics:1.94e-08, loss_res:1.66e-04, loss_energy_value:5.578000e-08
# Epoch #  338000/600000    time:47.53
# loss:8.23e-05, loss_ics:1.16e-08, loss_res:1.57e-04, loss_energy_value:1.975043e-07
# Epoch #  339000/600000    time:47.51
# loss:8.77e-05, loss_ics:7.08e-08, loss_res:1.54e-04, loss_energy_value:2.174641e-07
# Epoch #  340000/600000    time:47.51
# loss:7.94e-05, loss_ics:2.59e-08, loss_res:1.39e-04, loss_energy_value:2.349581e-08
# Epoch #  341000/600000    time:47.48
# loss:7.73e-05, loss_ics:7.53e-09, loss_res:1.39e-04, loss_energy_value:3.702585e-08
# Epoch #  342000/600000    time:47.43
# loss:7.58e-05, loss_ics:6.79e-09, loss_res:1.34e-04, loss_energy_value:1.410671e-07
# Epoch #  343000/600000    time:47.42
# loss:9.16e-05, loss_ics:1.71e-07, loss_res:1.31e-04, loss_energy_value:5.860936e-08
# Epoch #  344000/600000    time:47.56
# loss:7.58e-05, loss_ics:2.17e-08, loss_res:1.28e-04, loss_energy_value:7.930026e-08
# Epoch #  345000/600000    time:47.44
# loss:7.37e-05, loss_ics:1.86e-08, loss_res:1.22e-04, loss_energy_value:1.412111e-07
# Epoch #  346000/600000    time:47.60
# loss:7.39e-05, loss_ics:2.46e-08, loss_res:1.21e-04, loss_energy_value:2.225241e-07
# Epoch #  347000/600000    time:45.85
# loss:7.11e-05, loss_ics:6.65e-09, loss_res:1.18e-04, loss_energy_value:1.113489e-07
# Epoch #  348000/600000    time:44.87
# loss:7.14e-05, loss_ics:1.50e-08, loss_res:1.17e-04, loss_energy_value:7.534771e-08
# Epoch #  349000/600000    time:44.89
# loss:7.04e-05, loss_ics:1.68e-08, loss_res:1.13e-04, loss_energy_value:1.246876e-07
# Epoch #  350000/600000    time:47.50
# loss:6.75e-05, loss_ics:1.51e-08, loss_res:1.05e-04, loss_energy_value:1.056103e-07
# Epoch #  351000/600000    time:48.54
# loss:6.76e-05, loss_ics:1.96e-08, loss_res:1.04e-04, loss_energy_value:1.662269e-07
# Epoch #  352000/600000    time:49.17
# loss:6.74e-05, loss_ics:1.91e-08, loss_res:1.04e-04, loss_energy_value:6.563051e-08
# Epoch #  353000/600000    time:48.55
# loss:6.97e-05, loss_ics:5.38e-08, loss_res:1.01e-04, loss_energy_value:3.365052e-08
# Epoch #  354000/600000    time:47.70
# loss:6.85e-05, loss_ics:5.01e-08, loss_res:9.86e-05, loss_energy_value:1.339129e-07
# Epoch #  355000/600000    time:47.59
# loss:6.57e-05, loss_ics:2.56e-08, loss_res:9.79e-05, loss_energy_value:4.844740e-08
# Epoch #  356000/600000    time:47.63
# loss:6.48e-05, loss_ics:2.10e-08, loss_res:9.66e-05, loss_energy_value:7.786192e-08
# Epoch #  357000/600000    time:47.55
# loss:6.37e-05, loss_ics:1.99e-08, loss_res:9.41e-05, loss_energy_value:1.515243e-07
# Epoch #  358000/600000    time:48.39
# loss:6.20e-05, loss_ics:1.18e-08, loss_res:9.20e-05, loss_energy_value:5.207815e-08
# Epoch #  359000/600000    time:47.46
# loss:6.11e-05, loss_ics:6.99e-09, loss_res:9.11e-05, loss_energy_value:5.242260e-08
# Epoch #  360000/600000    time:47.80
# loss:5.78e-05, loss_ics:6.86e-09, loss_res:8.33e-05, loss_energy_value:2.678832e-08
# Epoch #  361000/600000    time:47.90
# loss:5.87e-05, loss_ics:5.19e-09, loss_res:8.58e-05, loss_energy_value:2.677320e-08
# Epoch #  362000/600000    time:47.93
# loss:6.22e-05, loss_ics:3.07e-08, loss_res:8.81e-05, loss_energy_value:8.473378e-08
# Epoch #  363000/600000    time:47.88
# loss:5.80e-05, loss_ics:1.12e-08, loss_res:8.28e-05, loss_energy_value:5.436048e-08
# Epoch #  364000/600000    time:47.87
# loss:5.74e-05, loss_ics:1.03e-08, loss_res:8.17e-05, loss_energy_value:4.464326e-08
# Epoch #  365000/600000    time:47.83
# loss:5.61e-05, loss_ics:1.24e-08, loss_res:7.84e-05, loss_energy_value:1.256790e-07
# Epoch #  366000/600000    time:48.18
# loss:5.61e-05, loss_ics:1.22e-08, loss_res:7.86e-05, loss_energy_value:4.968658e-08
# Epoch #  367000/600000    time:47.85
# loss:5.65e-05, loss_ics:2.31e-08, loss_res:7.71e-05, loss_energy_value:5.329880e-08
# Epoch #  368000/600000    time:47.97
# loss:5.61e-05, loss_ics:1.64e-08, loss_res:7.75e-05, loss_energy_value:1.149952e-07
# Epoch #  369000/600000    time:47.87
# loss:5.68e-05, loss_ics:3.63e-08, loss_res:7.48e-05, loss_energy_value:4.424896e-08
# Epoch #  370000/600000    time:47.68
# loss:5.20e-05, loss_ics:8.02e-09, loss_res:7.08e-05, loss_energy_value:6.926599e-08
# Epoch #  371000/600000    time:48.83
# loss:5.27e-05, loss_ics:1.47e-08, loss_res:7.07e-05, loss_energy_value:1.204161e-07
# Epoch #  372000/600000    time:48.32
# loss:5.13e-05, loss_ics:2.63e-08, loss_res:6.59e-05, loss_energy_value:4.341128e-08
# Epoch #  373000/600000    time:48.02
# loss:5.28e-05, loss_ics:2.20e-08, loss_res:6.97e-05, loss_energy_value:7.437386e-08
# Epoch #  374000/600000    time:47.82
# loss:5.06e-05, loss_ics:4.72e-09, loss_res:6.88e-05, loss_energy_value:2.667251e-08
# Epoch #  375000/600000    time:47.50
# loss:5.03e-05, loss_ics:4.04e-09, loss_res:6.83e-05, loss_energy_value:2.764513e-08
# Epoch #  376000/600000    time:47.57
# loss:5.14e-05, loss_ics:1.24e-08, loss_res:6.89e-05, loss_energy_value:1.128915e-07
# Epoch #  377000/600000    time:49.00
# loss:4.86e-05, loss_ics:6.26e-09, loss_res:6.46e-05, loss_energy_value:3.284603e-08
# Epoch #  378000/600000    time:50.43
# loss:5.02e-05, loss_ics:1.31e-08, loss_res:6.62e-05, loss_energy_value:1.097241e-07
# Epoch #  379000/600000    time:47.46
# loss:4.79e-05, loss_ics:1.09e-08, loss_res:6.25e-05, loss_energy_value:1.574686e-08
# Epoch #  380000/600000    time:47.40
# loss:4.64e-05, loss_ics:8.51e-09, loss_res:6.02e-05, loss_energy_value:1.979434e-08
# Epoch #  381000/600000    time:47.65
# loss:4.77e-05, loss_ics:1.23e-08, loss_res:6.19e-05, loss_energy_value:3.461049e-08
# Epoch #  382000/600000    time:47.54
# loss:4.62e-05, loss_ics:5.95e-09, loss_res:6.04e-05, loss_energy_value:2.428477e-08
# Epoch #  383000/600000    time:47.57
# loss:4.81e-05, loss_ics:1.34e-08, loss_res:6.25e-05, loss_energy_value:4.966616e-08
# Epoch #  384000/600000    time:47.57
# loss:4.65e-05, loss_ics:1.17e-08, loss_res:5.98e-05, loss_energy_value:3.280266e-08
# Epoch #  385000/600000    time:47.76
# loss:4.47e-05, loss_ics:4.59e-09, loss_res:5.79e-05, loss_energy_value:1.168791e-08
# Epoch #  386000/600000    time:47.64
# loss:4.51e-05, loss_ics:5.31e-09, loss_res:5.84e-05, loss_energy_value:5.638590e-08
# Epoch #  387000/600000    time:47.61
# loss:4.52e-05, loss_ics:1.53e-08, loss_res:5.70e-05, loss_energy_value:2.290161e-08
# Epoch #  388000/600000    time:47.66
# loss:4.44e-05, loss_ics:1.61e-08, loss_res:5.54e-05, loss_energy_value:2.501122e-08
# Epoch #  389000/600000    time:47.60
# loss:4.39e-05, loss_ics:6.69e-09, loss_res:5.62e-05, loss_energy_value:6.081046e-08
# Epoch #  390000/600000    time:47.55
# loss:4.26e-05, loss_ics:8.53e-09, loss_res:5.36e-05, loss_energy_value:5.524524e-08
# Epoch #  391000/600000    time:47.54
# loss:4.31e-05, loss_ics:4.92e-09, loss_res:5.51e-05, loss_energy_value:2.035912e-08
# Epoch #  392000/600000    time:48.39
# loss:4.28e-05, loss_ics:5.92e-09, loss_res:5.43e-05, loss_energy_value:5.634762e-08
# Epoch #  393000/600000    time:49.05
# loss:4.18e-05, loss_ics:5.06e-09, loss_res:5.29e-05, loss_energy_value:4.794131e-08
# Epoch #  394000/600000    time:49.05
# loss:4.18e-05, loss_ics:7.15e-09, loss_res:5.25e-05, loss_energy_value:3.428783e-08
# Epoch #  395000/600000    time:48.14
# loss:4.23e-05, loss_ics:1.25e-08, loss_res:5.24e-05, loss_energy_value:5.099411e-08
# Epoch #  396000/600000    time:48.84
# loss:4.09e-05, loss_ics:1.11e-08, loss_res:5.03e-05, loss_energy_value:2.578122e-08
# Epoch #  397000/600000    time:48.74
# ...
# Epoch #  468000/600000    time:47.82
# loss:2.52e-05, loss_ics:3.17e-09, loss_res:2.86e-05, loss_energy_value:5.894509e-09
# Epoch #  469000/600000    time:47.45
# loss:2.49e-05, loss_ics:4.25e-09, loss_res:2.79e-05, loss_energy_value:7.643097e-09
# Epoch #  470000/600000    time:47.61
# loss:2.47e-05, loss_ics:3.61e-09, loss_res:2.78e-05, loss_energy_value:3.536764e-09
# Epoch #  471000/600000    time:47.88
# loss:2.40e-05, loss_ics:3.02e-09, loss_res:2.69e-05, loss_energy_value:6.461335e-09
# Epoch #  472000/600000    time:47.49
# loss:2.37e-05, loss_ics:3.31e-09, loss_res:2.66e-05, loss_energy_value:1.431803e-09
# Epoch #  473000/600000    time:47.52
# loss:2.42e-05, loss_ics:3.61e-09, loss_res:2.71e-05, loss_energy_value:5.453396e-09
# Epoch #  474000/600000    time:47.43
# loss:2.43e-05, loss_ics:3.01e-09, loss_res:2.73e-05, loss_energy_value:7.401409e-09
# Epoch #  475000/600000    time:47.47
# loss:2.42e-05, loss_ics:4.27e-09, loss_res:2.70e-05, loss_energy_value:9.396556e-09
# Epoch #  476000/600000    time:49.95
# loss:2.39e-05, loss_ics:3.20e-09, loss_res:2.69e-05, loss_energy_value:6.571831e-09
# Epoch #  477000/600000    time:48.46
# loss:2.45e-05, loss_ics:3.76e-09, loss_res:2.75e-05, loss_energy_value:1.340057e-08
# Epoch #  478000/600000    time:47.79
# loss:2.33e-05, loss_ics:3.04e-09, loss_res:2.61e-05, loss_energy_value:2.034640e-09
# Epoch #  479000/600000    time:47.59
# loss:2.44e-05, loss_ics:4.10e-09, loss_res:2.73e-05, loss_energy_value:1.960158e-08
# Epoch #  480000/600000    time:47.56
# loss:2.35e-05, loss_ics:2.92e-09, loss_res:2.64e-05, loss_energy_value:4.895688e-09
# Epoch #  481000/600000    time:49.38
# loss:2.31e-05, loss_ics:2.86e-09, loss_res:2.58e-05, loss_energy_value:4.758551e-09
# Epoch #  482000/600000    time:47.61
# loss:2.32e-05, loss_ics:5.81e-09, loss_res:2.56e-05, loss_energy_value:1.344350e-09
# Epoch #  483000/600000    time:47.46
# loss:2.27e-05, loss_ics:3.42e-09, loss_res:2.53e-05, loss_energy_value:4.432618e-09
# Epoch #  484000/600000    time:48.66
# loss:2.31e-05, loss_ics:4.34e-09, loss_res:2.57e-05, loss_energy_value:4.497392e-09
# Epoch #  485000/600000    time:47.47
# loss:2.22e-05, loss_ics:2.78e-09, loss_res:2.47e-05, loss_energy_value:8.423044e-10
# Epoch #  486000/600000    time:47.45
# loss:2.27e-05, loss_ics:2.85e-09, loss_res:2.54e-05, loss_energy_value:7.655622e-09
# Epoch #  487000/600000    time:47.52
# loss:2.24e-05, loss_ics:2.57e-09, loss_res:2.50e-05, loss_energy_value:2.061421e-09
# Epoch #  488000/600000    time:47.55
# loss:2.24e-05, loss_ics:2.94e-09, loss_res:2.50e-05, loss_energy_value:7.473828e-09
# Epoch #  489000/600000    time:47.53
# loss:2.26e-05, loss_ics:5.83e-09, loss_res:2.48e-05, loss_energy_value:2.146638e-09
# Epoch #  490000/600000    time:47.50
# loss:2.31e-05, loss_ics:3.11e-09, loss_res:2.57e-05, loss_energy_value:1.324786e-08
# Epoch #  491000/600000    time:47.62
# loss:2.21e-05, loss_ics:2.72e-09, loss_res:2.45e-05, loss_energy_value:1.239116e-09
# Epoch #  492000/600000    time:47.54
# loss:2.21e-05, loss_ics:3.11e-09, loss_res:2.45e-05, loss_energy_value:8.140348e-09
# Epoch #  493000/600000    time:47.77
# loss:2.21e-05, loss_ics:3.12e-09, loss_res:2.46e-05, loss_energy_value:7.707370e-09
# Epoch #  494000/600000    time:47.83
# loss:2.19e-05, loss_ics:2.66e-09, loss_res:2.44e-05, loss_energy_value:3.110674e-09
# Epoch #  495000/600000    time:48.70
# loss:2.31e-05, loss_ics:4.07e-09, loss_res:2.56e-05, loss_energy_value:1.725869e-08
# Epoch #  496000/600000    time:47.64
# loss:2.13e-05, loss_ics:2.65e-09, loss_res:2.36e-05, loss_energy_value:1.692835e-09
# Epoch #  497000/600000    time:47.54
# loss:2.15e-05, loss_ics:2.50e-09, loss_res:2.39e-05, loss_energy_value:1.563823e-09
# Epoch #  498000/600000    time:47.54
# loss:2.23e-05, loss_ics:2.79e-09, loss_res:2.49e-05, loss_energy_value:8.338588e-09
# Epoch #  499000/600000    time:47.61
# loss:2.15e-05, loss_ics:3.06e-09, loss_res:2.38e-05, loss_energy_value:2.791845e-09
# Epoch #  500000/600000    time:47.62
# loss:2.10e-05, loss_ics:2.73e-09, loss_res:2.32e-05, loss_energy_value:3.240110e-09
# Epoch #  501000/600000    time:47.42
# loss:2.12e-05, loss_ics:2.52e-09, loss_res:2.35e-05, loss_energy_value:1.993374e-09
# Epoch #  502000/600000    time:47.49
# loss:2.12e-05, loss_ics:2.79e-09, loss_res:2.35e-05, loss_energy_value:4.852161e-09
# Epoch #  503000/600000    time:48.10
# loss:2.12e-05, loss_ics:2.47e-09, loss_res:2.34e-05, loss_energy_value:2.401936e-09
# Epoch #  504000/600000    time:47.97
# loss:2.09e-05, loss_ics:3.03e-09, loss_res:2.30e-05, loss_energy_value:4.417334e-09
# Epoch #  505000/600000    time:48.12
# loss:2.20e-05, loss_ics:5.02e-09, loss_res:2.41e-05, loss_energy_value:1.519568e-08
# Epoch #  506000/600000    time:47.98
# loss:2.11e-05, loss_ics:2.61e-09, loss_res:2.33e-05, loss_energy_value:5.589528e-09
# Epoch #  507000/600000    time:48.20
# loss:2.08e-05, loss_ics:2.89e-09, loss_res:2.29e-05, loss_energy_value:6.324694e-09
# Epoch #  508000/600000    time:48.02
# loss:2.12e-05, loss_ics:3.19e-09, loss_res:2.34e-05, loss_energy_value:1.227242e-08
# Epoch #  509000/600000    time:47.57
# loss:2.04e-05, loss_ics:2.60e-09, loss_res:2.24e-05, loss_energy_value:2.172273e-09
# Epoch #  510000/600000    time:47.86
# loss:2.03e-05, loss_ics:2.53e-09, loss_res:2.23e-05, loss_energy_value:3.197275e-09
# Epoch #  511000/600000    time:47.51
# loss:2.01e-05, loss_ics:2.48e-09, loss_res:2.20e-05, loss_energy_value:1.538975e-09
# Epoch #  512000/600000    time:48.90
# loss:2.04e-05, loss_ics:2.67e-09, loss_res:2.25e-05, loss_energy_value:5.319917e-09
# Epoch #  513000/600000    time:49.20
# loss:2.03e-05, loss_ics:2.74e-09, loss_res:2.23e-05, loss_energy_value:1.341112e-09
# Epoch #  514000/600000    time:48.93
# loss:2.00e-05, loss_ics:2.53e-09, loss_res:2.20e-05, loss_energy_value:3.704700e-09
# Epoch #  515000/600000    time:48.05
# loss:2.14e-05, loss_ics:4.44e-09, loss_res:2.35e-05, loss_energy_value:6.607511e-09
# Epoch #  516000/600000    time:48.63
# loss:2.01e-05, loss_ics:2.45e-09, loss_res:2.20e-05, loss_energy_value:1.789050e-09
# Epoch #  517000/600000    time:48.60
# loss:1.96e-05, loss_ics:2.46e-09, loss_res:2.15e-05, loss_energy_value:1.327012e-09
# Epoch #  518000/600000    time:48.66
# loss:2.02e-05, loss_ics:2.64e-09, loss_res:2.22e-05, loss_energy_value:7.091295e-09
# Epoch #  519000/600000    time:48.58
# loss:1.97e-05, loss_ics:2.49e-09, loss_res:2.16e-05, loss_energy_value:1.115441e-09
# Epoch #  520000/600000    time:48.55
# loss:1.97e-05, loss_ics:2.39e-09, loss_res:2.16e-05, loss_energy_value:1.730863e-09
# Epoch #  521000/600000    time:48.14
# loss:1.94e-05, loss_ics:2.36e-09, loss_res:2.12e-05, loss_energy_value:1.038627e-09
# Epoch #  522000/600000    time:47.54
# loss:1.95e-05, loss_ics:2.52e-09, loss_res:2.14e-05, loss_energy_value:1.626365e-09
# Epoch #  523000/600000    time:47.60
# loss:1.98e-05, loss_ics:2.75e-09, loss_res:2.17e-05, loss_energy_value:6.488914e-09
# Epoch #  524000/600000    time:47.50
# loss:1.95e-05, loss_ics:2.42e-09, loss_res:2.13e-05, loss_energy_value:1.663549e-09
# Epoch #  525000/600000    time:47.50
# loss:1.95e-05, loss_ics:2.27e-09, loss_res:2.13e-05, loss_energy_value:1.047678e-09
# Epoch #  526000/600000    time:48.04
# loss:1.92e-05, loss_ics:3.00e-09, loss_res:2.09e-05, loss_energy_value:1.565319e-09
# Epoch #  527000/600000    time:48.53
# loss:1.94e-05, loss_ics:2.75e-09, loss_res:2.12e-05, loss_energy_value:4.630886e-09
# Epoch #  528000/600000    time:48.25
# loss:1.91e-05, loss_ics:2.55e-09, loss_res:2.08e-05, loss_energy_value:8.035507e-10
# Epoch #  529000/600000    time:47.78
# loss:1.91e-05, loss_ics:2.67e-09, loss_res:2.08e-05, loss_energy_value:3.080264e-09
# Epoch #  530000/600000    time:48.29
# loss:1.89e-05, loss_ics:2.88e-09, loss_res:2.06e-05, loss_energy_value:6.969216e-10
# Epoch #  531000/600000    time:48.18
# loss:1.95e-05, loss_ics:2.72e-09, loss_res:2.13e-05, loss_energy_value:9.005300e-09
# Epoch #  532000/600000    time:48.75
# loss:1.87e-05, loss_ics:2.42e-09, loss_res:2.04e-05, loss_energy_value:9.505279e-10
# Epoch #  533000/600000    time:49.99
# loss:1.88e-05, loss_ics:2.46e-09, loss_res:2.05e-05, loss_energy_value:2.992758e-09
# Epoch #  534000/600000    time:49.29
# loss:1.89e-05, loss_ics:2.46e-09, loss_res:2.06e-05, loss_energy_value:4.444618e-09
# Epoch #  535000/600000    time:47.48
# loss:1.85e-05, loss_ics:2.56e-09, loss_res:2.01e-05, loss_energy_value:4.750177e-10
# Epoch #  536000/600000    time:47.55
# loss:1.85e-05, loss_ics:2.27e-09, loss_res:2.01e-05, loss_energy_value:1.066953e-09
# Epoch #  537000/600000    time:47.50
# loss:1.88e-05, loss_ics:3.61e-09, loss_res:2.03e-05, loss_energy_value:5.379654e-09
# Epoch #  538000/600000    time:47.51
# loss:1.83e-05, loss_ics:2.27e-09, loss_res:1.99e-05, loss_energy_value:1.052688e-09
# Epoch #  539000/600000    time:47.50
# loss:1.82e-05, loss_ics:2.26e-09, loss_res:1.98e-05, loss_energy_value:1.048639e-09
# Epoch #  540000/600000    time:47.49
# loss:1.82e-05, loss_ics:2.26e-09, loss_res:1.98e-05, loss_energy_value:1.040230e-09
# Epoch #  541000/600000    time:47.61
# loss:1.81e-05, loss_ics:2.25e-09, loss_res:1.97e-05, loss_energy_value:1.033142e-09
# Epoch #  542000/600000    time:47.53
# loss:1.81e-05, loss_ics:2.25e-09, loss_res:1.97e-05, loss_energy_value:1.031508e-09
# Epoch #  543000/600000    time:48.11
# loss:1.80e-05, loss_ics:2.24e-09, loss_res:1.96e-05, loss_energy_value:1.024188e-09
# Epoch #  544000/600000    time:49.10
# loss:1.86e-05, loss_ics:3.44e-09, loss_res:2.01e-05, loss_energy_value:1.035345e-08
# Epoch #  545000/600000    time:46.73
# loss:1.80e-05, loss_ics:2.23e-09, loss_res:1.95e-05, loss_energy_value:1.017180e-09
# Epoch #  546000/600000    time:44.88
# loss:1.79e-05, loss_ics:2.23e-09, loss_res:1.94e-05, loss_energy_value:1.009141e-09
# Epoch #  547000/600000    time:44.89
# loss:1.79e-05, loss_ics:2.22e-09, loss_res:1.94e-05, loss_energy_value:1.001516e-09
# Epoch #  548000/600000    time:49.77
# loss:1.78e-05, loss_ics:2.22e-09, loss_res:1.93e-05, loss_energy_value:1.002804e-09
# Epoch #  549000/600000    time:47.60
# loss:1.78e-05, loss_ics:2.21e-09, loss_res:1.93e-05, loss_energy_value:1.041571e-09
# Epoch #  550000/600000    time:47.79
# loss:1.77e-05, loss_ics:2.21e-09, loss_res:1.92e-05, loss_energy_value:9.881070e-10
# Epoch #  551000/600000    time:47.61
# loss:1.77e-05, loss_ics:2.20e-09, loss_res:1.91e-05, loss_energy_value:9.959059e-10
# Epoch #  552000/600000    time:47.52
# loss:1.76e-05, loss_ics:2.20e-09, loss_res:1.91e-05, loss_energy_value:9.800694e-10
# Epoch #  553000/600000    time:47.44
# loss:1.76e-05, loss_ics:2.19e-09, loss_res:1.90e-05, loss_energy_value:9.183183e-10
# Epoch #  554000/600000    time:47.49
# loss:1.75e-05, loss_ics:2.19e-09, loss_res:1.90e-05, loss_energy_value:9.717219e-10
# Epoch #  555000/600000    time:47.53
# loss:1.75e-05, loss_ics:2.19e-09, loss_res:1.89e-05, loss_energy_value:9.676157e-10
# Epoch #  556000/600000    time:47.53
# loss:1.90e-05, loss_ics:2.64e-09, loss_res:2.07e-05, loss_energy_value:4.443408e-09
# Epoch #  557000/600000    time:47.53
# loss:1.75e-05, loss_ics:2.33e-09, loss_res:1.89e-05, loss_energy_value:1.952355e-09
# Epoch #  558000/600000    time:47.58
# loss:1.74e-05, loss_ics:2.17e-09, loss_res:1.88e-05, loss_energy_value:9.510736e-10
# Epoch #  559000/600000    time:47.50
# loss:1.73e-05, loss_ics:2.17e-09, loss_res:1.87e-05, loss_energy_value:9.481603e-10
# Epoch #  560000/600000    time:47.50
# loss:1.73e-05, loss_ics:2.16e-09, loss_res:1.87e-05, loss_energy_value:9.459115e-10
# Epoch #  561000/600000    time:47.58
# loss:1.72e-05, loss_ics:2.16e-09, loss_res:1.86e-05, loss_energy_value:9.373061e-10
# Epoch #  562000/600000    time:47.60
# loss:1.72e-05, loss_ics:2.16e-09, loss_res:1.86e-05, loss_energy_value:9.645035e-10
# Epoch #  563000/600000    time:48.11
# loss:1.72e-05, loss_ics:2.15e-09, loss_res:1.85e-05, loss_energy_value:9.310078e-10
# Epoch #  564000/600000    time:47.83
# loss:1.71e-05, loss_ics:2.15e-09, loss_res:1.85e-05, loss_energy_value:9.292542e-10
# Epoch #  565000/600000    time:47.72
# loss:1.71e-05, loss_ics:2.14e-09, loss_res:1.84e-05, loss_energy_value:9.036150e-10
# Epoch #  566000/600000    time:47.98
# loss:1.70e-05, loss_ics:2.14e-09, loss_res:1.84e-05, loss_energy_value:9.127142e-10
# Epoch #  567000/600000    time:47.67
# loss:1.80e-05, loss_ics:3.51e-09, loss_res:1.94e-05, loss_energy_value:7.801360e-09
# Epoch #  568000/600000    time:47.73
# loss:1.69e-05, loss_ics:2.13e-09, loss_res:1.83e-05, loss_energy_value:9.142795e-10
# Epoch #  569000/600000    time:47.57
# loss:1.69e-05, loss_ics:2.13e-09, loss_res:1.82e-05, loss_energy_value:9.023530e-10
# Epoch #  570000/600000    time:47.50
# loss:1.69e-05, loss_ics:2.12e-09, loss_res:1.82e-05, loss_energy_value:9.150511e-10
# Epoch #  571000/600000    time:45.87
# loss:1.68e-05, loss_ics:2.12e-09, loss_res:1.81e-05, loss_energy_value:9.002314e-10
# Epoch #  572000/600000    time:44.87
# loss:1.68e-05, loss_ics:2.11e-09, loss_res:1.81e-05, loss_energy_value:8.933462e-10
# Epoch #  573000/600000    time:44.88
# loss:1.68e-05, loss_ics:2.11e-09, loss_res:1.80e-05, loss_energy_value:8.953549e-10
# Epoch #  574000/600000    time:44.88
# loss:1.70e-05, loss_ics:2.44e-09, loss_res:1.83e-05, loss_energy_value:9.989805e-10
# Epoch #  575000/600000    time:44.90
# loss:1.67e-05, loss_ics:2.10e-09, loss_res:1.80e-05, loss_energy_value:8.830888e-10
# Epoch #  576000/600000    time:44.90
# loss:1.66e-05, loss_ics:2.10e-09, loss_res:1.79e-05, loss_energy_value:8.827179e-10
# Epoch #  577000/600000    time:47.19
# loss:1.66e-05, loss_ics:2.09e-09, loss_res:1.79e-05, loss_energy_value:8.819441e-10
# Epoch #  578000/600000    time:47.51
# loss:1.66e-05, loss_ics:2.09e-09, loss_res:1.78e-05, loss_energy_value:8.773426e-10
# Epoch #  579000/600000    time:47.53
# loss:1.65e-05, loss_ics:2.09e-09, loss_res:1.78e-05, loss_energy_value:8.647597e-10
# Epoch #  580000/600000    time:47.52
# loss:1.67e-05, loss_ics:2.13e-09, loss_res:1.80e-05, loss_energy_value:9.229389e-10
# Epoch #  581000/600000    time:47.55
# loss:1.64e-05, loss_ics:2.08e-09, loss_res:1.77e-05, loss_energy_value:8.620099e-10
# Epoch #  582000/600000    time:47.45
# loss:1.64e-05, loss_ics:2.07e-09, loss_res:1.76e-05, loss_energy_value:8.476505e-10
# Epoch #  583000/600000    time:47.48
# loss:1.64e-05, loss_ics:2.07e-09, loss_res:1.76e-05, loss_energy_value:8.560569e-10
# Epoch #  584000/600000    time:47.66
# loss:1.63e-05, loss_ics:2.07e-09, loss_res:1.76e-05, loss_energy_value:8.499576e-10
# Epoch #  585000/600000    time:47.44
# loss:1.63e-05, loss_ics:2.06e-09, loss_res:1.75e-05, loss_energy_value:8.401493e-10
# Epoch #  586000/600000    time:47.61
# loss:1.63e-05, loss_ics:2.06e-09, loss_res:1.75e-05, loss_energy_value:8.436459e-10
# Epoch #  587000/600000    time:47.62
# loss:1.62e-05, loss_ics:2.06e-09, loss_res:1.74e-05, loss_energy_value:8.360765e-10
# Epoch #  588000/600000    time:47.42
# loss:1.62e-05, loss_ics:2.05e-09, loss_res:1.74e-05, loss_energy_value:8.373703e-10
# Epoch #  589000/600000    time:47.56
# loss:1.62e-05, loss_ics:2.05e-09, loss_res:1.74e-05, loss_energy_value:8.370371e-10
# Epoch #  590000/600000    time:48.45
# loss:1.61e-05, loss_ics:2.05e-09, loss_res:1.73e-05, loss_energy_value:8.286214e-10
# Epoch #  591000/600000    time:47.58
# loss:1.61e-05, loss_ics:2.04e-09, loss_res:1.73e-05, loss_energy_value:8.254517e-10
# Epoch #  592000/600000    time:47.71
# loss:1.61e-05, loss_ics:2.04e-09, loss_res:1.72e-05, loss_energy_value:8.251561e-10
# Epoch #  593000/600000    time:47.52
# loss:1.60e-05, loss_ics:2.03e-09, loss_res:1.72e-05, loss_energy_value:8.201951e-10
# Epoch #  594000/600000    time:47.59
# loss:1.60e-05, loss_ics:2.03e-09, loss_res:1.72e-05, loss_energy_value:8.186667e-10
# Epoch #  595000/600000    time:47.50
# loss:1.60e-05, loss_ics:2.03e-09, loss_res:1.71e-05, loss_energy_value:8.113005e-10
# Epoch #  596000/600000    time:47.50
# loss:1.59e-05, loss_ics:2.02e-09, loss_res:1.71e-05, loss_energy_value:8.153819e-10
# Epoch #  597000/600000    time:47.54
# loss:1.59e-05, loss_ics:2.02e-09, loss_res:1.70e-05, loss_energy_value:8.112821e-10
# Epoch #  598000/600000    time:47.57
# loss:1.59e-05, loss_ics:2.02e-09, loss_res:1.70e-05, loss_energy_value:8.043607e-10
# Epoch #  599000/600000    time:47.73
# loss:1.58e-05, loss_ics:2.01e-09, loss_res:1.70e-05, loss_energy_value:8.025247e-10

# %%
file = f'{args.epochs_Adam}epoch,{args.step_size}step_size,{args.tol}tol,E2'
if os.path.exists(file)==False:
    os.mkdir(file)

# %%
plt.plot(trainer.epoch_log, trainer.loss_ics_log, label='loss_ic')
plt.plot(trainer.epoch_log, trainer.loss_res_log, label='loss_r')
plt.yscale('log')
plt.legend()
plt.savefig(f'{file}/loss.jpg')

# %%
# load the data
data = scipy.io.loadmat('../data/KdV.mat')
usol = data['uu']

# Grid
t_star = data['tt'][0]
x_star = data['x'][0]
TT, XX = np.meshgrid(t_star, x_star)

# Reference solution
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
# Out:
# /home/stu1/.conda/envs/pde/lib/python3.6/site-packages/ipykernel_launcher.py:11: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   # This is added back by InteractiveShellApp.init_path()
# Text(0, 0.5, '$x$')

# %%
# Get trained network parameters
TX = np.hstack((TT.reshape(-1,1), XX.reshape(-1,1)))
TX = torch.from_numpy(TX).double()

model = trainer.model.cpu().double()
u_pred = model(TX).detach().numpy()
u_pred = u_pred.reshape(TT.shape)

error = np.linalg.norm(u_pred - usol) / np.linalg.norm(usol) 
print('Relative l2 error: {:.3e}'.format(error))
# Out:
# Relative l2 error: 2.605e-03

# %%
fig = plt.figure(figsize=(18, 5))
plt.subplot(1, 3, 1)
plt.pcolor(TT, XX, usol, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Exact $u(x)$')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.pcolor(TT, XX, u_pred, cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title(r'Predicted $u(x)$')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.pcolor(TT, XX, np.abs(usol - u_pred), cmap='jet')
plt.colorbar()
plt.xlabel('$t$')
plt.ylabel('$x$')
plt.title('Absolute error')
plt.tight_layout()
plt.savefig(f'{file}/predict.jpg')
plt.show()

# %%
fig = plt.figure(figsize=(13, 4))
plt.subplot(1, 3, 1)
plt.plot(x_star, usol[:,0], color='blue')
plt.plot(x_star, u_pred[:,0], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 0$')
plt.tight_layout()

plt.subplot(1, 3, 2)
plt.plot(x_star, usol[:,25], color='blue')
plt.plot(x_star, u_pred[:,25], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 0.5$')
plt.tight_layout()

plt.subplot(1, 3, 3)
plt.plot(x_star, usol[:,-1], color='blue')
plt.plot(x_star, u_pred[:,-1], '--', color='red')
plt.xlabel('$x$')
plt.ylabel('$u(t, x)$')
plt.title('$t = 1.0$')
plt.tight_layout()
plt.savefig(f'{file}/check_t.jpg')
plt.show()

# %%
L_t = trainer.L_t_log[-1].numpy()
W = trainer.W_log[-1].numpy()
t_r = np.linspace(0, 1, 100)

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(t_r, W)
plt.xlabel('$t$')
plt.ylabel('$w(t)$')

# %%
fig = plt.figure(figsize=(6, 5))
plt.plot(t_r, L_t)
plt.xlabel('$t$')
plt.ylabel('$\mathcal{L}(t, \\theta)$')

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

fig = plt.figure()
ims = []
for i in range(len(trainer.W_log)):
    im = plt.plot(t_r, trainer.W_log[i],'b')
    ims.append(im)
ani = animation.ArtistAnimation(fig, ims, interval=20, repeat_delay=50)
ani.save(f"{file}/weight.gif",writer='pillow')

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

fig = plt.figure()
ims = []
for i in range(len(trainer.L_t_log)):
    im = plt.plot(t_r, trainer.L_t_log[i],'b')
    plt.yscale('log')
    ims.append(im)
ani = animation.ArtistAnimation(fig, ims, interval=20, repeat_delay=50)
ani.save(f"{file}/loss_t.gif",writer='pillow')

# %%
gp = np.array([0.8611363116,-0.8611363116,0.3399810436,-0.3399810436])
gc = np.array([0.3478548451,0.3478548451,0.6521451549,0.6521451549])

# %%
l = np.linspace(-1, 1, 26)[:, None]

# %%
l = np.hstack([l[:-1], l[1:]])
print(l, l.shape)

# %%
c = (l[:, 1] - l[:, 0])/2
print(c.shape)

# %%
c = c[:, None]
c.shape

# %%
c

# %%
gp = gp[None, :]
gp.shape

# %%
d = ((l[:, 1] + l[:, 0])/2)
d.shape
d = d[:, None]

# %%
d.shape

# %%
d

# %%
n_p = c * gp + d

# %%
n_p.shape

# %%
n_p

# %%
gc = gc[None, :]

# %%
c = (l[:, 1] - l[:, 0])/2
c = c[:, None]

# %%
c

# %%
d = (l[:, 1] + l[:, 0])/2
d = d[:, None]

# %%
n_p  = c * gp +d

# %%
gcl = c * gc

# %%
gcl.shape

# %%
gcl

# %%
n_p ** 2 * gcl

# %%
np.sum(n_p ** 2 * gcl)

# %%
2/3

# %%
M = np.triu(np.ones([10, 10]),k=1).T

# %%
M

# %%
q_pred = torch.cos(math.pi * txg[:, 1])
q_pred = q_pred.reshape(100, 128)
#print(q_pred.shape)
gcl = torch.from_numpy(gcl).float().to(device)
q_pred = q_pred ** 2 * gcl.to(device)
q_pred = torch.sum(q_pred, axis=0)

# %%
q_pred

# %%
a = np.array([1, 2, 3, 4])

# %%
b= np.random.choice(a, 2 ,False)

# %%
b

# %%
t = np.linspace(0, 1, 100)

# %%
tt = np.random.choice(t, 10, False)

# %%
tt

# %%
xx = np.linspace(1, 10, 10)

# %%
xx

# %%
x1 , t1 = np.meshgrid(xx, tt)

# %%
aa = np.hstack([t1.reshape(-1, 1), x1.reshape(-1, 1)])

# %%
aa

# %%
aa.shape

# %%
c = np.linspace(1,100, 100)

# %%
c = c[:, None]

# %%
c

# %%
aa = np.hstack([aa, c])

# %%
aa

# %%
aa[:, 2].reshape(-1, 10)

# %%
t = np.linspace(0, 1, 128)[:, None]

# %%
t = np.random.choice(t, 15, False)
